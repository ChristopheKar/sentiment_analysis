# %% [markdown]
# ## **Source**

# %%
# https://github.com/jimmyyfeng/TD-LSTM

# %% [markdown]
# ## **Setup Environment**

# %%
# !unzip datasets.zip
# !rm datasets.zip
# !git clone https://github.com/jimmyyfeng/TD-LSTM
# !mkdir tmp
# !cp TD-LSTM/data/twitter/twitter_word_embedding_partial_200.txt /content/tmp/twitter_word_embedding_partial_200.txt
# !mv utils.py TD-LSTM/utils.py
# Out:
# Archive:  datasets.zip
#    creating: datasets/rt-polaritydata/
#   inflating: datasets/rt-polaritydata/rt-polarity.pos
#   inflating: datasets/rt-polaritydata/rt-polarity.neg
#    creating: datasets/semeval/
#   inflating: datasets/semeval/Restaurants_Train_v2.xml.txt
#   inflating: datasets/semeval/Laptops_test_PhaseB.xml.txt
#   inflating: datasets/semeval/Laptops_test_PhaseA.xml.txt
#   inflating: datasets/semeval/Restuarants_test_phaseA.xml.txt
#   inflating: datasets/semeval/Restuarants_test_phaseB.xml.txt
#   inflating: datasets/semeval/Laptops_train_v2.xml.txt
#   inflating: datasets/semeval/Restaurants_Train.xml.txt
#    creating: datasets/sentihood/
#   inflating: datasets/sentihood/sentihood-test.json
#   inflating: datasets/sentihood/sentihood-dev.json
#   inflating: datasets/sentihood/sentihood-train.json
#    creating: datasets/sst/
#   inflating: datasets/sst/Test_SST-1.txt
#   inflating: datasets/sst/Dev_SST-2.txt
#   inflating: datasets/sst/Training_SST-1.txt
#   inflating: datasets/sst/Training_SST-2.txt
#   inflating: datasets/sst/Dev_SST-1.txt
#   inflating: datasets/sst/Test_SST-2.txt
#    creating: datasets/sst/.ipynb_checkpoints/
# Cloning into 'TD-LSTM'...
# remote: Enumerating objects: 333, done.
# remote: Total 333 (delta 0), reused 0 (delta 0), pack-reused 333
# Receiving objects: 100% (333/333), 34.32 MiB | 26.91 MiB/s, done.
# Resolving deltas: 100% (127/127), done.

# %% [markdown]
# ## **Imports**

# %%
import numpy as np
import os
from operator import itemgetter
from string import punctuation
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## **Loading Data from Different Datasets**
# To train for a specific dataset, only run the cell for that dataset, then skip over to the next section.\
# Don't forget to run the first cells in this section for the loading functions.\

# %%
def generate_vocab(sentences):
    vectorizer = CountVectorizer(input = u'content',
                                analyzer = "word",
                                tokenizer = None,
                                preprocessor = None,
                                stop_words = None,
                                token_pattern = r',|\b\w+\b',
                                max_features = 15448)
    vectorizer.fit(sentences)
    return vectorizer.vocabulary_

def load_vocab(paths):
    sentences = []
    tokens = []
    for path in paths:
        with open(path, 'r', encoding='latin-1', errors='ignore') as f:
            r = f.read()
        for line in r.split('\n'):
            line = line.rstrip()
            text = line.split(' ')[1:]
            for token in text:
                if token not in punctuation:
                    tokens.append(token)
            sentences.append(' '.join(text))
    vocab = generate_vocab(sentences)
    return vocab, tokens
# Out:
# /content

# %%
# sst-1 data
% cd /content
def load_data(split_path, name):
    data = []
    with open(split_path, 'r', encoding='latin-1', errors='ignore') as f:
        r = f.read()
    for line in r.split('\n'):
        line = line.rstrip()
        text = line.split(' ')[1:]
        label = int(line.split(' ')[0])
        for token in text:
            if token not in punctuation:
                data.append((' '.join(text)).replace(token, '$T$'))
                data.append(token)
                data.append(label)  
    with open('tmp/' + name + '.raw', 'w') as f:
        for line in data:
            f.write(str(line) + '\n')

vocab, tokens = load_vocab(['datasets/sst/Training_SST-1.txt', 'datasets/sst/Dev_SST-1.txt', 'datasets/sst/Test_SST-1.txt'])

# word_id.txt
word_ids = [(w, idx+1) for w, idx in zip(list(vocab.keys()), list(vocab.values()))]
word_ids.sort(key=itemgetter(1))
with open('tmp/word_id.txt', 'w') as f:
    for w, idx in word_ids:
        f.write(f'{w} {idx}\n')

# aspect_id.txt
with open('tmp/aspect_id.txt', 'w') as f:
    for idx, token in enumerate(tokens):
        f.write(f'{token} {idx}\n')

# split.raw
load_data('datasets/sst/Training_SST-1.txt', 'train')
load_data('datasets/sst/Dev_SST-1.txt', 'validate')
load_data('datasets/sst/Test_SST-1.txt', 'test')

# %%
# sst-2 data
% cd /content
def load_data(split_path, name):
    data = []
    with open(split_path, 'r', encoding='latin-1', errors='ignore') as f:
        r = f.read()
    for line in r.split('\n'):
        line = line.rstrip()
        text = line.split(' ')[1:]
        label = int(line.split(' ')[0])
        for token in text:
            if token not in punctuation:
                data.append((' '.join(text)).replace(token, '$T$'))
                data.append(token)
                data.append(label)  
    with open('tmp/' + name + '.raw', 'w') as f:
        for line in data:
            f.write(str(line) + '\n')

vocab, tokens = load_vocab(['datasets/sst/Training_SST-2.txt', 'datasets/sst/Dev_SST-2.txt', 'datasets/sst/Test_SST-2.txt'])

# word_id.txt
word_ids = [(w, idx+1) for w, idx in zip(list(vocab.keys()), list(vocab.values()))]
word_ids.sort(key=itemgetter(1))
with open('tmp/word_id.txt', 'w') as f:
    for w, idx in word_ids:
        f.write(f'{w} {idx}\n')

# aspect_id.txt
with open('tmp/aspect_id.txt', 'w') as f:
    for idx, token in enumerate(tokens):
        f.write(f'{token} {idx}\n')

# split.raw
load_data('datasets/sst/Training_SST-2.txt', 'train')
load_data('datasets/sst/Dev_SST-2.txt', 'validate')
load_data('datasets/sst/Test_SST-2.txt', 'test')

# %%
# sentihood data
% cd /content
import json
def load_vocab(paths):
    sentences = []
    tokens = []
    for path in paths:
        with open(path, 'r') as f:
            jfile = json.load(f)
        for i in range(len(jfile)):
            for j in range(len(jfile[i]['opinions'])):                
                text = jfile[i]['text']
                aspect = jfile[i]['opinions'][j]['aspect']
                entity = jfile[i]['opinions'][j]['target_entity']
                sentences.append(text.replace(entity, aspect))
                tokens.append(aspect)
    vocab = generate_vocab(sentences)
    return vocab, tokens

def load_data(split_path, name):
    data = []
    with open(split_path, 'r') as f:
        jfile = json.load(f)
    for i in range(len(jfile)):
        for j in range(len(jfile[i]['opinions'])):                
            text = jfile[i]['text']
            aspect = jfile[i]['opinions'][j]['aspect']
            entity = jfile[i]['opinions'][j]['target_entity']
            if jfile[i]['opinions'][j]['sentiment'] == 'Negative':
                sentiment = 0
            else:
                sentiment = 1
            data.append(text.replace(entity, '$T$'))
            data.append(aspect)
            data.append(sentiment)
    with open('tmp/' + name + '.raw', 'w') as f:
        for line in data:
            f.write(str(line) + '\n')

vocab, tokens = load_vocab(['datasets/sentihood/sentihood-train.json', 'datasets/sentihood/sentihood-dev.json', 'datasets/sentihood/sentihood-test.json'])

# word_id.txt
word_ids = [(w, idx+1) for w, idx in zip(list(vocab.keys()), list(vocab.values()))]
word_ids.sort(key=itemgetter(1))
with open('tmp/word_id.txt', 'w') as f:
    for w, idx in word_ids:
        f.write(f'{w} {idx}\n')

# aspect_id.txt
with open('tmp/aspect_id.txt', 'w') as f:
    for idx, token in enumerate(tokens):
        f.write(f'{token} {idx}\n')

load_data('datasets/sentihood/sentihood-train.json', 'train')
load_data('datasets/sentihood/sentihood-dev.json', 'validate')
load_data('datasets/sentihood/sentihood-test.json', 'test')
# Out:
# /content

# %% [markdown]
# ## **Training**

# %%
# AT SST1
# %cd /content/TD-LSTM
# !python at_lstm.py --train_file_path='../tmp/train.raw' --validate_file_path='../tmp/validate.raw' --test_file_path='../tmp/test.raw' --embedding_file_path='../tmp/twitter_word_embedding_partial_200.txt' --word_id_file_path='../tmp/word_id.txt' --aspect_id_file_path='../tmp/aspect_id.txt' --method='AT' --n_class=5
# Out:
# /content/TD-LSTM
# WARNING:tensorflow:From at_lstm.py:376: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
#
# load word-id mapping done!
#
# a bad word embedding: jojo
# a bad word embedding: raining
# a bad word embedding: borderline
# a bad word embedding: yellow
# a bad word embedding: keno
# a bad word embedding: four
# a bad word embedding: gag
# a bad word embedding: woods
# a bad word embedding: olympics
# a bad word embedding: spiders
# a bad word embedding: verses
# a bad word embedding: hanging
# a bad word embedding: until
# a bad word embedding: marching
# a bad word embedding: foundation
# a bad word embedding: twittercrush
# a bad word embedding: extrapolate
# a bad word embedding: archuleta
# a bad word embedding: gnews
# a bad word embedding: lord
# a bad word embedding: sinking
# a bad word embedding: muthafuckin
# a bad word embedding: differently
# a bad word embedding: hdtv
# a bad word embedding: fur
# a bad word embedding: bringing
# a bad word embedding: pants
# a bad word embedding: welp
# a bad word embedding: engga
# a bad word embedding: prize
# a bad word embedding: less
# a bad word embedding: wooden
# a bad word embedding: classic
# a bad word embedding: voyeur
# a bad word embedding: wednesday
# a bad word embedding: oooo
# a bad word embedding: solid
# a bad word embedding: does
# a bad word embedding: crotch
# a bad word embedding: gizmodo
# a bad word embedding: oooh
# a bad word embedding: multilateral
# a bad word embedding: provided
# a bad word embedding: paul
# a bad word embedding: straight
# a bad word embedding: playlist
# a bad word embedding: figured
# a bad word embedding: specially
# a bad word embedding: tired
# a bad word embedding: nigg
# a bad word embedding: perch
# a bad word embedding: pulse
# a bad word embedding: byron
# a bad word embedding: tires
# a bad word embedding: matthew
# a bad word embedding: second
# a bad word embedding: hockey
# a bad word embedding: hootsuite
# a bad word embedding: spambot
# a bad word embedding: newsrooms
# a bad word embedding: mason
# a bad word embedding: bet
# a bad word embedding: errors
# a bad word embedding: relieving
# a bad word embedding: reopens
# a bad word embedding: cooking
# a bad word embedding: fingers
# a bad word embedding: wrong
# a bad word embedding: hamilton
# a bad word embedding: ko
# a bad word embedding: designing
# a bad word embedding: increasing
# a bad word embedding: presidential
# a bad word embedding: pressed
# a bad word embedding: dort
# a bad word embedding: neville
# a bad word embedding: hero
# a bad word embedding: reporter
# a bad word embedding: aja
# a bad word embedding: hera
# a bad word embedding: interrupting
# a bad word embedding: budget
# a bad word embedding: here
# a bad word embedding: trustworthy
# a bad word embedding: reported
# a bad word embedding: presidency
# a bad word embedding: hers
# a bad word embedding: daht
# a bad word embedding: dork
# a bad word embedding: darkness
# a bad word embedding: kids
# a bad word embedding: downfall
# a bad word embedding: miss
# a bad word embedding: reports
# a bad word embedding: controversy
# a bad word embedding: lg
# a bad word embedding: transfixed
# a bad word embedding: not
# a bad word embedding: military
# a bad word embedding: now
# a bad word embedding: nope
# a bad word embedding: gambhir
# a bad word embedding: criticism
# a bad word embedding: compared
# a bad word embedding: smdh
# a bad word embedding: owed
# a bad word embedding: harvey
# a bad word embedding: explained
# a bad word embedding: three
# a bad word embedding: replace
# a bad word embedding: brought
# a bad word embedding: shoddy
# a bad word embedding: skater
# a bad word embedding: stern
# a bad word embedding: pee
# a bad word embedding: cocaine
# a bad word embedding: unit
# a bad word embedding: mote
# a bad word embedding: casey
# a bad word embedding: sexual
# a bad word embedding: brittani
# a bad word embedding: spoke
# a bad word embedding: catchy
# a bad word embedding: dnt
# a bad word embedding: melanie
# a bad word embedding: music
# a bad word embedding: therefore
# a bad word embedding: strike
# a bad word embedding: musik
# a bad word embedding: until
# a bad word embedding: brighton
# a bad word embedding: hu
# a bad word embedding: playboy
# a bad word embedding: holy
# a bad word embedding: relax
# a bad word embedding: successful
# a bad word embedding: brings
# a bad word embedding: hypocritical
# a bad word embedding: poppers
# a bad word embedding: hurt
# a bad word embedding: hole
# a bad word embedding: hold
# a bad word embedding: locked
# a bad word embedding: vou
# a bad word embedding: text
# a bad word embedding: accomplishment
# a bad word embedding: ending
# a bad word embedding: luna
# a bad word embedding: inget
# a bad word embedding: battlefront
# a bad word embedding: sweeter
# a bad word embedding: example
# a bad word embedding: grimes
# a bad word embedding: duke
# a bad word embedding: le
# a bad word embedding: wang
# a bad word embedding: ends
# a bad word embedding: reality
# a bad word embedding: currency
# a bad word embedding: kiss
# a bad word embedding: reviewing
# a bad word embedding: want
# a bad word embedding: peanuts
# a bad word embedding: dyke
# a bad word embedding: rescue
# a bad word embedding: preferably
# a bad word embedding: hoe
# a bad word embedding: lb
# a bad word embedding: la
# a bad word embedding: complaining
# a bad word embedding: hoo
# a bad word embedding: travel
# a bad word embedding: attention
# a bad word embedding: damage
# a bad word embedding: killing
# a bad word embedding: machine
# a bad word embedding: how
# a bad word embedding: hot
# a bad word embedding: elmo
# a bad word embedding: phils
# a bad word embedding: lp
# a bad word embedding: stock
# a bad word embedding: preferable
# a bad word embedding: wolfram
# a bad word embedding: a
# a bad word embedding: gaming
# a bad word embedding: oritse
# a bad word embedding: beauty
# a bad word embedding: dressed
# a bad word embedding: dell
# a bad word embedding: wrong
# a bad word embedding: hear
# a bad word embedding: reese
# a bad word embedding: high-profile
# a bad word embedding: chorus
# a bad word embedding: balads
# a bad word embedding: outcry
# a bad word embedding: hoping
# a bad word embedding: wins
# a bad word embedding: tumblr
# a bad word embedding: gimmie
# a bad word embedding: season
# a bad word embedding: wink
# a bad word embedding: another
# a bad word embedding: keeps
# a bad word embedding: boice
# a bad word embedding: wind
# a bad word embedding: wine
# a bad word embedding: __
# a bad word embedding: blind
# a bad word embedding: feedback
# a bad word embedding: telecom
# a bad word embedding: govern
# a bad word embedding: sylvester
# a bad word embedding: bubbles
# a bad word embedding: butcher
# a bad word embedding: mañana
# a bad word embedding: dispatch
# a bad word embedding: true
# a bad word embedding: told
# a bad word embedding: hip
# a bad word embedding: gossip
# a bad word embedding: his
# a bad word embedding: fit
# a bad word embedding: wire
# a bad word embedding: screaming
# a bad word embedding: fix
# a bad word embedding: rescued
# a bad word embedding: harris
# a bad word embedding: spurs
# a bad word embedding: fin
# a bad word embedding: easier
# a bad word embedding: aguilera
# a bad word embedding: glorify
# a bad word embedding: blowjobs
# a bad word embedding: lambert
# a bad word embedding: slate
# a bad word embedding: keri
# a bad word embedding: seth
# a bad word embedding: hahahahahahah
# a bad word embedding: zac
# a bad word embedding: yonni
# a bad word embedding: effects
# a bad word embedding: velcro
# a bad word embedding: schools
# a bad word embedding: angelinajolie
# a bad word embedding: sixteen
# a bad word embedding: mereçe
# a bad word embedding: represents
# a bad word embedding: debut
# a bad word embedding: dumps
# a bad word embedding: shame
# a bad word embedding: self-titled
# a bad word embedding: addicted
# a bad word embedding: loeb
# a bad word embedding: herta
# a bad word embedding: curse
# a bad word embedding: financial
# a bad word embedding: snakes
# a bad word embedding: woes
# a bad word embedding: series
# a bad word embedding: lamesauce
# a bad word embedding: science
# a bad word embedding: donald
# a bad word embedding: efron
# a bad word embedding: woei
# a bad word embedding: hollywood
# a bad word embedding: whip
# a bad word embedding: rt
# a bad word embedding: rv
# a bad word embedding: trending
# a bad word embedding: maksim
# a bad word embedding: oprah
# a bad word embedding: dst
# a bad word embedding: blitzer
# a bad word embedding: dsi
# a bad word embedding: size
# a bad word embedding: super
# a bad word embedding: foundation
# a bad word embedding: word
# a bad word embedding: written
# a bad word embedding: media
# a bad word embedding: university
# a bad word embedding: work
# a bad word embedding: threatened
# a bad word embedding: corrects
# a bad word embedding: gameplay
# a bad word embedding: debuting
# a bad word embedding: ate
# a bad word embedding: shelves
# a bad word embedding: atm
# a bad word embedding: chan
# a bad word embedding: devastation
# a bad word embedding: commented
# a bad word embedding: shipped
# a bad word embedding: levels
# a bad word embedding: human
# a bad word embedding: chaz
# a bad word embedding: yester
# a bad word embedding: crossings
# a bad word embedding: obituary
# a bad word embedding: trillion
# a bad word embedding: dun
# a bad word embedding: duo
# a bad word embedding: disfigured
# a bad word embedding: goggle
# a bad word embedding: please
# a bad word embedding: brian
# a bad word embedding: lauter
# a bad word embedding: customization
# a bad word embedding: politics
# a bad word embedding: sex
# a bad word embedding: singh
# a bad word embedding: website
# a bad word embedding: basketball
# a bad word embedding: backlinks
# a bad word embedding: service
# a bad word embedding: lego
# a bad word embedding: effect
# a bad word embedding: needed
# a bad word embedding: simmons
# a bad word embedding: master
# a bad word embedding: listed
# a bad word embedding: worlds
# a bad word embedding: invasion
# a bad word embedding: legs
# a bad word embedding: bitter
# a bad word embedding: listen
# a bad word embedding: yay
# a bad word embedding: grown-up
# a bad word embedding: lucunya
# a bad word embedding: named
# a bad word embedding: wisdom
# a bad word embedding: nirvana
# a bad word embedding: date
# a bad word embedding: predictable
# a bad word embedding: victory
# a bad word embedding: legally
# a bad word embedding: suck
# a bad word embedding: positively
# a bad word embedding: spotifylink
# a bad word embedding: beautiful
# a bad word embedding: trek
# a bad word embedding: code
# a bad word embedding: showed
# a bad word embedding: elegant
# a bad word embedding: coward
# a bad word embedding: tree
# a bad word embedding: likely
# a bad word embedding: nations
# a bad word embedding: project
# a bad word embedding: pioneer
# a bad word embedding: sheen
# a bad word embedding: hahaha
# a bad word embedding: feeling
# a bad word embedding: lebron
# a bad word embedding: cody
# a bad word embedding: chicago
# a bad word embedding: runner
# a bad word embedding: boston
# a bad word embedding: aapl
# a bad word embedding: esto
# a bad word embedding: spectrum
# a bad word embedding: angela
# a bad word embedding: son
# a bad word embedding: angels
# a bad word embedding: williams
# a bad word embedding: then
# a bad word embedding: them
# a bad word embedding: kidnap
# a bad word embedding: britney
# a bad word embedding: ast
# a bad word embedding: ginuwine
# a bad word embedding: band
# a bad word embedding: recommended
# a bad word embedding: causing
# a bad word embedding: amusing
# a bad word embedding: they
# a bad word embedding: brains
# a bad word embedding: ask
# a bad word embedding: jones
# a bad word embedding: haunting
# a bad word embedding: shall
# a bad word embedding: thrilled
# a bad word embedding: screwing
# a bad word embedding: object
# a bad word embedding: cinematic
# a bad word embedding: victoria
# a bad word embedding: kelly
# a bad word embedding: mouth
# a bad word embedding: addict
# a bad word embedding: letter
# a bad word embedding: entry
# a bad word embedding: retaining
# a bad word embedding: macbook
# a bad word embedding: thriller
# a bad word embedding: typical
# a bad word embedding: singer
# a bad word embedding: africa
# a bad word embedding: episode
# a bad word embedding: hispanic
# a bad word embedding: camp
# a bad word embedding: bullock
# a bad word embedding: coloquem
# a bad word embedding: drunks
# a bad word embedding: tech
# a bad word embedding: lisbon
# a bad word embedding: scream
# a bad word embedding: came
# a bad word embedding: saying
# a bad word embedding: bomb
# a bad word embedding: reactor
# a bad word embedding: dédié
# a bad word embedding: flunking
# a bad word embedding: meetings
# a bad word embedding: agency
# a bad word embedding: curls
# a bad word embedding: nominated
# a bad word embedding: rediscovery
# a bad word embedding: tehran
# a bad word embedding: daryl
# a bad word embedding: congressional
# a bad word embedding: vindictive
# a bad word embedding: lessons
# a bad word embedding: orleans
# a bad word embedding: busy
# a bad word embedding: rca
# a bad word embedding: shuffling
# a bad word embedding: headline
# a bad word embedding: menu
# a bad word embedding: boleh
# a bad word embedding: bust
# a bad word embedding: rihanna
# a bad word embedding: theme
# a bad word embedding: rick
# a bad word embedding: rich
# a bad word embedding: snitch
# a bad word embedding: mrs.
# a bad word embedding: yo
# a bad word embedding: goper
# a bad word embedding: btw
# a bad word embedding: psychiatric
# a bad word embedding: ldn
# a bad word embedding: pocket
# a bad word embedding: x
# a bad word embedding: thingys
# a bad word embedding: net
# a bad word embedding: nicely
# a bad word embedding: jovana
# a bad word embedding: armin
# a bad word embedding: rio
# a bad word embedding: openly
# a bad word embedding: sean
# a bad word embedding: piggy
# a bad word embedding: release
# a bad word embedding: clearly
# a bad word embedding: pada
# a bad word embedding: dmb
# a bad word embedding: disaster
# a bad word embedding: fair
# a bad word embedding: deemed
# a bad word embedding: levant
# a bad word embedding: goodnight
# a bad word embedding: dms
# a bad word embedding: result
# a bad word embedding: fail
# a bad word embedding: logging
# a bad word embedding: android
# a bad word embedding: john
# a bad word embedding: hammer
# a bad word embedding: best
# a bad word embedding: karate
# a bad word embedding: cobra
# a bad word embedding: moron
# a bad word embedding: risk
# a bad word embedding: manson
# a bad word embedding: glass
# a bad word embedding: lots
# a bad word embedding: rise
# a bad word embedding: rings
# a bad word embedding: upgraded
# a bad word embedding: lott
# a bad word embedding: stamps
# a bad word embedding: dms
# a bad word embedding: cage
# a bad word embedding: ire
# a bad word embedding: lamar
# a bad word embedding: never
# a bad word embedding: parallels
# a bad word embedding: omnivore
# a bad word embedding: lindsey
# a bad word embedding: wtf
# a bad word embedding: wth
# a bad word embedding: perverts
# a bad word embedding: jlo
# a bad word embedding: debt
# a bad word embedding: capello
# a bad word embedding: pity
# a bad word embedding: veronica
# a bad word embedding: accident
# a bad word embedding: mixtape
# a bad word embedding: country
# a bad word embedding: adapter
# a bad word embedding: psa
# a bad word embedding: sanja
# a bad word embedding: adventures
# a bad word embedding: demanded
# a bad word embedding: playful
# a bad word embedding: tekin
# a bad word embedding: geweldig
# a bad word embedding: planned
# a bad word embedding: hated
# a bad word embedding: als
# a bad word embedding: login
# a bad word embedding: argue
# a bad word embedding: asked
# a bad word embedding: and
# a bad word embedding: mortified
# a bad word embedding: apartment
# a bad word embedding: twenty-three
# a bad word embedding: closet
# a bad word embedding: vail
# a bad word embedding: vaio
# a bad word embedding: blonds
# a bad word embedding: cult
# a bad word embedding: telegraph
# a bad word embedding: pregnancy
# a bad word embedding: blonde
# a bad word embedding: method
# a bad word embedding: saturday
# a bad word embedding: americus
# a bad word embedding: blocks
# a bad word embedding: angel
# a bad word embedding: fromtwitter
# a bad word embedding: source
# a bad word embedding: chrome
# a bad word embedding: activa
# a bad word embedding: fri
# a bad word embedding: fro
# a bad word embedding: .
# a bad word embedding: bothers
# a bad word embedding: much
# a bad word embedding: dont
# a bad word embedding: privilege
# a bad word embedding: reggie
# a bad word embedding: fry
# a bad word embedding: gladly
# a bad word embedding: tomato
# a bad word embedding: life
# a bad word embedding: crying
# a bad word embedding: poland
# a bad word embedding: worker
# a bad word embedding: moldova
# a bad word embedding: dave
# a bad word embedding: lift
# a bad word embedding: child
# a bad word embedding: easton
# a bad word embedding: stepdad
# a bad word embedding: haters
# a bad word embedding: spin
# a bad word embedding: chill
# a bad word embedding: holmes
# a bad word embedding: commerce
# a bad word embedding: simplifies
# a bad word embedding: presidency
# a bad word embedding: ada
# a bad word embedding: vexed
# a bad word embedding: castro
# a bad word embedding: hippocratic
# a bad word embedding: starstruck
# a bad word embedding: goaly
# a bad word embedding: event
# a bad word embedding: spoof
# a bad word embedding: surprises
# a bad word embedding: played
# a bad word embedding: ditching
# a bad word embedding: vacation
# a bad word embedding: lol
# a bad word embedding: conditioned
# a bad word embedding: player
# a bad word embedding: courtney
# a bad word embedding: madonna
# a bad word embedding: sells
# a bad word embedding: trusted
# a bad word embedding: undue
# a bad word embedding: hong
# a bad word embedding: recover
# a bad word embedding: taped
# a bad word embedding: python
# a bad word embedding: things
# a bad word embedding: oh
# a bad word embedding: backed
# a bad word embedding: patient
# a bad word embedding: split
# a bad word embedding: babies
# a bad word embedding: electro
# a bad word embedding: fairly
# a bad word embedding: runs
# a bad word embedding: biggie
# a bad word embedding: maybe
# a bad word embedding: keyshia
# a bad word embedding: jungle
# a bad word embedding: tops
# a bad word embedding: workforce
# a bad word embedding: tuna
# a bad word embedding: truths
# a bad word embedding: haggard
# a bad word embedding: tune
# a bad word embedding: nuanced
# a bad word embedding: nat'l
# a bad word embedding: blowjob
# a bad word embedding: academic
# a bad word embedding: corporate
# a bad word embedding: fittest
# a bad word embedding: opinions
# a bad word embedding: thank
# a bad word embedding: sleeps
# a bad word embedding: that
# a bad word embedding: sleepy
# a bad word embedding: sid
# a bad word embedding: allday
# a bad word embedding: meester
# a bad word embedding: censoring
# a bad word embedding: rushing
# a bad word embedding: succeeding
# a bad word embedding: happy
# a bad word embedding: hah
# a bad word embedding: blame
# a bad word embedding: hal
# a bad word embedding: offer
# a bad word embedding: marieclaire
# a bad word embedding: ease
# a bad word embedding: had
# a bad word embedding: hag
# a bad word embedding: bnk
# a bad word embedding: haz
# a bad word embedding: surely
# a bad word embedding: richie
# a bad word embedding: easy
# a bad word embedding: prison
# a bad word embedding: har
# a bad word embedding: has
# a bad word embedding: hat
# a bad word embedding: wide
# a bad word embedding: survival
# a bad word embedding: credit
# a bad word embedding: posed
# a bad word embedding: possible
# a bad word embedding: twinks
# a bad word embedding: revolver
# a bad word embedding: possibly
# a bad word embedding: yeh
# a bad word embedding: kiss
# a bad word embedding: distortion
# a bad word embedding: shadow
# a bad word embedding: unique
# a bad word embedding: usually
# a bad word embedding: stylist
# a bad word embedding: desire
# a bad word embedding: stooopid
# a bad word embedding: ang
# a bad word embedding: oh
# a bad word embedding: kust
# a bad word embedding: remind
# a bad word embedding: aristotle
# a bad word embedding: steven
# a bad word embedding: sebastian
# a bad word embedding: oooooooooh
# a bad word embedding: swedish
# a bad word embedding: ola
# a bad word embedding: attorney
# a bad word embedding: right
# a bad word embedding: old
# a bad word embedding: creek
# a bad word embedding: people
# a bad word embedding: idiot
# a bad word embedding: creed
# a bad word embedding: crown
# a bad word embedding: topping
# a bad word embedding: olo
# a bad word embedding: arquette
# a bad word embedding: gon
# a bad word embedding: insistence
# a bad word embedding: billboard
# a bad word embedding: prick
# a bad word embedding: fuuuuck
# a bad word embedding: creep
# a bad word embedding: gasps
# a bad word embedding: ruffled
# a bad word embedding: for
# a bad word embedding: bottom
# a bad word embedding: res
# a bad word embedding: fox
# a bad word embedding: creative
# a bad word embedding: witty
# a bad word embedding: foe
# a bad word embedding: fog
# a bad word embedding: facebook
# a bad word embedding: foc
# a bad word embedding: umm
# a bad word embedding: keith
# a bad word embedding: celebration
# a bad word embedding: pinched
# a bad word embedding: instant
# a bad word embedding: annan
# a bad word embedding: calls
# a bad word embedding: lightsabers
# a bad word embedding: trampoline
# a bad word embedding: dng
# a bad word embedding: thing
# a bad word embedding: shifting
# a bad word embedding: starring
# a bad word embedding: stylish
# a bad word embedding: losing
# a bad word embedding: memorable
# a bad word embedding: jelena
# a bad word embedding: think
# a bad word embedding: first
# a bad word embedding: amber
# a bad word embedding: spektor
# a bad word embedding: nowplaying
# a bad word embedding: dollars
# a bad word embedding: citizens
# a bad word embedding: entrants
# a bad word embedding: o
# a bad word embedding: valentine
# a bad word embedding: schue
# a bad word embedding: stoked
# a bad word embedding: meddle
# a bad word embedding: sooo
# a bad word embedding: happens
# a bad word embedding: raised
# a bad word embedding: statements
# a bad word embedding: logo
# a bad word embedding: marshall
# a bad word embedding: honeymoon
# a bad word embedding: som
# a bad word embedding: son
# a bad word embedding: thankful
# a bad word embedding: aaron
# a bad word embedding: magazines
# a bad word embedding: latina
# a bad word embedding: globalgrind
# a bad word embedding: adhd
# a bad word embedding: soy
# a bad word embedding: shoots
# a bad word embedding: discography
# a bad word embedding: fey
# a bad word embedding: novo
# a bad word embedding: ends
# a bad word embedding: novi
# a bad word embedding: waits
# a bad word embedding: support
# a bad word embedding: halle
# a bad word embedding: hang
# a bad word embedding: avail
# a bad word embedding: absolutely
# a bad word embedding: jank
# a bad word embedding: spring
# a bad word embedding: awful
# a bad word embedding: tweeps
# a bad word embedding: marge
# a bad word embedding: happy
# a bad word embedding: manufacturers
# a bad word embedding: fascination
# a bad word embedding: eer
# a bad word embedding: publicized
# a bad word embedding: fresh
# a bad word embedding: handjob
# a bad word embedding: upgrades
# a bad word embedding: seeing
# a bad word embedding: congratulations
# a bad word embedding: humbled
# a bad word embedding: minaj
# a bad word embedding: inside
# a bad word embedding: islands
# a bad word embedding: trash
# a bad word embedding: devices
# a bad word embedding: cale
# a bad word embedding: considered
# a bad word embedding: vanguard
# a bad word embedding: tony
# a bad word embedding: palm
# a bad word embedding: duet
# a bad word embedding: panels
# a bad word embedding: cuddles
# a bad word embedding: disgrace
# a bad word embedding: minaj
# a bad word embedding: steady
# a bad word embedding: six
# a bad word embedding: josh
# a bad word embedding: christina
# a bad word embedding: proven
# a bad word embedding: ''
# a bad word embedding: virgin
# a bad word embedding: proves
# a bad word embedding: exist
# a bad word embedding: portrayed
# a bad word embedding: dealer
# a bad word embedding: woooow
# a bad word embedding: francisco
# a bad word embedding: floor
# a bad word embedding: feat
# a bad word embedding: mayo
# a bad word embedding: actor
# a bad word embedding: ourselves
# a bad word embedding: flood
# a bad word embedding: role
# a bad word embedding: woke
# a bad word embedding: hurr
# a bad word embedding: developers
# a bad word embedding: smell
# a bad word embedding: roll
# a bad word embedding: re-watched
# a bad word embedding: cracks
# a bad word embedding: 's
# a bad word embedding: palms
# a bad word embedding: lenny
# a bad word embedding: meghan
# a bad word embedding: center
# a bad word embedding: snowe
# a bad word embedding: 'd
# a bad word embedding: idk
# a bad word embedding: miranda
# a bad word embedding: rolling
# a bad word embedding: 'n
# a bad word embedding: 'm
# a bad word embedding: chrisette
# a bad word embedding: jewelry
# a bad word embedding: 's
# a bad word embedding: euroland
# a bad word embedding: contacts
# a bad word embedding: ottawa
# a bad word embedding: montag
# a bad word embedding: bitchmode
# a bad word embedding: time
# a bad word embedding: push
# a bad word embedding: tunes
# a bad word embedding: empire
# a bad word embedding: inc
# a bad word embedding: gown
# a bad word embedding: japan
# a bad word embedding: whoever
# a bad word embedding: real-estate
# a bad word embedding: nicklaus
# a bad word embedding: plumb
# a bad word embedding: hawaii
# a bad word embedding: disappears
# a bad word embedding: chair
# a bad word embedding: bye
# a bad word embedding: imacs
# a bad word embedding: ward
# a bad word embedding: ver
# a bad word embedding: struggle
# a bad word embedding: sneakers
# a bad word embedding: tourism
# a bad word embedding: eliminate
# a bad word embedding: recipient
# a bad word embedding: logos
# a bad word embedding: downloading
# a bad word embedding: prize
# a bad word embedding: jerk
# a bad word embedding: everytime
# a bad word embedding: saldana
# a bad word embedding: consolidation
# a bad word embedding: olympus
# a bad word embedding: choice
# a bad word embedding: nothing
# a bad word embedding: laurie
# a bad word embedding: rechargable
# a bad word embedding: minute
# a bad word embedding: rand
# a bad word embedding: cooks
# a bad word embedding: doggy
# a bad word embedding: micah
# a bad word embedding: hahah
# a bad word embedding: ludacris
# a bad word embedding: tax
# a bad word embedding: invade
# a bad word embedding: leave
# a bad word embedding: :]
# a bad word embedding: katrina
# a bad word embedding: dnc
# a bad word embedding: team
# a bad word embedding: warren
# a bad word embedding: loads
# a bad word embedding: shooters
# a bad word embedding: kevin
# a bad word embedding: prevent
# a bad word embedding: droid
# a bad word embedding: o.o
# a bad word embedding: sigh
# a bad word embedding: sign
# a bad word embedding: utility
# a bad word embedding: failed
# a bad word embedding: erotic
# a bad word embedding: mega
# a bad word embedding: designs
# a bad word embedding: shirts
# a bad word embedding: reaffirmed
# a bad word embedding: ➲
# a bad word embedding: brady
# a bad word embedding: threesomes
# a bad word embedding: jeopardy
# a bad word embedding: celebrated
# a bad word embedding: realizing
# a bad word embedding: melt
# a bad word embedding: maine
# a bad word embedding: current
# a bad word embedding: freaks
# a bad word embedding: ➜
# a bad word embedding: locket
# a bad word embedding: falling
# a bad word embedding: celebrates
# a bad word embedding: lopez
# a bad word embedding: me
# a bad word embedding: creepiest
# a bad word embedding: dates
# a bad word embedding: ma
# a bad word embedding: niche
# a bad word embedding: africa
# a bad word embedding: rachel
# a bad word embedding: understanding
# a bad word embedding: sharing
# a bad word embedding: mr
# a bad word embedding: alone
# a bad word embedding: along
# a bad word embedding: my
# a bad word embedding: warner
# a bad word embedding: assassinating
# a bad word embedding: neville
# a bad word embedding: butt-naked
# a bad word embedding: toyboy
# a bad word embedding: redemption
# a bad word embedding: dusty
# a bad word embedding: woop
# a bad word embedding: wherever
# a bad word embedding: mj
# a bad word embedding: blog
# a bad word embedding: born
# a bad word embedding: ineffective
# a bad word embedding: myers
# a bad word embedding: my
# a bad word embedding: mx
# a bad word embedding: reclaim
# a bad word embedding: real
# a bad word embedding: love
# a bad word embedding: policies
# a bad word embedding: lactating
# a bad word embedding: defend
# a bad word embedding: prefer
# a bad word embedding: dog
# a bad word embedding: bloody
# a bad word embedding: fakers
# a bad word embedding: fake
# a bad word embedding: carol
# a bad word embedding: ecuador
# a bad word embedding: himym
# a bad word embedding: working
# a bad word embedding: may
# a bad word embedding: positive
# a bad word embedding: angry
# a bad word embedding: nationalize
# a bad word embedding: hello
# a bad word embedding: sisterly
# a bad word embedding: wondering
# a bad word embedding: films
# a bad word embedding: heroics
# a bad word embedding: softball
# a bad word embedding: bodies
# a bad word embedding: loving
# a bad word embedding: scratched
# a bad word embedding: ``
# a bad word embedding: leeches
# a bad word embedding: clitoris
# a bad word embedding: apparent
# a bad word embedding: refrain
# a bad word embedding: consoles
# a bad word embedding: goods
# a bad word embedding: everywhere
# a bad word embedding: icon
# a bad word embedding: rythme
# a bad word embedding: behalf
# a bad word embedding: suckah
# a bad word embedding: logos
# a bad word embedding: deserved
# a bad word embedding: originally
# a bad word embedding: pretend
# a bad word embedding: magnificent
# a bad word embedding: birkin
# a bad word embedding: believer
# a bad word embedding: believes
# a bad word embedding: nether
# a bad word embedding: inciter
# a bad word embedding: values
# a bad word embedding: phoebe
# a bad word embedding: goody
# a bad word embedding: following
# a bad word embedding: our
# a bad word embedding: marsden
# a bad word embedding: slightly
# a bad word embedding: pur
# a bad word embedding: out
# a bad word embedding: hermoine
# a bad word embedding: awesome
# a bad word embedding: stipulation
# a bad word embedding: bad
# a bad word embedding: ter
# a bad word embedding: allowed
# a bad word embedding: offense
# a bad word embedding: kemacetan
# a bad word embedding: juli
# a bad word embedding: stole
# a bad word embedding: piazza
# a bad word embedding: winter
# a bad word embedding: cobain
# a bad word embedding: gambino
# a bad word embedding: who
# a bad word embedding: poking
# a bad word embedding: cloak
# a bad word embedding: caged
# a bad word embedding: homii
# a bad word embedding: why
# a bad word embedding: snaps
# a bad word embedding: jazz
# a bad word embedding: laundry
# a bad word embedding: explorer
# a bad word embedding: meets
# a bad word embedding: blogtv
# a bad word embedding: punk
# a bad word embedding: blasting
# a bad word embedding: spot
# a bad word embedding: dats
# a bad word embedding: applications
# a bad word embedding: snape
# a bad word embedding: co-writing
# a bad word embedding: date
# a bad word embedding: such
# a bad word embedding: suck
# a bad word embedding: data
# a bad word embedding: shockingly
# a bad word embedding: moly
# a bad word embedding: surfing
# a bad word embedding: natural
# a bad word embedding: vogel
# a bad word embedding: stomping
# a bad word embedding: wheelchair
# a bad word embedding: sw
# a bad word embedding: st
# a bad word embedding: si
# a bad word embedding: sh
# a bad word embedding: so
# a bad word embedding: haterade
# a bad word embedding: swollen
# a bad word embedding: kanye
# a bad word embedding: sa
# a bad word embedding: katie
# a bad word embedding: pulled
# a bad word embedding: se
# a bad word embedding: sd
# a bad word embedding: drunken
# a bad word embedding: lie
# a bad word embedding: imogen
# a bad word embedding: barnes
# a bad word embedding: morissette
# a bad word embedding: years
# a bad word embedding: rihanna
# a bad word embedding: course
# a bad word embedding: episodes
# a bad word embedding: kanye
# a bad word embedding: stills
# a bad word embedding: abduzeedo
# a bad word embedding: hip-hop
# a bad word embedding: splurge
# a bad word embedding: overhaul
# a bad word embedding: thumb
# a bad word embedding: couric
# a bad word embedding: muses
# a bad word embedding: tori
# a bad word embedding: stupidity
# a bad word embedding: faves
# a bad word embedding: attraction
# a bad word embedding: suspicion
# a bad word embedding: whitney
# a bad word embedding: troubled
# a bad word embedding: visiting
# a bad word embedding: petition
# a bad word embedding: sate
# a bad word embedding: buck
# a bad word embedding: sister
# a bad word embedding: unlove
# a bad word embedding: hop
# a bad word embedding: matches
# a bad word embedding: smarter
# a bad word embedding: nation
# a bad word embedding: fr
# a bad word embedding: records
# a bad word embedding: strauss
# a bad word embedding: arriving
# a bad word embedding: sorted
# a bad word embedding: twilight
# a bad word embedding: \
# a bad word embedding: maintaining
# a bad word embedding: osama
# a bad word embedding: newest
# a bad word embedding: apologizes
# a bad word embedding: succeeds
# a bad word embedding: wish
# a bad word embedding: yellow
# a bad word embedding: pete
# a bad word embedding: fucking
# a bad word embedding: grants
# a bad word embedding: bowling
# a bad word embedding: stanley
# a bad word embedding: amnesty
# a bad word embedding: argies
# a bad word embedding: repaired
# a bad word embedding: ooomg
# a bad word embedding: louboutin
# a bad word embedding: square
# a bad word embedding: honduras
# a bad word embedding: mexico
# a bad word embedding: couples
# a bad word embedding: breakthrough
# a bad word embedding: live
# a bad word embedding: entering
# a bad word embedding: cole
# a bad word embedding: ergh
# a bad word embedding: troll
# a bad word embedding: joker
# a bad word embedding: demolition
# a bad word embedding: joy
# a bad word embedding: welcome
# a bad word embedding: job
# a bad word embedding: exploding
# a bad word embedding: joe
# a bad word embedding: squares
# a bad word embedding: bla
# a bad word embedding: jon
# a bad word embedding: smalls
# a bad word embedding: dodgers
# a bad word embedding: thank
# a bad word embedding: hairdresser
# a bad word embedding: million
# a bad word embedding: seventh
# a bad word embedding: magical
# a bad word embedding: governing
# a bad word embedding: quite
# a bad word embedding: disrespect
# a bad word embedding: complicated
# a bad word embedding: crazier
# a bad word embedding: besides
# a bad word embedding: mixed
# a bad word embedding: poems
# a bad word embedding: ___
# a bad word embedding: training
# a bad word embedding: dunno
# a bad word embedding: punk
# a bad word embedding: initiate
# a bad word embedding: whiplash
# a bad word embedding: puns
# a bad word embedding: massive
# a bad word embedding: bargain
# a bad word embedding: router
# a bad word embedding: brazil
# a bad word embedding: intuition
# a bad word embedding: saving
# a bad word embedding: baybay
# a bad word embedding: gasp
# a bad word embedding: petulant
# a bad word embedding: royal
# a bad word embedding: one
# a bad word embedding: behave
# a bad word embedding: spanish
# a bad word embedding: vote
# a bad word embedding: open
# a bad word embedding: ripping
# a bad word embedding: exaggerations
# a bad word embedding: city
# a bad word embedding: chums
# a bad word embedding: wrath
# a bad word embedding: monday
# a bad word embedding: structured
# a bad word embedding: rule
# a bad word embedding: hmm
# a bad word embedding: homosexuality
# a bad word embedding: draft
# a bad word embedding: types
# a bad word embedding: stuffed
# a bad word embedding: typing
# a bad word embedding: hype
# a bad word embedding: uses
# a bad word embedding: repeal
# a bad word embedding: violated
# a bad word embedding: williams
# a bad word embedding: patrick
# a bad word embedding: proving
# a bad word embedding: ridiculous
# a bad word embedding: korean
# a bad word embedding: bombs
# a bad word embedding: smoking
# a bad word embedding: fooled
# a bad word embedding: kurt
# a bad word embedding: boyfriend
# a bad word embedding: bored
# a bad word embedding: earmuffs
# a bad word embedding: dickhead
# a bad word embedding: depressed
# a bad word embedding: rival
# a bad word embedding: folly
# a bad word embedding: sensation
# a bad word embedding: crossroads
# a bad word embedding: fun
# a bad word embedding: rehab
# a bad word embedding: rochelle
# a bad word embedding: future
# a bad word embedding: fills
# a bad word embedding: surprisingly
# a bad word embedding: pwahaha
# a bad word embedding: damned
# a bad word embedding: prospect
# a bad word embedding: fly
# a bad word embedding: addressing
# a bad word embedding: illness
# a bad word embedding: nicer
# a bad word embedding: overcooked
# a bad word embedding: turned
# a bad word embedding: argument
# a bad word embedding: alley
# a bad word embedding: sad
# a bad word embedding: prestigious
# a bad word embedding: say
# a bad word embedding: buried
# a bad word embedding: hilarious
# a bad word embedding: allen
# a bad word embedding: regards
# a bad word embedding: e-book
# a bad word embedding: opened
# a bad word embedding: both
# a bad word embedding: presid
# a bad word embedding: zoe
# a bad word embedding: babysit
# a bad word embedding: alicia
# a bad word embedding: aside
# a bad word embedding: note
# a bad word embedding: omfg
# a bad word embedding: take
# a bad word embedding: half
# a bad word embedding: destroy
# a bad word embedding: mayer
# a bad word embedding: hall
# a bad word embedding: ironically
# a bad word embedding: printer
# a bad word embedding: altered
# a bad word embedding: opposite
# a bad word embedding: buffer
# a bad word embedding: knew
# a bad word embedding: kerr
# a bad word embedding: times
# a bad word embedding: wong
# a bad word embedding: abus
# a bad word embedding: keri
# a bad word embedding: remarks
# a bad word embedding: knee
# a bad word embedding: hoped
# a bad word embedding: pages
# a bad word embedding: trainer
# a bad word embedding: democratic
# a bad word embedding: cher
# a bad word embedding: phil
# a bad word embedding: drive
# a bad word embedding: moose
# a bad word embedding: federal
# a bad word embedding: antarctica
# a bad word embedding: strip
# a bad word embedding: ♪
# a bad word embedding: flashback
# a bad word embedding: blue
# a bad word embedding: walking
# a bad word embedding: olha
# a bad word embedding: supplements
# a bad word embedding: opportunist
# a bad word embedding: virgos
# a bad word embedding: sky
# a bad word embedding: tohoku
# a bad word embedding: boyz
# a bad word embedding: roland
# a bad word embedding: hornby
# a bad word embedding: aggressive
# a bad word embedding: wants
# a bad word embedding: smfh
# a bad word embedding: slow
# a bad word embedding: motherhood
# a bad word embedding: sacramento
# a bad word embedding: deck
# a bad word embedding: cinco
# a bad word embedding: tears
# a bad word embedding: going
# a bad word embedding: hockey
# a bad word embedding: outrage
# a bad word embedding: ✔
# a bad word embedding: congressional
# a bad word embedding: bryant
# a bad word embedding: trivia
# a bad word embedding: predict
# a bad word embedding: beatles
# a bad word embedding: hallows
# a bad word embedding: freezing
# a bad word embedding: cursing
# a bad word embedding: magazine
# a bad word embedding: products
# a bad word embedding: crossed
# a bad word embedding: having
# a bad word embedding: prime
# a bad word embedding: resource
# a bad word embedding: clipe
# a bad word embedding: artist
# a bad word embedding: jeff
# a bad word embedding: borrow
# a bad word embedding: awwwww
# a bad word embedding: worried
# a bad word embedding: manchester
# a bad word embedding: bombs
# a bad word embedding: worries
# a bad word embedding: yes
# a bad word embedding: where
# a bad word embedding: vision
# a bad word embedding: lindsaylohan
# a bad word embedding: cio
# a bad word embedding: diluted
# a bad word embedding: gangster
# a bad word embedding: anyways
# a bad word embedding: fellas
# a bad word embedding: surgery
# a bad word embedding: enjoying
# a bad word embedding: into
# a bad word embedding: rages
# a bad word embedding: britt
# a bad word embedding: church
# a bad word embedding: brave
# a bad word embedding: that
# a bad word embedding: jumped
# a bad word embedding: sites
# a bad word embedding: wisdom
# a bad word embedding: teeny
# a bad word embedding: books
# a bad word embedding: jonas
# a bad word embedding: teens
# a bad word embedding: than
# a bad word embedding: jumper
# a bad word embedding: bible
# a bad word embedding: jobs
# a bad word embedding: uk
# a bad word embedding: klown
# a bad word embedding: screen
# a bad word embedding: planes
# a bad word embedding: dome
# a bad word embedding: supermarket
# a bad word embedding: awards
# a bad word embedding: dslrs
# a bad word embedding: spark
# a bad word embedding: undermine
# a bad word embedding: tried
# a bad word embedding: www
# a bad word embedding: rant
# a bad word embedding: lice
# a bad word embedding: many
# a bad word embedding: manz
# a bad word embedding: millionaire
# a bad word embedding: flipped
# a bad word embedding: mana
# a bad word embedding: s
# a bad word embedding: loudly
# a bad word embedding: crooked
# a bad word embedding: expression
# a bad word embedding: guts
# a bad word embedding: syria
# a bad word embedding: timberlake
# a bad word embedding: team
# a bad word embedding: yankovic
# a bad word embedding: fsm
# a bad word embedding: mccain
# a bad word embedding: comparing
# a bad word embedding: twin
# a bad word embedding: appeaser
# a bad word embedding: comeback
# a bad word embedding: sentinel
# a bad word embedding: considers
# a bad word embedding: boat
# a bad word embedding: math
# a bad word embedding: caring
# a bad word embedding: myles
# a bad word embedding: armstrong
# a bad word embedding: fic
# a bad word embedding: stretch
# a bad word embedding: west
# a bad word embedding: flash
# a bad word embedding: breath
# a bad word embedding: combined
# a bad word embedding: nessas
# a bad word embedding: reflex
# a bad word embedding: princess
# a bad word embedding: hilarity
# a bad word embedding: shine
# a bad word embedding: wants
# a bad word embedding: detach
# a bad word embedding: whenever
# a bad word embedding: marc
# a bad word embedding: antivirus
# a bad word embedding: turtleneck
# a bad word embedding: muchlove
# a bad word embedding: greatest
# a bad word embedding: fleshy
# a bad word embedding: former
# a bad word embedding: fireflies
# a bad word embedding: jazeera
# a bad word embedding: run
# a bad word embedding: libya
# a bad word embedding: consultant
# a bad word embedding: polls
# a bad word embedding: outside
# a bad word embedding: ransom
# a bad word embedding: him
# a bad word embedding: doctrine
# a bad word embedding: situation
# a bad word embedding: album
# a bad word embedding: ive
# a bad word embedding: feel
# a bad word embedding: die
# a bad word embedding: purse
# a bad word embedding: dubious
# a bad word embedding: quiet
# a bad word embedding: looking
# a bad word embedding: blah
# a bad word embedding: useless
# a bad word embedding: prez
# a bad word embedding: pharoah
# a bad word embedding: grievous
# a bad word embedding: month
# a bad word embedding: technology
# a bad word embedding: fame
# a bad word embedding: pres
# a bad word embedding: len
# a bad word embedding: binary
# a bad word embedding: missiles
# a bad word embedding: verified
# a bad word embedding: rooting
# a bad word embedding: nationalism
# a bad word embedding: lovers
# a bad word embedding: yessir
# a bad word embedding: damon
# a bad word embedding: through
# a bad word embedding: bloom
# a bad word embedding: workout
# a bad word embedding: homophobic
# a bad word embedding: jailbreaking
# a bad word embedding: breakdown
# a bad word embedding: wires
# a bad word embedding: sickness
# a bad word embedding: i
# a bad word embedding: rotflmao
# a bad word embedding: rfid
# a bad word embedding: cheers
# a bad word embedding: cullen
# a bad word embedding: wired
# a bad word embedding: deff
# a bad word embedding: clean
# a bad word embedding: %
# a bad word embedding: taskbar
# a bad word embedding: own
# a bad word embedding: says
# a bad word embedding: behaved
# a bad word embedding: owe
# a bad word embedding: know
# a bad word embedding: may
# a bad word embedding: costs
# a bad word embedding: tutorial
# a bad word embedding: scholarship
# a bad word embedding: summer
# a bad word embedding: hbo
# a bad word embedding: sprayed
# a bad word embedding: predicting
# a bad word embedding: being
# a bad word embedding: rest
# a bad word embedding: conservative
# a bad word embedding: cards
# a bad word embedding: daniel
# a bad word embedding: verdad
# a bad word embedding: summed
# a bad word embedding: jeremy
# a bad word embedding: weekly
# a bad word embedding: segal
# a bad word embedding: kirk
# a bad word embedding: approves
# a bad word embedding: characterization
# a bad word embedding: nyanyi
# a bad word embedding: travolta
# a bad word embedding: crank
# a bad word embedding: overthrow
# a bad word embedding: coded
# a bad word embedding: vibrating
# a bad word embedding: pfsh
# a bad word embedding: travel
# a bad word embedding: roller
# a bad word embedding: ellen
# a bad word embedding: starving
# a bad word embedding: aspects
# a bad word embedding: around
# a bad word embedding: sonic
# a bad word embedding: myself
# a bad word embedding: drake
# a bad word embedding: bresnan
# a bad word embedding: retract
# a bad word embedding: dari
# a bad word embedding: traffic
# a bad word embedding: preference
# a bad word embedding: mgmt
# a bad word embedding: libs
# a bad word embedding: world
# a bad word embedding: dare
# a bad word embedding: sensational
# a bad word embedding: intel
# a bad word embedding: extremely
# a bad word embedding: share
# a bad word embedding: pole
# a bad word embedding: yourself
# a bad word embedding: rachael
# a bad word embedding: achievement
# a bad word embedding: clay
# a bad word embedding: beverly
# a bad word embedding: pundits
# a bad word embedding: tart
# a bad word embedding: agreed
# a bad word embedding: brite
# a bad word embedding: perry
# a bad word embedding: fives
# a bad word embedding: india
# a bad word embedding: khaled
# a bad word embedding: lebanon
# a bad word embedding: tvs
# a bad word embedding: seriously
# a bad word embedding: elements
# a bad word embedding: strobist
# a bad word embedding: brits
# a bad word embedding: divine
# a bad word embedding: thinks
# a bad word embedding: boxers
# a bad word embedding: scandals
# a bad word embedding: noob
# a bad word embedding: ddr
# a bad word embedding: tube
# a bad word embedding: ;]
# a bad word embedding: nook
# a bad word embedding: korver
# a bad word embedding: exit
# a bad word embedding: effort
# a bad word embedding: biased
# a bad word embedding: squabble
# a bad word embedding: transformers
# a bad word embedding: tcot
# a bad word embedding: disinformation
# a bad word embedding: sephora
# a bad word embedding: thumbs-up
# a bad word embedding: cash
# a bad word embedding: shoujo
# a bad word embedding: leadership
# a bad word embedding: curious
# a bad word embedding: lucia
# a bad word embedding: miss
# a bad word embedding: lock
# a bad word embedding: stone
# a bad word embedding: ace
# a bad word embedding: industry
# a bad word embedding: favorite
# a bad word embedding: side
# a bad word embedding: act
# a bad word embedding: message
# a bad word embedding: mean
# a bad word embedding: skew
# a bad word embedding: notwinning
# a bad word embedding: buuren
# a bad word embedding: her
# a bad word embedding: no
# a bad word embedding: headsets
# a bad word embedding: image
# a bad word embedding: qro
# a bad word embedding: paint
# a bad word embedding: gaddafi
# a bad word embedding: homeless
# a bad word embedding: parties
# a bad word embedding: nh
# a bad word embedding: subscriber
# a bad word embedding: her
# a bad word embedding: hes
# a bad word embedding: na
# a bad word embedding: transexual
# a bad word embedding: housewives
# a bad word embedding: sides
# a bad word embedding: hee
# a bad word embedding: nz
# a bad word embedding: mindless
# a bad word embedding: hea
# a bad word embedding: ringwald
# a bad word embedding: brazilian
# a bad word embedding: np
# a bad word embedding: bubble
# a bad word embedding: lang
# a bad word embedding: complete
# a bad word embedding: yayy
# a bad word embedding: arrogance
# a bad word embedding: harry
# a bad word embedding: lampoons
# a bad word embedding: with
# a bad word embedding: kai
# a bad word embedding: buying
# a bad word embedding: handsome
# a bad word embedding: pull
# a bad word embedding: rush
# a bad word embedding: october
# a bad word embedding: marni
# a bad word embedding: monopoly
# a bad word embedding: house
# a bad word embedding: tripe
# a bad word embedding: unveils
# a bad word embedding: taught
# a bad word embedding: -------------
# a bad word embedding: dirty
# a bad word embedding: politically
# a bad word embedding: obsession
# a bad word embedding: agree
# a bad word embedding: detailed
# a bad word embedding: e'er
# a bad word embedding: ab
# a bad word embedding: ohh
# a bad word embedding: ad
# a bad word embedding: ai
# a bad word embedding: ah
# a bad word embedding: walkn
# a bad word embedding: stealing
# a bad word embedding: am
# a bad word embedding: al
# a bad word embedding: watches
# a bad word embedding: how
# a bad word embedding: as
# a bad word embedding: ar
# a bad word embedding: au
# a bad word embedding: at
# ...
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W0117 00:08:27.134771 140549804296064 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0117 00:08:27.142986 140549804296064 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0117 00:08:27.159714 140549804296064 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From at_lstm.py:213: calling reduce_max_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# W0117 00:08:27.188444 140549804296064 deprecation.py:506] From at_lstm.py:213: calling reduce_max_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From at_lstm.py:218: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# W0117 00:08:27.197238 140549804296064 deprecation.py:506] From at_lstm.py:218: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From at_lstm.py:230: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# W0117 00:08:27.220478 140549804296064 module_wrapper.py:139] From at_lstm.py:230: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From at_lstm.py:230: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0117 00:08:27.220768 140549804296064 module_wrapper.py:139] From at_lstm.py:230: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From at_lstm.py:232: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0117 00:08:27.221529 140549804296064 module_wrapper.py:139] From at_lstm.py:232: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From at_lstm.py:236: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0117 00:08:27.232327 140549804296064 module_wrapper.py:139] From at_lstm.py:236: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From at_lstm.py:246: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0117 00:08:27.907702 140549804296064 module_wrapper.py:139] From at_lstm.py:246: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-01-17 00:08:27.909437: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-17 00:08:27.982328: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 00:08:27.982969: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-01-17 00:08:28.001887: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-17 00:08:28.272554: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-01-17 00:08:28.412349: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-01-17 00:08:28.441757: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-01-17 00:08:28.702823: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-01-17 00:08:28.730944: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-01-17 00:08:29.278245: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-01-17 00:08:29.278500: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 00:08:29.279282: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 00:08:29.279848: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-01-17 00:08:29.315030: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-01-17 00:08:29.315439: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x165b100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-01-17 00:08:29.315496: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-01-17 00:08:29.452640: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 00:08:29.453418: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x165b2c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-01-17 00:08:29.453450: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-01-17 00:08:29.454737: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 00:08:29.455344: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-01-17 00:08:29.455427: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-17 00:08:29.455453: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-01-17 00:08:29.455477: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-01-17 00:08:29.455498: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-01-17 00:08:29.455526: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-01-17 00:08:29.455551: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-01-17 00:08:29.455574: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-01-17 00:08:29.455696: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 00:08:29.456353: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 00:08:29.456905: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-01-17 00:08:29.460740: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-17 00:08:29.462158: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-01-17 00:08:29.462216: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-01-17 00:08:29.462234: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-01-17 00:08:29.463438: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 00:08:29.464120: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 00:08:29.464726: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-01-17 00:08:29.464773: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From at_lstm.py:258: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0117 00:08:29.465872 140549804296064 module_wrapper.py:139] From at_lstm.py:258: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From at_lstm.py:260: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W0117 00:08:29.468713 140549804296064 module_wrapper.py:139] From at_lstm.py:260: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From at_lstm.py:266: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# W0117 00:08:29.470560 140549804296064 module_wrapper.py:139] From at_lstm.py:266: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From at_lstm.py:270: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0117 00:08:36.094600 140549804296064 module_wrapper.py:139] From at_lstm.py:270: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From at_lstm.py:270: The name tf.train.SaverDef is deprecated. Please use tf.compat.v1.train.SaverDef instead.
#
# W0117 00:08:36.094919 140549804296064 module_wrapper.py:139] From at_lstm.py:270: The name tf.train.SaverDef is deprecated. Please use tf.compat.v1.train.SaverDef instead.
#
# WARNING:tensorflow:From at_lstm.py:272: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# W0117 00:08:36.130015 140549804296064 module_wrapper.py:139] From at_lstm.py:272: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# load word-to-id done!
# load aspect-to-id done!
# cnt= 147113
# Counter({'3': 41234, '1': 38385, '2': 26954, '4': 21710, '0': 18830})
# load word-to-id done!
# load aspect-to-id done!
# cnt= 38165
# Counter({'1': 11031, '3': 9153, '4': 6708, '2': 6643, '0': 4630})
# 2020-01-17 00:08:53.425167: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# all samples=38165, correct prediction=12287.0
# Iter 0: mini-batch loss=0.504523, test acc=0.321944
# all samples=38165, correct prediction=12095.0
# Iter 1: mini-batch loss=0.498955, test acc=0.316913
# all samples=38165, correct prediction=12399.0
# Iter 2: mini-batch loss=0.601737, test acc=0.324879
# all samples=38165, correct prediction=12214.0
# Iter 3: mini-batch loss=0.538606, test acc=0.320031
# all samples=38165, correct prediction=12306.0
# Iter 4: mini-batch loss=0.527008, test acc=0.322442
# all samples=38165, correct prediction=12360.0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# W0117 00:51:30.630621 140549804296064 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Iter 5: mini-batch loss=0.591923, test acc=0.323857
# all samples=38165, correct prediction=11799.0
# Iter 6: mini-batch loss=0.620121, test acc=0.309158
# all samples=38165, correct prediction=12441.0
# Iter 7: mini-batch loss=0.604738, test acc=0.325979
# all samples=38165, correct prediction=11986.0
# Iter 8: mini-batch loss=0.617225, test acc=0.314057
# all samples=38165, correct prediction=12175.0
# Iter 9: mini-batch loss=0.591003, test acc=0.319010
# all samples=38165, correct prediction=12454.0
# Iter 10: mini-batch loss=0.665333, test acc=0.326320
# all samples=38165, correct prediction=11966.0
# Iter 11: mini-batch loss=0.692390, test acc=0.313533
# all samples=38165, correct prediction=12081.0
# Iter 12: mini-batch loss=0.570296, test acc=0.316547
# all samples=38165, correct prediction=12230.0
# Iter 13: mini-batch loss=0.578661, test acc=0.320451
# all samples=38165, correct prediction=11848.0
# Iter 14: mini-batch loss=0.662570, test acc=0.310442
# all samples=38165, correct prediction=11738.0
# Iter 15: mini-batch loss=0.630470, test acc=0.307559
# all samples=38165, correct prediction=12345.0
# Iter 16: mini-batch loss=0.615354, test acc=0.323464
# all samples=38165, correct prediction=12274.0
# Iter 17: mini-batch loss=0.580410, test acc=0.321604
# all samples=38165, correct prediction=12302.0
# Iter 18: mini-batch loss=0.580251, test acc=0.322337
# all samples=38165, correct prediction=12400.0
# Iter 19: mini-batch loss=0.589938, test acc=0.324905
# Optimization Finished! Max acc=0.32631992663435083
# Learning_rate=0.01, iter_num=20, batch_size=25, hidden_num=300, l2=0.001

# %%
# AEAT SST1
# %cd /content/TD-LSTM
# !python at_lstm.py --train_file_path='../tmp/train.raw' --validate_file_path='../tmp/validate.raw' --test_file_path='../tmp/test.raw' --embedding_file_path='../tmp/twitter_word_embedding_partial_200.txt' --word_id_file_path='../tmp/word_id.txt' --aspect_id_file_path='../tmp/aspect_id.txt' --method='AE' --n_class=5
# Out:
# /content/TD-LSTM
# WARNING:tensorflow:From at_lstm.py:376: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
#
# load word-id mapping done!
#
# a bad word embedding: jojo
# a bad word embedding: raining
# a bad word embedding: borderline
# a bad word embedding: yellow
# a bad word embedding: keno
# a bad word embedding: four
# a bad word embedding: gag
# a bad word embedding: woods
# a bad word embedding: olympics
# a bad word embedding: spiders
# a bad word embedding: verses
# a bad word embedding: hanging
# a bad word embedding: until
# a bad word embedding: marching
# a bad word embedding: foundation
# a bad word embedding: twittercrush
# a bad word embedding: extrapolate
# a bad word embedding: archuleta
# a bad word embedding: gnews
# a bad word embedding: lord
# a bad word embedding: sinking
# a bad word embedding: muthafuckin
# a bad word embedding: differently
# a bad word embedding: hdtv
# a bad word embedding: fur
# a bad word embedding: bringing
# a bad word embedding: pants
# a bad word embedding: welp
# a bad word embedding: engga
# a bad word embedding: prize
# a bad word embedding: less
# a bad word embedding: wooden
# a bad word embedding: classic
# a bad word embedding: voyeur
# a bad word embedding: wednesday
# a bad word embedding: oooo
# a bad word embedding: solid
# a bad word embedding: does
# a bad word embedding: crotch
# a bad word embedding: gizmodo
# a bad word embedding: oooh
# a bad word embedding: multilateral
# a bad word embedding: provided
# a bad word embedding: paul
# a bad word embedding: straight
# a bad word embedding: playlist
# a bad word embedding: figured
# a bad word embedding: specially
# a bad word embedding: tired
# a bad word embedding: nigg
# a bad word embedding: perch
# a bad word embedding: pulse
# a bad word embedding: byron
# a bad word embedding: tires
# a bad word embedding: matthew
# a bad word embedding: second
# a bad word embedding: hockey
# a bad word embedding: hootsuite
# a bad word embedding: spambot
# a bad word embedding: newsrooms
# a bad word embedding: mason
# a bad word embedding: bet
# a bad word embedding: errors
# a bad word embedding: relieving
# a bad word embedding: reopens
# a bad word embedding: cooking
# a bad word embedding: fingers
# a bad word embedding: wrong
# a bad word embedding: hamilton
# a bad word embedding: ko
# a bad word embedding: designing
# a bad word embedding: increasing
# a bad word embedding: presidential
# a bad word embedding: pressed
# a bad word embedding: dort
# a bad word embedding: neville
# a bad word embedding: hero
# a bad word embedding: reporter
# a bad word embedding: aja
# a bad word embedding: hera
# a bad word embedding: interrupting
# a bad word embedding: budget
# a bad word embedding: here
# a bad word embedding: trustworthy
# a bad word embedding: reported
# a bad word embedding: presidency
# a bad word embedding: hers
# a bad word embedding: daht
# a bad word embedding: dork
# a bad word embedding: darkness
# a bad word embedding: kids
# a bad word embedding: downfall
# a bad word embedding: miss
# a bad word embedding: reports
# a bad word embedding: controversy
# a bad word embedding: lg
# a bad word embedding: transfixed
# a bad word embedding: not
# a bad word embedding: military
# a bad word embedding: now
# a bad word embedding: nope
# a bad word embedding: gambhir
# a bad word embedding: criticism
# a bad word embedding: compared
# a bad word embedding: smdh
# a bad word embedding: owed
# a bad word embedding: harvey
# a bad word embedding: explained
# a bad word embedding: three
# a bad word embedding: replace
# a bad word embedding: brought
# a bad word embedding: shoddy
# a bad word embedding: skater
# a bad word embedding: stern
# a bad word embedding: pee
# a bad word embedding: cocaine
# a bad word embedding: unit
# a bad word embedding: mote
# a bad word embedding: casey
# a bad word embedding: sexual
# a bad word embedding: brittani
# a bad word embedding: spoke
# a bad word embedding: catchy
# a bad word embedding: dnt
# a bad word embedding: melanie
# a bad word embedding: music
# a bad word embedding: therefore
# a bad word embedding: strike
# a bad word embedding: musik
# a bad word embedding: until
# a bad word embedding: brighton
# a bad word embedding: hu
# a bad word embedding: playboy
# a bad word embedding: holy
# a bad word embedding: relax
# a bad word embedding: successful
# a bad word embedding: brings
# a bad word embedding: hypocritical
# a bad word embedding: poppers
# a bad word embedding: hurt
# a bad word embedding: hole
# a bad word embedding: hold
# a bad word embedding: locked
# a bad word embedding: vou
# a bad word embedding: text
# a bad word embedding: accomplishment
# a bad word embedding: ending
# a bad word embedding: luna
# a bad word embedding: inget
# a bad word embedding: battlefront
# a bad word embedding: sweeter
# a bad word embedding: example
# a bad word embedding: grimes
# a bad word embedding: duke
# a bad word embedding: le
# a bad word embedding: wang
# a bad word embedding: ends
# a bad word embedding: reality
# a bad word embedding: currency
# a bad word embedding: kiss
# a bad word embedding: reviewing
# a bad word embedding: want
# a bad word embedding: peanuts
# a bad word embedding: dyke
# a bad word embedding: rescue
# a bad word embedding: preferably
# a bad word embedding: hoe
# a bad word embedding: lb
# a bad word embedding: la
# a bad word embedding: complaining
# a bad word embedding: hoo
# a bad word embedding: travel
# a bad word embedding: attention
# a bad word embedding: damage
# a bad word embedding: killing
# a bad word embedding: machine
# a bad word embedding: how
# a bad word embedding: hot
# a bad word embedding: elmo
# a bad word embedding: phils
# a bad word embedding: lp
# a bad word embedding: stock
# a bad word embedding: preferable
# a bad word embedding: wolfram
# a bad word embedding: a
# a bad word embedding: gaming
# a bad word embedding: oritse
# a bad word embedding: beauty
# a bad word embedding: dressed
# a bad word embedding: dell
# a bad word embedding: wrong
# a bad word embedding: hear
# a bad word embedding: reese
# a bad word embedding: high-profile
# a bad word embedding: chorus
# a bad word embedding: balads
# a bad word embedding: outcry
# a bad word embedding: hoping
# a bad word embedding: wins
# a bad word embedding: tumblr
# a bad word embedding: gimmie
# a bad word embedding: season
# a bad word embedding: wink
# a bad word embedding: another
# a bad word embedding: keeps
# a bad word embedding: boice
# a bad word embedding: wind
# a bad word embedding: wine
# a bad word embedding: __
# a bad word embedding: blind
# a bad word embedding: feedback
# a bad word embedding: telecom
# a bad word embedding: govern
# a bad word embedding: sylvester
# a bad word embedding: bubbles
# a bad word embedding: butcher
# a bad word embedding: mañana
# a bad word embedding: dispatch
# a bad word embedding: true
# a bad word embedding: told
# a bad word embedding: hip
# a bad word embedding: gossip
# a bad word embedding: his
# a bad word embedding: fit
# a bad word embedding: wire
# a bad word embedding: screaming
# a bad word embedding: fix
# a bad word embedding: rescued
# a bad word embedding: harris
# a bad word embedding: spurs
# a bad word embedding: fin
# a bad word embedding: easier
# a bad word embedding: aguilera
# a bad word embedding: glorify
# a bad word embedding: blowjobs
# a bad word embedding: lambert
# a bad word embedding: slate
# a bad word embedding: keri
# a bad word embedding: seth
# a bad word embedding: hahahahahahah
# a bad word embedding: zac
# a bad word embedding: yonni
# a bad word embedding: effects
# a bad word embedding: velcro
# a bad word embedding: schools
# a bad word embedding: angelinajolie
# a bad word embedding: sixteen
# a bad word embedding: mereçe
# a bad word embedding: represents
# a bad word embedding: debut
# a bad word embedding: dumps
# a bad word embedding: shame
# a bad word embedding: self-titled
# a bad word embedding: addicted
# a bad word embedding: loeb
# a bad word embedding: herta
# a bad word embedding: curse
# a bad word embedding: financial
# a bad word embedding: snakes
# a bad word embedding: woes
# a bad word embedding: series
# a bad word embedding: lamesauce
# a bad word embedding: science
# a bad word embedding: donald
# a bad word embedding: efron
# a bad word embedding: woei
# a bad word embedding: hollywood
# a bad word embedding: whip
# a bad word embedding: rt
# a bad word embedding: rv
# a bad word embedding: trending
# a bad word embedding: maksim
# a bad word embedding: oprah
# a bad word embedding: dst
# a bad word embedding: blitzer
# a bad word embedding: dsi
# a bad word embedding: size
# a bad word embedding: super
# a bad word embedding: foundation
# a bad word embedding: word
# a bad word embedding: written
# a bad word embedding: media
# a bad word embedding: university
# a bad word embedding: work
# a bad word embedding: threatened
# a bad word embedding: corrects
# a bad word embedding: gameplay
# a bad word embedding: debuting
# a bad word embedding: ate
# a bad word embedding: shelves
# a bad word embedding: atm
# a bad word embedding: chan
# a bad word embedding: devastation
# a bad word embedding: commented
# a bad word embedding: shipped
# a bad word embedding: levels
# a bad word embedding: human
# a bad word embedding: chaz
# a bad word embedding: yester
# a bad word embedding: crossings
# a bad word embedding: obituary
# a bad word embedding: trillion
# a bad word embedding: dun
# a bad word embedding: duo
# a bad word embedding: disfigured
# a bad word embedding: goggle
# a bad word embedding: please
# a bad word embedding: brian
# a bad word embedding: lauter
# a bad word embedding: customization
# a bad word embedding: politics
# a bad word embedding: sex
# a bad word embedding: singh
# a bad word embedding: website
# a bad word embedding: basketball
# a bad word embedding: backlinks
# a bad word embedding: service
# a bad word embedding: lego
# a bad word embedding: effect
# a bad word embedding: needed
# a bad word embedding: simmons
# a bad word embedding: master
# a bad word embedding: listed
# a bad word embedding: worlds
# a bad word embedding: invasion
# a bad word embedding: legs
# a bad word embedding: bitter
# a bad word embedding: listen
# a bad word embedding: yay
# a bad word embedding: grown-up
# a bad word embedding: lucunya
# a bad word embedding: named
# a bad word embedding: wisdom
# a bad word embedding: nirvana
# a bad word embedding: date
# a bad word embedding: predictable
# a bad word embedding: victory
# a bad word embedding: legally
# a bad word embedding: suck
# a bad word embedding: positively
# a bad word embedding: spotifylink
# a bad word embedding: beautiful
# a bad word embedding: trek
# a bad word embedding: code
# a bad word embedding: showed
# a bad word embedding: elegant
# a bad word embedding: coward
# a bad word embedding: tree
# a bad word embedding: likely
# a bad word embedding: nations
# a bad word embedding: project
# a bad word embedding: pioneer
# a bad word embedding: sheen
# a bad word embedding: hahaha
# a bad word embedding: feeling
# a bad word embedding: lebron
# a bad word embedding: cody
# a bad word embedding: chicago
# a bad word embedding: runner
# a bad word embedding: boston
# a bad word embedding: aapl
# a bad word embedding: esto
# a bad word embedding: spectrum
# a bad word embedding: angela
# a bad word embedding: son
# a bad word embedding: angels
# a bad word embedding: williams
# a bad word embedding: then
# a bad word embedding: them
# a bad word embedding: kidnap
# a bad word embedding: britney
# a bad word embedding: ast
# a bad word embedding: ginuwine
# a bad word embedding: band
# a bad word embedding: recommended
# a bad word embedding: causing
# a bad word embedding: amusing
# a bad word embedding: they
# a bad word embedding: brains
# a bad word embedding: ask
# a bad word embedding: jones
# a bad word embedding: haunting
# a bad word embedding: shall
# a bad word embedding: thrilled
# a bad word embedding: screwing
# a bad word embedding: object
# a bad word embedding: cinematic
# a bad word embedding: victoria
# a bad word embedding: kelly
# a bad word embedding: mouth
# a bad word embedding: addict
# a bad word embedding: letter
# a bad word embedding: entry
# a bad word embedding: retaining
# a bad word embedding: macbook
# a bad word embedding: thriller
# a bad word embedding: typical
# a bad word embedding: singer
# a bad word embedding: africa
# a bad word embedding: episode
# a bad word embedding: hispanic
# a bad word embedding: camp
# a bad word embedding: bullock
# a bad word embedding: coloquem
# a bad word embedding: drunks
# a bad word embedding: tech
# a bad word embedding: lisbon
# a bad word embedding: scream
# a bad word embedding: came
# a bad word embedding: saying
# a bad word embedding: bomb
# a bad word embedding: reactor
# a bad word embedding: dédié
# a bad word embedding: flunking
# a bad word embedding: meetings
# a bad word embedding: agency
# a bad word embedding: curls
# a bad word embedding: nominated
# a bad word embedding: rediscovery
# a bad word embedding: tehran
# a bad word embedding: daryl
# a bad word embedding: congressional
# a bad word embedding: vindictive
# a bad word embedding: lessons
# a bad word embedding: orleans
# a bad word embedding: busy
# a bad word embedding: rca
# a bad word embedding: shuffling
# a bad word embedding: headline
# a bad word embedding: menu
# a bad word embedding: boleh
# a bad word embedding: bust
# a bad word embedding: rihanna
# a bad word embedding: theme
# a bad word embedding: rick
# a bad word embedding: rich
# a bad word embedding: snitch
# a bad word embedding: mrs.
# a bad word embedding: yo
# a bad word embedding: goper
# a bad word embedding: btw
# a bad word embedding: psychiatric
# a bad word embedding: ldn
# a bad word embedding: pocket
# a bad word embedding: x
# a bad word embedding: thingys
# a bad word embedding: net
# a bad word embedding: nicely
# a bad word embedding: jovana
# a bad word embedding: armin
# a bad word embedding: rio
# a bad word embedding: openly
# a bad word embedding: sean
# a bad word embedding: piggy
# a bad word embedding: release
# a bad word embedding: clearly
# a bad word embedding: pada
# a bad word embedding: dmb
# a bad word embedding: disaster
# a bad word embedding: fair
# a bad word embedding: deemed
# a bad word embedding: levant
# a bad word embedding: goodnight
# a bad word embedding: dms
# a bad word embedding: result
# a bad word embedding: fail
# a bad word embedding: logging
# a bad word embedding: android
# a bad word embedding: john
# a bad word embedding: hammer
# a bad word embedding: best
# a bad word embedding: karate
# a bad word embedding: cobra
# a bad word embedding: moron
# a bad word embedding: risk
# a bad word embedding: manson
# a bad word embedding: glass
# a bad word embedding: lots
# a bad word embedding: rise
# a bad word embedding: rings
# a bad word embedding: upgraded
# a bad word embedding: lott
# a bad word embedding: stamps
# a bad word embedding: dms
# a bad word embedding: cage
# a bad word embedding: ire
# a bad word embedding: lamar
# a bad word embedding: never
# a bad word embedding: parallels
# a bad word embedding: omnivore
# a bad word embedding: lindsey
# a bad word embedding: wtf
# a bad word embedding: wth
# a bad word embedding: perverts
# a bad word embedding: jlo
# a bad word embedding: debt
# a bad word embedding: capello
# a bad word embedding: pity
# a bad word embedding: veronica
# a bad word embedding: accident
# a bad word embedding: mixtape
# a bad word embedding: country
# a bad word embedding: adapter
# a bad word embedding: psa
# a bad word embedding: sanja
# a bad word embedding: adventures
# a bad word embedding: demanded
# a bad word embedding: playful
# a bad word embedding: tekin
# a bad word embedding: geweldig
# a bad word embedding: planned
# a bad word embedding: hated
# a bad word embedding: als
# a bad word embedding: login
# a bad word embedding: argue
# a bad word embedding: asked
# a bad word embedding: and
# a bad word embedding: mortified
# a bad word embedding: apartment
# a bad word embedding: twenty-three
# a bad word embedding: closet
# a bad word embedding: vail
# a bad word embedding: vaio
# a bad word embedding: blonds
# a bad word embedding: cult
# a bad word embedding: telegraph
# a bad word embedding: pregnancy
# a bad word embedding: blonde
# a bad word embedding: method
# a bad word embedding: saturday
# a bad word embedding: americus
# a bad word embedding: blocks
# a bad word embedding: angel
# a bad word embedding: fromtwitter
# a bad word embedding: source
# a bad word embedding: chrome
# a bad word embedding: activa
# a bad word embedding: fri
# a bad word embedding: fro
# a bad word embedding: .
# a bad word embedding: bothers
# a bad word embedding: much
# a bad word embedding: dont
# a bad word embedding: privilege
# a bad word embedding: reggie
# a bad word embedding: fry
# a bad word embedding: gladly
# a bad word embedding: tomato
# a bad word embedding: life
# a bad word embedding: crying
# a bad word embedding: poland
# a bad word embedding: worker
# a bad word embedding: moldova
# a bad word embedding: dave
# a bad word embedding: lift
# a bad word embedding: child
# a bad word embedding: easton
# a bad word embedding: stepdad
# a bad word embedding: haters
# a bad word embedding: spin
# a bad word embedding: chill
# a bad word embedding: holmes
# a bad word embedding: commerce
# a bad word embedding: simplifies
# a bad word embedding: presidency
# a bad word embedding: ada
# a bad word embedding: vexed
# a bad word embedding: castro
# a bad word embedding: hippocratic
# a bad word embedding: starstruck
# a bad word embedding: goaly
# a bad word embedding: event
# a bad word embedding: spoof
# a bad word embedding: surprises
# a bad word embedding: played
# a bad word embedding: ditching
# a bad word embedding: vacation
# a bad word embedding: lol
# a bad word embedding: conditioned
# a bad word embedding: player
# a bad word embedding: courtney
# a bad word embedding: madonna
# a bad word embedding: sells
# a bad word embedding: trusted
# a bad word embedding: undue
# a bad word embedding: hong
# a bad word embedding: recover
# a bad word embedding: taped
# a bad word embedding: python
# a bad word embedding: things
# a bad word embedding: oh
# a bad word embedding: backed
# a bad word embedding: patient
# a bad word embedding: split
# a bad word embedding: babies
# a bad word embedding: electro
# a bad word embedding: fairly
# a bad word embedding: runs
# a bad word embedding: biggie
# a bad word embedding: maybe
# a bad word embedding: keyshia
# a bad word embedding: jungle
# a bad word embedding: tops
# a bad word embedding: workforce
# a bad word embedding: tuna
# a bad word embedding: truths
# a bad word embedding: haggard
# a bad word embedding: tune
# a bad word embedding: nuanced
# a bad word embedding: nat'l
# a bad word embedding: blowjob
# a bad word embedding: academic
# a bad word embedding: corporate
# a bad word embedding: fittest
# a bad word embedding: opinions
# a bad word embedding: thank
# a bad word embedding: sleeps
# a bad word embedding: that
# a bad word embedding: sleepy
# a bad word embedding: sid
# a bad word embedding: allday
# a bad word embedding: meester
# a bad word embedding: censoring
# a bad word embedding: rushing
# a bad word embedding: succeeding
# a bad word embedding: happy
# a bad word embedding: hah
# a bad word embedding: blame
# a bad word embedding: hal
# a bad word embedding: offer
# a bad word embedding: marieclaire
# a bad word embedding: ease
# a bad word embedding: had
# a bad word embedding: hag
# a bad word embedding: bnk
# a bad word embedding: haz
# a bad word embedding: surely
# a bad word embedding: richie
# a bad word embedding: easy
# a bad word embedding: prison
# a bad word embedding: har
# a bad word embedding: has
# a bad word embedding: hat
# a bad word embedding: wide
# a bad word embedding: survival
# a bad word embedding: credit
# a bad word embedding: posed
# a bad word embedding: possible
# a bad word embedding: twinks
# a bad word embedding: revolver
# a bad word embedding: possibly
# a bad word embedding: yeh
# a bad word embedding: kiss
# a bad word embedding: distortion
# a bad word embedding: shadow
# a bad word embedding: unique
# a bad word embedding: usually
# a bad word embedding: stylist
# a bad word embedding: desire
# a bad word embedding: stooopid
# a bad word embedding: ang
# a bad word embedding: oh
# a bad word embedding: kust
# a bad word embedding: remind
# a bad word embedding: aristotle
# a bad word embedding: steven
# a bad word embedding: sebastian
# a bad word embedding: oooooooooh
# a bad word embedding: swedish
# a bad word embedding: ola
# a bad word embedding: attorney
# a bad word embedding: right
# a bad word embedding: old
# a bad word embedding: creek
# a bad word embedding: people
# a bad word embedding: idiot
# a bad word embedding: creed
# a bad word embedding: crown
# a bad word embedding: topping
# a bad word embedding: olo
# a bad word embedding: arquette
# a bad word embedding: gon
# a bad word embedding: insistence
# a bad word embedding: billboard
# a bad word embedding: prick
# a bad word embedding: fuuuuck
# a bad word embedding: creep
# a bad word embedding: gasps
# a bad word embedding: ruffled
# a bad word embedding: for
# a bad word embedding: bottom
# a bad word embedding: res
# a bad word embedding: fox
# a bad word embedding: creative
# a bad word embedding: witty
# a bad word embedding: foe
# a bad word embedding: fog
# a bad word embedding: facebook
# a bad word embedding: foc
# a bad word embedding: umm
# a bad word embedding: keith
# a bad word embedding: celebration
# a bad word embedding: pinched
# a bad word embedding: instant
# a bad word embedding: annan
# a bad word embedding: calls
# a bad word embedding: lightsabers
# a bad word embedding: trampoline
# a bad word embedding: dng
# a bad word embedding: thing
# a bad word embedding: shifting
# a bad word embedding: starring
# a bad word embedding: stylish
# a bad word embedding: losing
# a bad word embedding: memorable
# a bad word embedding: jelena
# a bad word embedding: think
# a bad word embedding: first
# a bad word embedding: amber
# a bad word embedding: spektor
# a bad word embedding: nowplaying
# a bad word embedding: dollars
# a bad word embedding: citizens
# a bad word embedding: entrants
# a bad word embedding: o
# a bad word embedding: valentine
# a bad word embedding: schue
# a bad word embedding: stoked
# a bad word embedding: meddle
# a bad word embedding: sooo
# a bad word embedding: happens
# a bad word embedding: raised
# a bad word embedding: statements
# a bad word embedding: logo
# a bad word embedding: marshall
# a bad word embedding: honeymoon
# a bad word embedding: som
# a bad word embedding: son
# a bad word embedding: thankful
# a bad word embedding: aaron
# a bad word embedding: magazines
# a bad word embedding: latina
# a bad word embedding: globalgrind
# a bad word embedding: adhd
# a bad word embedding: soy
# a bad word embedding: shoots
# a bad word embedding: discography
# a bad word embedding: fey
# a bad word embedding: novo
# a bad word embedding: ends
# a bad word embedding: novi
# a bad word embedding: waits
# a bad word embedding: support
# a bad word embedding: halle
# a bad word embedding: hang
# a bad word embedding: avail
# a bad word embedding: absolutely
# a bad word embedding: jank
# a bad word embedding: spring
# a bad word embedding: awful
# a bad word embedding: tweeps
# a bad word embedding: marge
# a bad word embedding: happy
# a bad word embedding: manufacturers
# a bad word embedding: fascination
# a bad word embedding: eer
# a bad word embedding: publicized
# a bad word embedding: fresh
# a bad word embedding: handjob
# a bad word embedding: upgrades
# a bad word embedding: seeing
# a bad word embedding: congratulations
# a bad word embedding: humbled
# a bad word embedding: minaj
# a bad word embedding: inside
# a bad word embedding: islands
# a bad word embedding: trash
# a bad word embedding: devices
# a bad word embedding: cale
# a bad word embedding: considered
# a bad word embedding: vanguard
# a bad word embedding: tony
# a bad word embedding: palm
# a bad word embedding: duet
# a bad word embedding: panels
# a bad word embedding: cuddles
# a bad word embedding: disgrace
# a bad word embedding: minaj
# a bad word embedding: steady
# a bad word embedding: six
# a bad word embedding: josh
# a bad word embedding: christina
# a bad word embedding: proven
# a bad word embedding: ''
# a bad word embedding: virgin
# a bad word embedding: proves
# a bad word embedding: exist
# a bad word embedding: portrayed
# a bad word embedding: dealer
# a bad word embedding: woooow
# a bad word embedding: francisco
# a bad word embedding: floor
# a bad word embedding: feat
# a bad word embedding: mayo
# a bad word embedding: actor
# a bad word embedding: ourselves
# a bad word embedding: flood
# a bad word embedding: role
# a bad word embedding: woke
# a bad word embedding: hurr
# a bad word embedding: developers
# a bad word embedding: smell
# a bad word embedding: roll
# a bad word embedding: re-watched
# a bad word embedding: cracks
# a bad word embedding: 's
# a bad word embedding: palms
# a bad word embedding: lenny
# a bad word embedding: meghan
# a bad word embedding: center
# a bad word embedding: snowe
# a bad word embedding: 'd
# a bad word embedding: idk
# a bad word embedding: miranda
# a bad word embedding: rolling
# a bad word embedding: 'n
# a bad word embedding: 'm
# a bad word embedding: chrisette
# a bad word embedding: jewelry
# a bad word embedding: 's
# a bad word embedding: euroland
# a bad word embedding: contacts
# a bad word embedding: ottawa
# a bad word embedding: montag
# a bad word embedding: bitchmode
# a bad word embedding: time
# a bad word embedding: push
# a bad word embedding: tunes
# a bad word embedding: empire
# a bad word embedding: inc
# a bad word embedding: gown
# a bad word embedding: japan
# a bad word embedding: whoever
# a bad word embedding: real-estate
# a bad word embedding: nicklaus
# a bad word embedding: plumb
# a bad word embedding: hawaii
# a bad word embedding: disappears
# a bad word embedding: chair
# a bad word embedding: bye
# a bad word embedding: imacs
# a bad word embedding: ward
# a bad word embedding: ver
# a bad word embedding: struggle
# a bad word embedding: sneakers
# a bad word embedding: tourism
# a bad word embedding: eliminate
# a bad word embedding: recipient
# a bad word embedding: logos
# a bad word embedding: downloading
# a bad word embedding: prize
# a bad word embedding: jerk
# a bad word embedding: everytime
# a bad word embedding: saldana
# a bad word embedding: consolidation
# a bad word embedding: olympus
# a bad word embedding: choice
# a bad word embedding: nothing
# a bad word embedding: laurie
# a bad word embedding: rechargable
# a bad word embedding: minute
# a bad word embedding: rand
# a bad word embedding: cooks
# a bad word embedding: doggy
# a bad word embedding: micah
# a bad word embedding: hahah
# a bad word embedding: ludacris
# a bad word embedding: tax
# a bad word embedding: invade
# a bad word embedding: leave
# a bad word embedding: :]
# a bad word embedding: katrina
# a bad word embedding: dnc
# a bad word embedding: team
# a bad word embedding: warren
# a bad word embedding: loads
# a bad word embedding: shooters
# a bad word embedding: kevin
# a bad word embedding: prevent
# a bad word embedding: droid
# a bad word embedding: o.o
# a bad word embedding: sigh
# a bad word embedding: sign
# a bad word embedding: utility
# a bad word embedding: failed
# a bad word embedding: erotic
# a bad word embedding: mega
# a bad word embedding: designs
# a bad word embedding: shirts
# a bad word embedding: reaffirmed
# a bad word embedding: ➲
# a bad word embedding: brady
# a bad word embedding: threesomes
# a bad word embedding: jeopardy
# a bad word embedding: celebrated
# a bad word embedding: realizing
# a bad word embedding: melt
# a bad word embedding: maine
# a bad word embedding: current
# a bad word embedding: freaks
# a bad word embedding: ➜
# a bad word embedding: locket
# a bad word embedding: falling
# a bad word embedding: celebrates
# a bad word embedding: lopez
# a bad word embedding: me
# a bad word embedding: creepiest
# a bad word embedding: dates
# a bad word embedding: ma
# a bad word embedding: niche
# a bad word embedding: africa
# a bad word embedding: rachel
# a bad word embedding: understanding
# a bad word embedding: sharing
# a bad word embedding: mr
# a bad word embedding: alone
# a bad word embedding: along
# a bad word embedding: my
# a bad word embedding: warner
# a bad word embedding: assassinating
# a bad word embedding: neville
# a bad word embedding: butt-naked
# a bad word embedding: toyboy
# a bad word embedding: redemption
# a bad word embedding: dusty
# a bad word embedding: woop
# a bad word embedding: wherever
# a bad word embedding: mj
# a bad word embedding: blog
# a bad word embedding: born
# a bad word embedding: ineffective
# a bad word embedding: myers
# a bad word embedding: my
# a bad word embedding: mx
# a bad word embedding: reclaim
# a bad word embedding: real
# a bad word embedding: love
# a bad word embedding: policies
# a bad word embedding: lactating
# a bad word embedding: defend
# a bad word embedding: prefer
# a bad word embedding: dog
# a bad word embedding: bloody
# a bad word embedding: fakers
# a bad word embedding: fake
# a bad word embedding: carol
# a bad word embedding: ecuador
# a bad word embedding: himym
# a bad word embedding: working
# a bad word embedding: may
# a bad word embedding: positive
# a bad word embedding: angry
# a bad word embedding: nationalize
# a bad word embedding: hello
# a bad word embedding: sisterly
# a bad word embedding: wondering
# a bad word embedding: films
# a bad word embedding: heroics
# a bad word embedding: softball
# a bad word embedding: bodies
# a bad word embedding: loving
# a bad word embedding: scratched
# a bad word embedding: ``
# a bad word embedding: leeches
# a bad word embedding: clitoris
# a bad word embedding: apparent
# a bad word embedding: refrain
# a bad word embedding: consoles
# a bad word embedding: goods
# a bad word embedding: everywhere
# a bad word embedding: icon
# a bad word embedding: rythme
# a bad word embedding: behalf
# a bad word embedding: suckah
# a bad word embedding: logos
# a bad word embedding: deserved
# a bad word embedding: originally
# a bad word embedding: pretend
# a bad word embedding: magnificent
# a bad word embedding: birkin
# a bad word embedding: believer
# a bad word embedding: believes
# a bad word embedding: nether
# a bad word embedding: inciter
# a bad word embedding: values
# a bad word embedding: phoebe
# a bad word embedding: goody
# a bad word embedding: following
# a bad word embedding: our
# a bad word embedding: marsden
# a bad word embedding: slightly
# a bad word embedding: pur
# a bad word embedding: out
# a bad word embedding: hermoine
# a bad word embedding: awesome
# a bad word embedding: stipulation
# a bad word embedding: bad
# a bad word embedding: ter
# a bad word embedding: allowed
# a bad word embedding: offense
# a bad word embedding: kemacetan
# a bad word embedding: juli
# a bad word embedding: stole
# a bad word embedding: piazza
# a bad word embedding: winter
# a bad word embedding: cobain
# a bad word embedding: gambino
# a bad word embedding: who
# a bad word embedding: poking
# a bad word embedding: cloak
# a bad word embedding: caged
# a bad word embedding: homii
# a bad word embedding: why
# a bad word embedding: snaps
# a bad word embedding: jazz
# a bad word embedding: laundry
# a bad word embedding: explorer
# a bad word embedding: meets
# a bad word embedding: blogtv
# a bad word embedding: punk
# a bad word embedding: blasting
# a bad word embedding: spot
# a bad word embedding: dats
# a bad word embedding: applications
# a bad word embedding: snape
# a bad word embedding: co-writing
# a bad word embedding: date
# a bad word embedding: such
# a bad word embedding: suck
# a bad word embedding: data
# a bad word embedding: shockingly
# a bad word embedding: moly
# a bad word embedding: surfing
# a bad word embedding: natural
# a bad word embedding: vogel
# a bad word embedding: stomping
# a bad word embedding: wheelchair
# a bad word embedding: sw
# a bad word embedding: st
# a bad word embedding: si
# a bad word embedding: sh
# a bad word embedding: so
# a bad word embedding: haterade
# a bad word embedding: swollen
# a bad word embedding: kanye
# a bad word embedding: sa
# a bad word embedding: katie
# a bad word embedding: pulled
# a bad word embedding: se
# a bad word embedding: sd
# a bad word embedding: drunken
# a bad word embedding: lie
# a bad word embedding: imogen
# a bad word embedding: barnes
# a bad word embedding: morissette
# a bad word embedding: years
# a bad word embedding: rihanna
# a bad word embedding: course
# a bad word embedding: episodes
# a bad word embedding: kanye
# a bad word embedding: stills
# a bad word embedding: abduzeedo
# a bad word embedding: hip-hop
# a bad word embedding: splurge
# a bad word embedding: overhaul
# a bad word embedding: thumb
# a bad word embedding: couric
# a bad word embedding: muses
# a bad word embedding: tori
# a bad word embedding: stupidity
# a bad word embedding: faves
# a bad word embedding: attraction
# a bad word embedding: suspicion
# a bad word embedding: whitney
# a bad word embedding: troubled
# a bad word embedding: visiting
# a bad word embedding: petition
# a bad word embedding: sate
# a bad word embedding: buck
# a bad word embedding: sister
# a bad word embedding: unlove
# a bad word embedding: hop
# a bad word embedding: matches
# a bad word embedding: smarter
# a bad word embedding: nation
# a bad word embedding: fr
# a bad word embedding: records
# a bad word embedding: strauss
# a bad word embedding: arriving
# a bad word embedding: sorted
# a bad word embedding: twilight
# a bad word embedding: \
# a bad word embedding: maintaining
# a bad word embedding: osama
# a bad word embedding: newest
# a bad word embedding: apologizes
# a bad word embedding: succeeds
# a bad word embedding: wish
# a bad word embedding: yellow
# a bad word embedding: pete
# a bad word embedding: fucking
# a bad word embedding: grants
# a bad word embedding: bowling
# a bad word embedding: stanley
# a bad word embedding: amnesty
# a bad word embedding: argies
# a bad word embedding: repaired
# a bad word embedding: ooomg
# a bad word embedding: louboutin
# a bad word embedding: square
# a bad word embedding: honduras
# a bad word embedding: mexico
# a bad word embedding: couples
# a bad word embedding: breakthrough
# a bad word embedding: live
# a bad word embedding: entering
# a bad word embedding: cole
# a bad word embedding: ergh
# a bad word embedding: troll
# a bad word embedding: joker
# a bad word embedding: demolition
# a bad word embedding: joy
# a bad word embedding: welcome
# a bad word embedding: job
# a bad word embedding: exploding
# a bad word embedding: joe
# a bad word embedding: squares
# a bad word embedding: bla
# a bad word embedding: jon
# a bad word embedding: smalls
# a bad word embedding: dodgers
# a bad word embedding: thank
# a bad word embedding: hairdresser
# a bad word embedding: million
# a bad word embedding: seventh
# a bad word embedding: magical
# a bad word embedding: governing
# a bad word embedding: quite
# a bad word embedding: disrespect
# a bad word embedding: complicated
# a bad word embedding: crazier
# a bad word embedding: besides
# a bad word embedding: mixed
# a bad word embedding: poems
# a bad word embedding: ___
# a bad word embedding: training
# a bad word embedding: dunno
# a bad word embedding: punk
# a bad word embedding: initiate
# a bad word embedding: whiplash
# a bad word embedding: puns
# a bad word embedding: massive
# a bad word embedding: bargain
# a bad word embedding: router
# a bad word embedding: brazil
# a bad word embedding: intuition
# a bad word embedding: saving
# a bad word embedding: baybay
# a bad word embedding: gasp
# a bad word embedding: petulant
# a bad word embedding: royal
# a bad word embedding: one
# a bad word embedding: behave
# a bad word embedding: spanish
# a bad word embedding: vote
# a bad word embedding: open
# a bad word embedding: ripping
# a bad word embedding: exaggerations
# a bad word embedding: city
# a bad word embedding: chums
# a bad word embedding: wrath
# a bad word embedding: monday
# a bad word embedding: structured
# a bad word embedding: rule
# a bad word embedding: hmm
# a bad word embedding: homosexuality
# a bad word embedding: draft
# a bad word embedding: types
# a bad word embedding: stuffed
# a bad word embedding: typing
# a bad word embedding: hype
# a bad word embedding: uses
# a bad word embedding: repeal
# a bad word embedding: violated
# a bad word embedding: williams
# a bad word embedding: patrick
# a bad word embedding: proving
# a bad word embedding: ridiculous
# a bad word embedding: korean
# a bad word embedding: bombs
# a bad word embedding: smoking
# a bad word embedding: fooled
# a bad word embedding: kurt
# a bad word embedding: boyfriend
# a bad word embedding: bored
# a bad word embedding: earmuffs
# a bad word embedding: dickhead
# a bad word embedding: depressed
# a bad word embedding: rival
# a bad word embedding: folly
# a bad word embedding: sensation
# a bad word embedding: crossroads
# a bad word embedding: fun
# a bad word embedding: rehab
# a bad word embedding: rochelle
# a bad word embedding: future
# a bad word embedding: fills
# a bad word embedding: surprisingly
# a bad word embedding: pwahaha
# a bad word embedding: damned
# a bad word embedding: prospect
# a bad word embedding: fly
# a bad word embedding: addressing
# a bad word embedding: illness
# a bad word embedding: nicer
# a bad word embedding: overcooked
# a bad word embedding: turned
# a bad word embedding: argument
# a bad word embedding: alley
# a bad word embedding: sad
# a bad word embedding: prestigious
# a bad word embedding: say
# a bad word embedding: buried
# a bad word embedding: hilarious
# a bad word embedding: allen
# a bad word embedding: regards
# a bad word embedding: e-book
# a bad word embedding: opened
# a bad word embedding: both
# a bad word embedding: presid
# a bad word embedding: zoe
# a bad word embedding: babysit
# a bad word embedding: alicia
# a bad word embedding: aside
# a bad word embedding: note
# a bad word embedding: omfg
# a bad word embedding: take
# a bad word embedding: half
# a bad word embedding: destroy
# a bad word embedding: mayer
# a bad word embedding: hall
# a bad word embedding: ironically
# a bad word embedding: printer
# a bad word embedding: altered
# a bad word embedding: opposite
# a bad word embedding: buffer
# a bad word embedding: knew
# a bad word embedding: kerr
# a bad word embedding: times
# a bad word embedding: wong
# a bad word embedding: abus
# a bad word embedding: keri
# a bad word embedding: remarks
# a bad word embedding: knee
# a bad word embedding: hoped
# a bad word embedding: pages
# a bad word embedding: trainer
# a bad word embedding: democratic
# a bad word embedding: cher
# a bad word embedding: phil
# a bad word embedding: drive
# a bad word embedding: moose
# a bad word embedding: federal
# a bad word embedding: antarctica
# a bad word embedding: strip
# a bad word embedding: ♪
# a bad word embedding: flashback
# a bad word embedding: blue
# a bad word embedding: walking
# a bad word embedding: olha
# a bad word embedding: supplements
# a bad word embedding: opportunist
# a bad word embedding: virgos
# a bad word embedding: sky
# a bad word embedding: tohoku
# a bad word embedding: boyz
# a bad word embedding: roland
# a bad word embedding: hornby
# a bad word embedding: aggressive
# a bad word embedding: wants
# a bad word embedding: smfh
# a bad word embedding: slow
# a bad word embedding: motherhood
# a bad word embedding: sacramento
# a bad word embedding: deck
# a bad word embedding: cinco
# a bad word embedding: tears
# a bad word embedding: going
# a bad word embedding: hockey
# a bad word embedding: outrage
# a bad word embedding: ✔
# a bad word embedding: congressional
# a bad word embedding: bryant
# a bad word embedding: trivia
# a bad word embedding: predict
# a bad word embedding: beatles
# a bad word embedding: hallows
# a bad word embedding: freezing
# a bad word embedding: cursing
# a bad word embedding: magazine
# a bad word embedding: products
# a bad word embedding: crossed
# a bad word embedding: having
# a bad word embedding: prime
# a bad word embedding: resource
# a bad word embedding: clipe
# a bad word embedding: artist
# a bad word embedding: jeff
# a bad word embedding: borrow
# a bad word embedding: awwwww
# a bad word embedding: worried
# a bad word embedding: manchester
# a bad word embedding: bombs
# a bad word embedding: worries
# a bad word embedding: yes
# a bad word embedding: where
# a bad word embedding: vision
# a bad word embedding: lindsaylohan
# a bad word embedding: cio
# a bad word embedding: diluted
# a bad word embedding: gangster
# a bad word embedding: anyways
# a bad word embedding: fellas
# a bad word embedding: surgery
# a bad word embedding: enjoying
# a bad word embedding: into
# a bad word embedding: rages
# a bad word embedding: britt
# a bad word embedding: church
# a bad word embedding: brave
# a bad word embedding: that
# a bad word embedding: jumped
# a bad word embedding: sites
# a bad word embedding: wisdom
# a bad word embedding: teeny
# a bad word embedding: books
# a bad word embedding: jonas
# a bad word embedding: teens
# a bad word embedding: than
# a bad word embedding: jumper
# a bad word embedding: bible
# a bad word embedding: jobs
# a bad word embedding: uk
# a bad word embedding: klown
# a bad word embedding: screen
# a bad word embedding: planes
# a bad word embedding: dome
# a bad word embedding: supermarket
# a bad word embedding: awards
# a bad word embedding: dslrs
# a bad word embedding: spark
# a bad word embedding: undermine
# a bad word embedding: tried
# a bad word embedding: www
# a bad word embedding: rant
# a bad word embedding: lice
# a bad word embedding: many
# a bad word embedding: manz
# a bad word embedding: millionaire
# a bad word embedding: flipped
# a bad word embedding: mana
# a bad word embedding: s
# a bad word embedding: loudly
# a bad word embedding: crooked
# a bad word embedding: expression
# a bad word embedding: guts
# a bad word embedding: syria
# a bad word embedding: timberlake
# a bad word embedding: team
# a bad word embedding: yankovic
# a bad word embedding: fsm
# a bad word embedding: mccain
# a bad word embedding: comparing
# a bad word embedding: twin
# a bad word embedding: appeaser
# a bad word embedding: comeback
# a bad word embedding: sentinel
# a bad word embedding: considers
# a bad word embedding: boat
# a bad word embedding: math
# a bad word embedding: caring
# a bad word embedding: myles
# a bad word embedding: armstrong
# a bad word embedding: fic
# a bad word embedding: stretch
# a bad word embedding: west
# a bad word embedding: flash
# a bad word embedding: breath
# a bad word embedding: combined
# a bad word embedding: nessas
# a bad word embedding: reflex
# a bad word embedding: princess
# a bad word embedding: hilarity
# a bad word embedding: shine
# a bad word embedding: wants
# a bad word embedding: detach
# a bad word embedding: whenever
# a bad word embedding: marc
# a bad word embedding: antivirus
# a bad word embedding: turtleneck
# a bad word embedding: muchlove
# a bad word embedding: greatest
# a bad word embedding: fleshy
# a bad word embedding: former
# a bad word embedding: fireflies
# a bad word embedding: jazeera
# a bad word embedding: run
# a bad word embedding: libya
# a bad word embedding: consultant
# a bad word embedding: polls
# a bad word embedding: outside
# a bad word embedding: ransom
# a bad word embedding: him
# a bad word embedding: doctrine
# a bad word embedding: situation
# a bad word embedding: album
# a bad word embedding: ive
# a bad word embedding: feel
# a bad word embedding: die
# a bad word embedding: purse
# a bad word embedding: dubious
# a bad word embedding: quiet
# a bad word embedding: looking
# a bad word embedding: blah
# a bad word embedding: useless
# a bad word embedding: prez
# a bad word embedding: pharoah
# a bad word embedding: grievous
# a bad word embedding: month
# a bad word embedding: technology
# a bad word embedding: fame
# a bad word embedding: pres
# a bad word embedding: len
# a bad word embedding: binary
# a bad word embedding: missiles
# a bad word embedding: verified
# a bad word embedding: rooting
# a bad word embedding: nationalism
# a bad word embedding: lovers
# a bad word embedding: yessir
# a bad word embedding: damon
# a bad word embedding: through
# a bad word embedding: bloom
# a bad word embedding: workout
# a bad word embedding: homophobic
# a bad word embedding: jailbreaking
# a bad word embedding: breakdown
# a bad word embedding: wires
# a bad word embedding: sickness
# a bad word embedding: i
# a bad word embedding: rotflmao
# a bad word embedding: rfid
# a bad word embedding: cheers
# a bad word embedding: cullen
# a bad word embedding: wired
# a bad word embedding: deff
# a bad word embedding: clean
# a bad word embedding: %
# a bad word embedding: taskbar
# a bad word embedding: own
# a bad word embedding: says
# a bad word embedding: behaved
# a bad word embedding: owe
# a bad word embedding: know
# a bad word embedding: may
# a bad word embedding: costs
# a bad word embedding: tutorial
# a bad word embedding: scholarship
# a bad word embedding: summer
# a bad word embedding: hbo
# a bad word embedding: sprayed
# a bad word embedding: predicting
# a bad word embedding: being
# a bad word embedding: rest
# a bad word embedding: conservative
# a bad word embedding: cards
# a bad word embedding: daniel
# a bad word embedding: verdad
# a bad word embedding: summed
# a bad word embedding: jeremy
# a bad word embedding: weekly
# a bad word embedding: segal
# a bad word embedding: kirk
# a bad word embedding: approves
# a bad word embedding: characterization
# a bad word embedding: nyanyi
# a bad word embedding: travolta
# a bad word embedding: crank
# a bad word embedding: overthrow
# a bad word embedding: coded
# a bad word embedding: vibrating
# a bad word embedding: pfsh
# a bad word embedding: travel
# a bad word embedding: roller
# a bad word embedding: ellen
# a bad word embedding: starving
# a bad word embedding: aspects
# a bad word embedding: around
# a bad word embedding: sonic
# a bad word embedding: myself
# a bad word embedding: drake
# a bad word embedding: bresnan
# a bad word embedding: retract
# a bad word embedding: dari
# a bad word embedding: traffic
# a bad word embedding: preference
# a bad word embedding: mgmt
# a bad word embedding: libs
# a bad word embedding: world
# a bad word embedding: dare
# a bad word embedding: sensational
# a bad word embedding: intel
# a bad word embedding: extremely
# a bad word embedding: share
# a bad word embedding: pole
# a bad word embedding: yourself
# a bad word embedding: rachael
# a bad word embedding: achievement
# a bad word embedding: clay
# a bad word embedding: beverly
# a bad word embedding: pundits
# a bad word embedding: tart
# a bad word embedding: agreed
# a bad word embedding: brite
# a bad word embedding: perry
# a bad word embedding: fives
# a bad word embedding: india
# a bad word embedding: khaled
# a bad word embedding: lebanon
# a bad word embedding: tvs
# a bad word embedding: seriously
# a bad word embedding: elements
# a bad word embedding: strobist
# a bad word embedding: brits
# a bad word embedding: divine
# a bad word embedding: thinks
# a bad word embedding: boxers
# a bad word embedding: scandals
# a bad word embedding: noob
# a bad word embedding: ddr
# a bad word embedding: tube
# a bad word embedding: ;]
# a bad word embedding: nook
# a bad word embedding: korver
# a bad word embedding: exit
# a bad word embedding: effort
# a bad word embedding: biased
# a bad word embedding: squabble
# a bad word embedding: transformers
# a bad word embedding: tcot
# a bad word embedding: disinformation
# a bad word embedding: sephora
# a bad word embedding: thumbs-up
# a bad word embedding: cash
# a bad word embedding: shoujo
# a bad word embedding: leadership
# a bad word embedding: curious
# a bad word embedding: lucia
# a bad word embedding: miss
# a bad word embedding: lock
# a bad word embedding: stone
# a bad word embedding: ace
# a bad word embedding: industry
# a bad word embedding: favorite
# a bad word embedding: side
# a bad word embedding: act
# a bad word embedding: message
# a bad word embedding: mean
# a bad word embedding: skew
# a bad word embedding: notwinning
# a bad word embedding: buuren
# a bad word embedding: her
# a bad word embedding: no
# a bad word embedding: headsets
# a bad word embedding: image
# a bad word embedding: qro
# a bad word embedding: paint
# a bad word embedding: gaddafi
# a bad word embedding: homeless
# a bad word embedding: parties
# a bad word embedding: nh
# a bad word embedding: subscriber
# a bad word embedding: her
# a bad word embedding: hes
# a bad word embedding: na
# a bad word embedding: transexual
# a bad word embedding: housewives
# a bad word embedding: sides
# a bad word embedding: hee
# a bad word embedding: nz
# a bad word embedding: mindless
# a bad word embedding: hea
# a bad word embedding: ringwald
# a bad word embedding: brazilian
# a bad word embedding: np
# a bad word embedding: bubble
# a bad word embedding: lang
# a bad word embedding: complete
# a bad word embedding: yayy
# a bad word embedding: arrogance
# a bad word embedding: harry
# a bad word embedding: lampoons
# a bad word embedding: with
# a bad word embedding: kai
# a bad word embedding: buying
# a bad word embedding: handsome
# a bad word embedding: pull
# a bad word embedding: rush
# a bad word embedding: october
# a bad word embedding: marni
# a bad word embedding: monopoly
# a bad word embedding: house
# a bad word embedding: tripe
# a bad word embedding: unveils
# a bad word embedding: taught
# a bad word embedding: -------------
# a bad word embedding: dirty
# a bad word embedding: politically
# a bad word embedding: obsession
# a bad word embedding: agree
# a bad word embedding: detailed
# a bad word embedding: e'er
# a bad word embedding: ab
# a bad word embedding: ohh
# a bad word embedding: ad
# a bad word embedding: ai
# a bad word embedding: ah
# a bad word embedding: walkn
# a bad word embedding: stealing
# a bad word embedding: am
# a bad word embedding: al
# a bad word embedding: watches
# a bad word embedding: how
# a bad word embedding: as
# a bad word embedding: ar
# a bad word embedding: au
# a bad word embedding: at
# ...
#
# WARNING:tensorflow:From at_lstm.py:68: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0117 08:45:07.576144 139868490356608 module_wrapper.py:139] From at_lstm.py:68: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0117 08:45:07.576477 139868490356608 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# I0117 08:45:08.020478 139868490356608 utils.py:141] NumExpr defaulting to 2 threads.
# I am AE.
# WARNING:tensorflow:From at_lstm.py:160: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0117 08:45:08.567953 139868490356608 deprecation.py:506] From at_lstm.py:160: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From at_lstm.py:113: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W0117 08:45:08.576731 139868490356608 deprecation.py:323] From at_lstm.py:113: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From at_lstm.py:117: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# W0117 08:45:08.577988 139868490356608 deprecation.py:323] From at_lstm.py:117: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W0117 08:45:08.654161 139868490356608 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0117 08:45:08.660269 139868490356608 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0117 08:45:08.673630 139868490356608 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From at_lstm.py:230: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# W0117 08:45:08.706640 139868490356608 module_wrapper.py:139] From at_lstm.py:230: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From at_lstm.py:230: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0117 08:45:08.706808 139868490356608 module_wrapper.py:139] From at_lstm.py:230: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From at_lstm.py:232: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0117 08:45:08.707426 139868490356608 module_wrapper.py:139] From at_lstm.py:232: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From at_lstm.py:236: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0117 08:45:08.716487 139868490356608 module_wrapper.py:139] From at_lstm.py:236: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From at_lstm.py:246: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0117 08:45:09.209484 139868490356608 module_wrapper.py:139] From at_lstm.py:246: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-01-17 08:45:09.210948: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-17 08:45:09.270051: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 08:45:09.270734: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-01-17 08:45:09.283989: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-17 08:45:09.535193: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-01-17 08:45:09.669849: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-01-17 08:45:09.693387: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-01-17 08:45:09.953922: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-01-17 08:45:09.987008: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-01-17 08:45:10.485412: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-01-17 08:45:10.485680: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 08:45:10.486330: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 08:45:10.486867: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-01-17 08:45:10.500334: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-01-17 08:45:10.500994: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2ec5100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-01-17 08:45:10.501029: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-01-17 08:45:10.628114: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 08:45:10.628801: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2ec52c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-01-17 08:45:10.628832: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-01-17 08:45:10.629648: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 08:45:10.630168: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-01-17 08:45:10.630236: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-17 08:45:10.630262: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-01-17 08:45:10.630283: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-01-17 08:45:10.630306: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-01-17 08:45:10.630325: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-01-17 08:45:10.630343: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-01-17 08:45:10.630361: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-01-17 08:45:10.630475: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 08:45:10.631065: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 08:45:10.631596: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-01-17 08:45:10.635356: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-17 08:45:10.636725: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-01-17 08:45:10.636752: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-01-17 08:45:10.636762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-01-17 08:45:10.638833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 08:45:10.639460: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-17 08:45:10.640012: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-01-17 08:45:10.640053: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From at_lstm.py:258: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0117 08:45:10.640880 139868490356608 module_wrapper.py:139] From at_lstm.py:258: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From at_lstm.py:260: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W0117 08:45:10.643260 139868490356608 module_wrapper.py:139] From at_lstm.py:260: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From at_lstm.py:266: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# W0117 08:45:10.644834 139868490356608 module_wrapper.py:139] From at_lstm.py:266: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From at_lstm.py:270: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0117 08:45:16.456650 139868490356608 module_wrapper.py:139] From at_lstm.py:270: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From at_lstm.py:270: The name tf.train.SaverDef is deprecated. Please use tf.compat.v1.train.SaverDef instead.
#
# W0117 08:45:17.037111 139868490356608 module_wrapper.py:139] From at_lstm.py:270: The name tf.train.SaverDef is deprecated. Please use tf.compat.v1.train.SaverDef instead.
#
# WARNING:tensorflow:From at_lstm.py:272: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# W0117 08:45:17.069564 139868490356608 module_wrapper.py:139] From at_lstm.py:272: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# load word-to-id done!
# load aspect-to-id done!
# cnt= 147113
# Counter({'3': 41234, '1': 38385, '2': 26954, '4': 21710, '0': 18830})
# load word-to-id done!
# load aspect-to-id done!
# cnt= 38165
# Counter({'1': 11031, '3': 9153, '4': 6708, '2': 6643, '0': 4630})
# 2020-01-17 08:45:34.707757: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# Traceback (most recent call last):
#   File "at_lstm.py", line 376, in <module>
#     tf.app.run()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 299, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 250, in _run_main
#     sys.exit(main(argv))
#   File "at_lstm.py", line 372, in main
#     lstm.run()
#   File "at_lstm.py", line 311, in run
#     _loss, _acc, _summary, _step, alpha, ty, py = sess.run([cost, accuracy, validate_summary_op, global_step, self.alpha, true_y, pred_y],
# AttributeError: 'LSTM' object has no attribute 'alpha'

# %%
# AT SST2
# %cd /content/TD-LSTM
# !python at_lstm.py --train_file_path='../tmp/train.raw' --validate_file_path='../tmp/validate.raw' --test_file_path='../tmp/test.raw' --embedding_file_path='../tmp/twitter_word_embedding_partial_200.txt' --word_id_file_path='../tmp/word_id.txt' --aspect_id_file_path='../tmp/aspect_id.txt' --method='AT' --n_class=2
# Out:
# /content/TD-LSTM
# WARNING:tensorflow:From at_lstm.py:376: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
#
# load word-id mapping done!
#
# a bad word embedding: jojo
# a bad word embedding: raining
# a bad word embedding: borderline
# a bad word embedding: yellow
# a bad word embedding: keno
# a bad word embedding: four
# a bad word embedding: gag
# a bad word embedding: woods
# a bad word embedding: olympics
# a bad word embedding: spiders
# a bad word embedding: verses
# a bad word embedding: hanging
# a bad word embedding: until
# a bad word embedding: marching
# a bad word embedding: foundation
# a bad word embedding: twittercrush
# a bad word embedding: extrapolate
# a bad word embedding: archuleta
# a bad word embedding: gnews
# a bad word embedding: lord
# a bad word embedding: sinking
# a bad word embedding: muthafuckin
# a bad word embedding: differently
# a bad word embedding: hdtv
# a bad word embedding: fur
# a bad word embedding: bringing
# a bad word embedding: pants
# a bad word embedding: welp
# a bad word embedding: engga
# a bad word embedding: prize
# a bad word embedding: less
# a bad word embedding: wooden
# a bad word embedding: classic
# a bad word embedding: voyeur
# a bad word embedding: wednesday
# a bad word embedding: oooo
# a bad word embedding: solid
# a bad word embedding: does
# a bad word embedding: crotch
# a bad word embedding: gizmodo
# a bad word embedding: oooh
# a bad word embedding: multilateral
# a bad word embedding: provided
# a bad word embedding: paul
# a bad word embedding: straight
# a bad word embedding: playlist
# a bad word embedding: figured
# a bad word embedding: specially
# a bad word embedding: tired
# a bad word embedding: nigg
# a bad word embedding: perch
# a bad word embedding: pulse
# a bad word embedding: byron
# a bad word embedding: tires
# a bad word embedding: matthew
# a bad word embedding: second
# a bad word embedding: hockey
# a bad word embedding: hootsuite
# a bad word embedding: spambot
# a bad word embedding: newsrooms
# a bad word embedding: mason
# a bad word embedding: bet
# a bad word embedding: errors
# a bad word embedding: relieving
# a bad word embedding: reopens
# a bad word embedding: cooking
# a bad word embedding: fingers
# a bad word embedding: wrong
# a bad word embedding: hamilton
# a bad word embedding: ko
# a bad word embedding: designing
# a bad word embedding: increasing
# a bad word embedding: presidential
# a bad word embedding: pressed
# a bad word embedding: dort
# a bad word embedding: neville
# a bad word embedding: hero
# a bad word embedding: reporter
# a bad word embedding: aja
# a bad word embedding: hera
# a bad word embedding: interrupting
# a bad word embedding: budget
# a bad word embedding: here
# a bad word embedding: trustworthy
# a bad word embedding: reported
# a bad word embedding: presidency
# a bad word embedding: hers
# a bad word embedding: daht
# a bad word embedding: dork
# a bad word embedding: darkness
# a bad word embedding: kids
# a bad word embedding: downfall
# a bad word embedding: miss
# a bad word embedding: reports
# a bad word embedding: controversy
# a bad word embedding: lg
# a bad word embedding: transfixed
# a bad word embedding: not
# a bad word embedding: military
# a bad word embedding: now
# a bad word embedding: nope
# a bad word embedding: gambhir
# a bad word embedding: criticism
# a bad word embedding: compared
# a bad word embedding: smdh
# a bad word embedding: owed
# a bad word embedding: harvey
# a bad word embedding: explained
# a bad word embedding: three
# a bad word embedding: replace
# a bad word embedding: brought
# a bad word embedding: shoddy
# a bad word embedding: skater
# a bad word embedding: stern
# a bad word embedding: pee
# a bad word embedding: cocaine
# a bad word embedding: unit
# a bad word embedding: mote
# a bad word embedding: casey
# a bad word embedding: sexual
# a bad word embedding: brittani
# a bad word embedding: spoke
# a bad word embedding: catchy
# a bad word embedding: dnt
# a bad word embedding: melanie
# a bad word embedding: music
# a bad word embedding: therefore
# a bad word embedding: strike
# a bad word embedding: musik
# a bad word embedding: until
# a bad word embedding: brighton
# a bad word embedding: hu
# a bad word embedding: playboy
# a bad word embedding: holy
# a bad word embedding: relax
# a bad word embedding: successful
# a bad word embedding: brings
# a bad word embedding: hypocritical
# a bad word embedding: poppers
# a bad word embedding: hurt
# a bad word embedding: hole
# a bad word embedding: hold
# a bad word embedding: locked
# a bad word embedding: vou
# a bad word embedding: text
# a bad word embedding: accomplishment
# a bad word embedding: ending
# a bad word embedding: luna
# a bad word embedding: inget
# a bad word embedding: battlefront
# a bad word embedding: sweeter
# a bad word embedding: example
# a bad word embedding: grimes
# a bad word embedding: duke
# a bad word embedding: le
# a bad word embedding: wang
# a bad word embedding: ends
# a bad word embedding: reality
# a bad word embedding: currency
# a bad word embedding: kiss
# a bad word embedding: reviewing
# a bad word embedding: want
# a bad word embedding: peanuts
# a bad word embedding: dyke
# a bad word embedding: rescue
# a bad word embedding: preferably
# a bad word embedding: hoe
# a bad word embedding: lb
# a bad word embedding: la
# a bad word embedding: complaining
# a bad word embedding: hoo
# a bad word embedding: travel
# a bad word embedding: attention
# a bad word embedding: damage
# a bad word embedding: killing
# a bad word embedding: machine
# a bad word embedding: how
# a bad word embedding: hot
# a bad word embedding: elmo
# a bad word embedding: phils
# a bad word embedding: lp
# a bad word embedding: stock
# a bad word embedding: preferable
# a bad word embedding: wolfram
# a bad word embedding: a
# a bad word embedding: gaming
# a bad word embedding: oritse
# a bad word embedding: beauty
# a bad word embedding: dressed
# a bad word embedding: dell
# a bad word embedding: wrong
# a bad word embedding: hear
# a bad word embedding: reese
# a bad word embedding: high-profile
# a bad word embedding: chorus
# a bad word embedding: balads
# a bad word embedding: outcry
# a bad word embedding: hoping
# a bad word embedding: wins
# a bad word embedding: tumblr
# a bad word embedding: gimmie
# a bad word embedding: season
# a bad word embedding: wink
# a bad word embedding: another
# a bad word embedding: keeps
# a bad word embedding: boice
# a bad word embedding: wind
# a bad word embedding: wine
# a bad word embedding: __
# a bad word embedding: blind
# a bad word embedding: feedback
# a bad word embedding: telecom
# a bad word embedding: govern
# a bad word embedding: sylvester
# a bad word embedding: bubbles
# a bad word embedding: butcher
# a bad word embedding: mañana
# a bad word embedding: dispatch
# a bad word embedding: true
# a bad word embedding: told
# a bad word embedding: hip
# a bad word embedding: gossip
# a bad word embedding: his
# a bad word embedding: fit
# a bad word embedding: wire
# a bad word embedding: screaming
# a bad word embedding: fix
# a bad word embedding: rescued
# a bad word embedding: harris
# a bad word embedding: spurs
# a bad word embedding: fin
# a bad word embedding: easier
# a bad word embedding: aguilera
# a bad word embedding: glorify
# a bad word embedding: blowjobs
# a bad word embedding: lambert
# a bad word embedding: slate
# a bad word embedding: keri
# a bad word embedding: seth
# a bad word embedding: hahahahahahah
# a bad word embedding: zac
# a bad word embedding: yonni
# a bad word embedding: effects
# a bad word embedding: velcro
# a bad word embedding: schools
# a bad word embedding: angelinajolie
# a bad word embedding: sixteen
# a bad word embedding: mereçe
# a bad word embedding: represents
# a bad word embedding: debut
# a bad word embedding: dumps
# a bad word embedding: shame
# a bad word embedding: self-titled
# a bad word embedding: addicted
# a bad word embedding: loeb
# a bad word embedding: herta
# a bad word embedding: curse
# a bad word embedding: financial
# a bad word embedding: snakes
# a bad word embedding: woes
# a bad word embedding: series
# a bad word embedding: lamesauce
# a bad word embedding: science
# a bad word embedding: donald
# a bad word embedding: efron
# a bad word embedding: woei
# a bad word embedding: hollywood
# a bad word embedding: whip
# a bad word embedding: rt
# a bad word embedding: rv
# a bad word embedding: trending
# a bad word embedding: maksim
# a bad word embedding: oprah
# a bad word embedding: dst
# a bad word embedding: blitzer
# a bad word embedding: dsi
# a bad word embedding: size
# a bad word embedding: super
# a bad word embedding: foundation
# a bad word embedding: word
# a bad word embedding: written
# a bad word embedding: media
# a bad word embedding: university
# a bad word embedding: work
# a bad word embedding: threatened
# a bad word embedding: corrects
# a bad word embedding: gameplay
# a bad word embedding: debuting
# a bad word embedding: ate
# a bad word embedding: shelves
# a bad word embedding: atm
# a bad word embedding: chan
# a bad word embedding: devastation
# a bad word embedding: commented
# a bad word embedding: shipped
# a bad word embedding: levels
# a bad word embedding: human
# a bad word embedding: chaz
# a bad word embedding: yester
# a bad word embedding: crossings
# a bad word embedding: obituary
# a bad word embedding: trillion
# a bad word embedding: dun
# a bad word embedding: duo
# a bad word embedding: disfigured
# a bad word embedding: goggle
# a bad word embedding: please
# a bad word embedding: brian
# a bad word embedding: lauter
# a bad word embedding: customization
# a bad word embedding: politics
# a bad word embedding: sex
# a bad word embedding: singh
# a bad word embedding: website
# a bad word embedding: basketball
# a bad word embedding: backlinks
# a bad word embedding: service
# a bad word embedding: lego
# a bad word embedding: effect
# a bad word embedding: needed
# a bad word embedding: simmons
# a bad word embedding: master
# a bad word embedding: listed
# a bad word embedding: worlds
# a bad word embedding: invasion
# a bad word embedding: legs
# a bad word embedding: bitter
# a bad word embedding: listen
# a bad word embedding: yay
# a bad word embedding: grown-up
# a bad word embedding: lucunya
# a bad word embedding: named
# a bad word embedding: wisdom
# a bad word embedding: nirvana
# a bad word embedding: date
# a bad word embedding: predictable
# a bad word embedding: victory
# a bad word embedding: legally
# a bad word embedding: suck
# a bad word embedding: positively
# a bad word embedding: spotifylink
# a bad word embedding: beautiful
# a bad word embedding: trek
# a bad word embedding: code
# a bad word embedding: showed
# a bad word embedding: elegant
# a bad word embedding: coward
# a bad word embedding: tree
# a bad word embedding: likely
# a bad word embedding: nations
# a bad word embedding: project
# a bad word embedding: pioneer
# a bad word embedding: sheen
# a bad word embedding: hahaha
# a bad word embedding: feeling
# a bad word embedding: lebron
# a bad word embedding: cody
# a bad word embedding: chicago
# a bad word embedding: runner
# a bad word embedding: boston
# a bad word embedding: aapl
# a bad word embedding: esto
# a bad word embedding: spectrum
# a bad word embedding: angela
# a bad word embedding: son
# a bad word embedding: angels
# a bad word embedding: williams
# a bad word embedding: then
# a bad word embedding: them
# a bad word embedding: kidnap
# a bad word embedding: britney
# a bad word embedding: ast
# a bad word embedding: ginuwine
# a bad word embedding: band
# a bad word embedding: recommended
# a bad word embedding: causing
# a bad word embedding: amusing
# a bad word embedding: they
# a bad word embedding: brains
# a bad word embedding: ask
# a bad word embedding: jones
# a bad word embedding: haunting
# a bad word embedding: shall
# a bad word embedding: thrilled
# a bad word embedding: screwing
# a bad word embedding: object
# a bad word embedding: cinematic
# a bad word embedding: victoria
# a bad word embedding: kelly
# a bad word embedding: mouth
# a bad word embedding: addict
# a bad word embedding: letter
# a bad word embedding: entry
# a bad word embedding: retaining
# a bad word embedding: macbook
# a bad word embedding: thriller
# a bad word embedding: typical
# a bad word embedding: singer
# a bad word embedding: africa
# a bad word embedding: episode
# a bad word embedding: hispanic
# a bad word embedding: camp
# a bad word embedding: bullock
# a bad word embedding: coloquem
# a bad word embedding: drunks
# a bad word embedding: tech
# a bad word embedding: lisbon
# a bad word embedding: scream
# a bad word embedding: came
# a bad word embedding: saying
# a bad word embedding: bomb
# a bad word embedding: reactor
# a bad word embedding: dédié
# a bad word embedding: flunking
# a bad word embedding: meetings
# a bad word embedding: agency
# a bad word embedding: curls
# a bad word embedding: nominated
# a bad word embedding: rediscovery
# a bad word embedding: tehran
# a bad word embedding: daryl
# a bad word embedding: congressional
# a bad word embedding: vindictive
# a bad word embedding: lessons
# a bad word embedding: orleans
# a bad word embedding: busy
# a bad word embedding: rca
# a bad word embedding: shuffling
# a bad word embedding: headline
# a bad word embedding: menu
# a bad word embedding: boleh
# a bad word embedding: bust
# a bad word embedding: rihanna
# a bad word embedding: theme
# a bad word embedding: rick
# a bad word embedding: rich
# a bad word embedding: snitch
# a bad word embedding: mrs.
# a bad word embedding: yo
# a bad word embedding: goper
# a bad word embedding: btw
# a bad word embedding: psychiatric
# a bad word embedding: ldn
# a bad word embedding: pocket
# a bad word embedding: x
# a bad word embedding: thingys
# a bad word embedding: net
# a bad word embedding: nicely
# a bad word embedding: jovana
# a bad word embedding: armin
# a bad word embedding: rio
# a bad word embedding: openly
# a bad word embedding: sean
# a bad word embedding: piggy
# a bad word embedding: release
# a bad word embedding: clearly
# a bad word embedding: pada
# a bad word embedding: dmb
# a bad word embedding: disaster
# a bad word embedding: fair
# a bad word embedding: deemed
# a bad word embedding: levant
# a bad word embedding: goodnight
# a bad word embedding: dms
# a bad word embedding: result
# a bad word embedding: fail
# a bad word embedding: logging
# a bad word embedding: android
# a bad word embedding: john
# a bad word embedding: hammer
# a bad word embedding: best
# a bad word embedding: karate
# a bad word embedding: cobra
# a bad word embedding: moron
# a bad word embedding: risk
# a bad word embedding: manson
# a bad word embedding: glass
# a bad word embedding: lots
# a bad word embedding: rise
# a bad word embedding: rings
# a bad word embedding: upgraded
# a bad word embedding: lott
# a bad word embedding: stamps
# a bad word embedding: dms
# a bad word embedding: cage
# a bad word embedding: ire
# a bad word embedding: lamar
# a bad word embedding: never
# a bad word embedding: parallels
# a bad word embedding: omnivore
# a bad word embedding: lindsey
# a bad word embedding: wtf
# a bad word embedding: wth
# a bad word embedding: perverts
# a bad word embedding: jlo
# a bad word embedding: debt
# a bad word embedding: capello
# a bad word embedding: pity
# a bad word embedding: veronica
# a bad word embedding: accident
# a bad word embedding: mixtape
# a bad word embedding: country
# a bad word embedding: adapter
# a bad word embedding: psa
# a bad word embedding: sanja
# a bad word embedding: adventures
# a bad word embedding: demanded
# a bad word embedding: playful
# a bad word embedding: tekin
# a bad word embedding: geweldig
# a bad word embedding: planned
# a bad word embedding: hated
# a bad word embedding: als
# a bad word embedding: login
# a bad word embedding: argue
# a bad word embedding: asked
# a bad word embedding: and
# a bad word embedding: mortified
# a bad word embedding: apartment
# a bad word embedding: twenty-three
# a bad word embedding: closet
# a bad word embedding: vail
# a bad word embedding: vaio
# a bad word embedding: blonds
# a bad word embedding: cult
# a bad word embedding: telegraph
# a bad word embedding: pregnancy
# a bad word embedding: blonde
# a bad word embedding: method
# a bad word embedding: saturday
# a bad word embedding: americus
# a bad word embedding: blocks
# a bad word embedding: angel
# a bad word embedding: fromtwitter
# a bad word embedding: source
# a bad word embedding: chrome
# a bad word embedding: activa
# a bad word embedding: fri
# a bad word embedding: fro
# a bad word embedding: .
# a bad word embedding: bothers
# a bad word embedding: much
# a bad word embedding: dont
# a bad word embedding: privilege
# a bad word embedding: reggie
# a bad word embedding: fry
# a bad word embedding: gladly
# a bad word embedding: tomato
# a bad word embedding: life
# a bad word embedding: crying
# a bad word embedding: poland
# a bad word embedding: worker
# a bad word embedding: moldova
# a bad word embedding: dave
# a bad word embedding: lift
# a bad word embedding: child
# a bad word embedding: easton
# a bad word embedding: stepdad
# a bad word embedding: haters
# a bad word embedding: spin
# a bad word embedding: chill
# a bad word embedding: holmes
# a bad word embedding: commerce
# a bad word embedding: simplifies
# a bad word embedding: presidency
# a bad word embedding: ada
# a bad word embedding: vexed
# a bad word embedding: castro
# a bad word embedding: hippocratic
# a bad word embedding: starstruck
# a bad word embedding: goaly
# a bad word embedding: event
# a bad word embedding: spoof
# a bad word embedding: surprises
# a bad word embedding: played
# a bad word embedding: ditching
# a bad word embedding: vacation
# a bad word embedding: lol
# a bad word embedding: conditioned
# a bad word embedding: player
# a bad word embedding: courtney
# a bad word embedding: madonna
# a bad word embedding: sells
# a bad word embedding: trusted
# a bad word embedding: undue
# a bad word embedding: hong
# a bad word embedding: recover
# a bad word embedding: taped
# a bad word embedding: python
# a bad word embedding: things
# a bad word embedding: oh
# a bad word embedding: backed
# a bad word embedding: patient
# a bad word embedding: split
# a bad word embedding: babies
# a bad word embedding: electro
# a bad word embedding: fairly
# a bad word embedding: runs
# a bad word embedding: biggie
# a bad word embedding: maybe
# a bad word embedding: keyshia
# a bad word embedding: jungle
# a bad word embedding: tops
# a bad word embedding: workforce
# a bad word embedding: tuna
# a bad word embedding: truths
# a bad word embedding: haggard
# a bad word embedding: tune
# a bad word embedding: nuanced
# a bad word embedding: nat'l
# a bad word embedding: blowjob
# a bad word embedding: academic
# a bad word embedding: corporate
# a bad word embedding: fittest
# a bad word embedding: opinions
# a bad word embedding: thank
# a bad word embedding: sleeps
# a bad word embedding: that
# a bad word embedding: sleepy
# a bad word embedding: sid
# a bad word embedding: allday
# a bad word embedding: meester
# a bad word embedding: censoring
# a bad word embedding: rushing
# a bad word embedding: succeeding
# a bad word embedding: happy
# a bad word embedding: hah
# a bad word embedding: blame
# a bad word embedding: hal
# a bad word embedding: offer
# a bad word embedding: marieclaire
# a bad word embedding: ease
# a bad word embedding: had
# a bad word embedding: hag
# a bad word embedding: bnk
# a bad word embedding: haz
# a bad word embedding: surely
# a bad word embedding: richie
# a bad word embedding: easy
# a bad word embedding: prison
# a bad word embedding: har
# a bad word embedding: has
# a bad word embedding: hat
# a bad word embedding: wide
# a bad word embedding: survival
# a bad word embedding: credit
# a bad word embedding: posed
# a bad word embedding: possible
# a bad word embedding: twinks
# a bad word embedding: revolver
# a bad word embedding: possibly
# a bad word embedding: yeh
# a bad word embedding: kiss
# a bad word embedding: distortion
# a bad word embedding: shadow
# a bad word embedding: unique
# a bad word embedding: usually
# a bad word embedding: stylist
# a bad word embedding: desire
# a bad word embedding: stooopid
# a bad word embedding: ang
# a bad word embedding: oh
# a bad word embedding: kust
# a bad word embedding: remind
# a bad word embedding: aristotle
# a bad word embedding: steven
# a bad word embedding: sebastian
# a bad word embedding: oooooooooh
# a bad word embedding: swedish
# a bad word embedding: ola
# a bad word embedding: attorney
# a bad word embedding: right
# a bad word embedding: old
# a bad word embedding: creek
# a bad word embedding: people
# a bad word embedding: idiot
# a bad word embedding: creed
# a bad word embedding: crown
# a bad word embedding: topping
# a bad word embedding: olo
# a bad word embedding: arquette
# a bad word embedding: gon
# a bad word embedding: insistence
# a bad word embedding: billboard
# a bad word embedding: prick
# a bad word embedding: fuuuuck
# a bad word embedding: creep
# a bad word embedding: gasps
# a bad word embedding: ruffled
# a bad word embedding: for
# a bad word embedding: bottom
# a bad word embedding: res
# a bad word embedding: fox
# a bad word embedding: creative
# a bad word embedding: witty
# a bad word embedding: foe
# a bad word embedding: fog
# a bad word embedding: facebook
# a bad word embedding: foc
# a bad word embedding: umm
# a bad word embedding: keith
# a bad word embedding: celebration
# a bad word embedding: pinched
# a bad word embedding: instant
# a bad word embedding: annan
# a bad word embedding: calls
# a bad word embedding: lightsabers
# a bad word embedding: trampoline
# a bad word embedding: dng
# a bad word embedding: thing
# a bad word embedding: shifting
# a bad word embedding: starring
# a bad word embedding: stylish
# a bad word embedding: losing
# a bad word embedding: memorable
# a bad word embedding: jelena
# a bad word embedding: think
# a bad word embedding: first
# a bad word embedding: amber
# a bad word embedding: spektor
# a bad word embedding: nowplaying
# a bad word embedding: dollars
# a bad word embedding: citizens
# a bad word embedding: entrants
# a bad word embedding: o
# a bad word embedding: valentine
# a bad word embedding: schue
# a bad word embedding: stoked
# a bad word embedding: meddle
# a bad word embedding: sooo
# a bad word embedding: happens
# a bad word embedding: raised
# a bad word embedding: statements
# a bad word embedding: logo
# a bad word embedding: marshall
# a bad word embedding: honeymoon
# a bad word embedding: som
# a bad word embedding: son
# a bad word embedding: thankful
# a bad word embedding: aaron
# a bad word embedding: magazines
# a bad word embedding: latina
# a bad word embedding: globalgrind
# a bad word embedding: adhd
# a bad word embedding: soy
# a bad word embedding: shoots
# a bad word embedding: discography
# a bad word embedding: fey
# a bad word embedding: novo
# a bad word embedding: ends
# a bad word embedding: novi
# a bad word embedding: waits
# a bad word embedding: support
# a bad word embedding: halle
# a bad word embedding: hang
# a bad word embedding: avail
# a bad word embedding: absolutely
# a bad word embedding: jank
# a bad word embedding: spring
# a bad word embedding: awful
# a bad word embedding: tweeps
# a bad word embedding: marge
# a bad word embedding: happy
# a bad word embedding: manufacturers
# a bad word embedding: fascination
# a bad word embedding: eer
# a bad word embedding: publicized
# a bad word embedding: fresh
# a bad word embedding: handjob
# a bad word embedding: upgrades
# a bad word embedding: seeing
# a bad word embedding: congratulations
# a bad word embedding: humbled
# a bad word embedding: minaj
# a bad word embedding: inside
# a bad word embedding: islands
# a bad word embedding: trash
# a bad word embedding: devices
# a bad word embedding: cale
# a bad word embedding: considered
# a bad word embedding: vanguard
# a bad word embedding: tony
# a bad word embedding: palm
# a bad word embedding: duet
# a bad word embedding: panels
# a bad word embedding: cuddles
# a bad word embedding: disgrace
# a bad word embedding: minaj
# a bad word embedding: steady
# a bad word embedding: six
# a bad word embedding: josh
# a bad word embedding: christina
# a bad word embedding: proven
# a bad word embedding: ''
# a bad word embedding: virgin
# a bad word embedding: proves
# a bad word embedding: exist
# a bad word embedding: portrayed
# a bad word embedding: dealer
# a bad word embedding: woooow
# a bad word embedding: francisco
# a bad word embedding: floor
# a bad word embedding: feat
# a bad word embedding: mayo
# a bad word embedding: actor
# a bad word embedding: ourselves
# a bad word embedding: flood
# a bad word embedding: role
# a bad word embedding: woke
# a bad word embedding: hurr
# a bad word embedding: developers
# a bad word embedding: smell
# a bad word embedding: roll
# a bad word embedding: re-watched
# a bad word embedding: cracks
# a bad word embedding: 's
# a bad word embedding: palms
# a bad word embedding: lenny
# a bad word embedding: meghan
# a bad word embedding: center
# a bad word embedding: snowe
# a bad word embedding: 'd
# a bad word embedding: idk
# a bad word embedding: miranda
# a bad word embedding: rolling
# a bad word embedding: 'n
# a bad word embedding: 'm
# a bad word embedding: chrisette
# a bad word embedding: jewelry
# a bad word embedding: 's
# a bad word embedding: euroland
# a bad word embedding: contacts
# a bad word embedding: ottawa
# a bad word embedding: montag
# a bad word embedding: bitchmode
# a bad word embedding: time
# a bad word embedding: push
# a bad word embedding: tunes
# a bad word embedding: empire
# a bad word embedding: inc
# a bad word embedding: gown
# a bad word embedding: japan
# a bad word embedding: whoever
# a bad word embedding: real-estate
# a bad word embedding: nicklaus
# a bad word embedding: plumb
# a bad word embedding: hawaii
# a bad word embedding: disappears
# a bad word embedding: chair
# a bad word embedding: bye
# a bad word embedding: imacs
# a bad word embedding: ward
# a bad word embedding: ver
# a bad word embedding: struggle
# a bad word embedding: sneakers
# a bad word embedding: tourism
# a bad word embedding: eliminate
# a bad word embedding: recipient
# a bad word embedding: logos
# a bad word embedding: downloading
# a bad word embedding: prize
# a bad word embedding: jerk
# a bad word embedding: everytime
# a bad word embedding: saldana
# a bad word embedding: consolidation
# a bad word embedding: olympus
# a bad word embedding: choice
# a bad word embedding: nothing
# a bad word embedding: laurie
# a bad word embedding: rechargable
# a bad word embedding: minute
# a bad word embedding: rand
# a bad word embedding: cooks
# a bad word embedding: doggy
# a bad word embedding: micah
# a bad word embedding: hahah
# a bad word embedding: ludacris
# a bad word embedding: tax
# a bad word embedding: invade
# a bad word embedding: leave
# a bad word embedding: :]
# a bad word embedding: katrina
# a bad word embedding: dnc
# a bad word embedding: team
# a bad word embedding: warren
# a bad word embedding: loads
# a bad word embedding: shooters
# a bad word embedding: kevin
# a bad word embedding: prevent
# a bad word embedding: droid
# a bad word embedding: o.o
# a bad word embedding: sigh
# a bad word embedding: sign
# a bad word embedding: utility
# a bad word embedding: failed
# a bad word embedding: erotic
# a bad word embedding: mega
# a bad word embedding: designs
# a bad word embedding: shirts
# a bad word embedding: reaffirmed
# a bad word embedding: ➲
# a bad word embedding: brady
# a bad word embedding: threesomes
# a bad word embedding: jeopardy
# a bad word embedding: celebrated
# a bad word embedding: realizing
# a bad word embedding: melt
# a bad word embedding: maine
# a bad word embedding: current
# a bad word embedding: freaks
# a bad word embedding: ➜
# a bad word embedding: locket
# a bad word embedding: falling
# a bad word embedding: celebrates
# a bad word embedding: lopez
# a bad word embedding: me
# a bad word embedding: creepiest
# a bad word embedding: dates
# a bad word embedding: ma
# a bad word embedding: niche
# a bad word embedding: africa
# a bad word embedding: rachel
# a bad word embedding: understanding
# a bad word embedding: sharing
# a bad word embedding: mr
# a bad word embedding: alone
# a bad word embedding: along
# a bad word embedding: my
# a bad word embedding: warner
# a bad word embedding: assassinating
# a bad word embedding: neville
# a bad word embedding: butt-naked
# a bad word embedding: toyboy
# a bad word embedding: redemption
# a bad word embedding: dusty
# a bad word embedding: woop
# a bad word embedding: wherever
# a bad word embedding: mj
# a bad word embedding: blog
# a bad word embedding: born
# a bad word embedding: ineffective
# a bad word embedding: myers
# a bad word embedding: my
# a bad word embedding: mx
# a bad word embedding: reclaim
# a bad word embedding: real
# a bad word embedding: love
# a bad word embedding: policies
# a bad word embedding: lactating
# a bad word embedding: defend
# a bad word embedding: prefer
# a bad word embedding: dog
# a bad word embedding: bloody
# a bad word embedding: fakers
# a bad word embedding: fake
# a bad word embedding: carol
# a bad word embedding: ecuador
# a bad word embedding: himym
# a bad word embedding: working
# a bad word embedding: may
# a bad word embedding: positive
# a bad word embedding: angry
# a bad word embedding: nationalize
# a bad word embedding: hello
# a bad word embedding: sisterly
# a bad word embedding: wondering
# a bad word embedding: films
# a bad word embedding: heroics
# a bad word embedding: softball
# a bad word embedding: bodies
# a bad word embedding: loving
# a bad word embedding: scratched
# a bad word embedding: ``
# a bad word embedding: leeches
# a bad word embedding: clitoris
# a bad word embedding: apparent
# a bad word embedding: refrain
# a bad word embedding: consoles
# a bad word embedding: goods
# a bad word embedding: everywhere
# a bad word embedding: icon
# a bad word embedding: rythme
# a bad word embedding: behalf
# a bad word embedding: suckah
# a bad word embedding: logos
# a bad word embedding: deserved
# a bad word embedding: originally
# a bad word embedding: pretend
# a bad word embedding: magnificent
# a bad word embedding: birkin
# a bad word embedding: believer
# a bad word embedding: believes
# a bad word embedding: nether
# a bad word embedding: inciter
# a bad word embedding: values
# a bad word embedding: phoebe
# a bad word embedding: goody
# a bad word embedding: following
# a bad word embedding: our
# a bad word embedding: marsden
# a bad word embedding: slightly
# a bad word embedding: pur
# a bad word embedding: out
# a bad word embedding: hermoine
# a bad word embedding: awesome
# a bad word embedding: stipulation
# a bad word embedding: bad
# a bad word embedding: ter
# a bad word embedding: allowed
# a bad word embedding: offense
# a bad word embedding: kemacetan
# a bad word embedding: juli
# a bad word embedding: stole
# a bad word embedding: piazza
# a bad word embedding: winter
# a bad word embedding: cobain
# a bad word embedding: gambino
# a bad word embedding: who
# a bad word embedding: poking
# a bad word embedding: cloak
# a bad word embedding: caged
# a bad word embedding: homii
# a bad word embedding: why
# a bad word embedding: snaps
# a bad word embedding: jazz
# a bad word embedding: laundry
# a bad word embedding: explorer
# a bad word embedding: meets
# a bad word embedding: blogtv
# a bad word embedding: punk
# a bad word embedding: blasting
# a bad word embedding: spot
# a bad word embedding: dats
# a bad word embedding: applications
# a bad word embedding: snape
# a bad word embedding: co-writing
# a bad word embedding: date
# a bad word embedding: such
# a bad word embedding: suck
# a bad word embedding: data
# a bad word embedding: shockingly
# a bad word embedding: moly
# a bad word embedding: surfing
# a bad word embedding: natural
# a bad word embedding: vogel
# a bad word embedding: stomping
# a bad word embedding: wheelchair
# a bad word embedding: sw
# a bad word embedding: st
# a bad word embedding: si
# a bad word embedding: sh
# a bad word embedding: so
# a bad word embedding: haterade
# a bad word embedding: swollen
# a bad word embedding: kanye
# a bad word embedding: sa
# a bad word embedding: katie
# a bad word embedding: pulled
# a bad word embedding: se
# a bad word embedding: sd
# a bad word embedding: drunken
# a bad word embedding: lie
# a bad word embedding: imogen
# a bad word embedding: barnes
# a bad word embedding: morissette
# a bad word embedding: years
# a bad word embedding: rihanna
# a bad word embedding: course
# a bad word embedding: episodes
# a bad word embedding: kanye
# a bad word embedding: stills
# a bad word embedding: abduzeedo
# a bad word embedding: hip-hop
# a bad word embedding: splurge
# a bad word embedding: overhaul
# a bad word embedding: thumb
# a bad word embedding: couric
# a bad word embedding: muses
# a bad word embedding: tori
# a bad word embedding: stupidity
# a bad word embedding: faves
# a bad word embedding: attraction
# a bad word embedding: suspicion
# a bad word embedding: whitney
# a bad word embedding: troubled
# a bad word embedding: visiting
# a bad word embedding: petition
# a bad word embedding: sate
# a bad word embedding: buck
# a bad word embedding: sister
# a bad word embedding: unlove
# a bad word embedding: hop
# a bad word embedding: matches
# a bad word embedding: smarter
# a bad word embedding: nation
# a bad word embedding: fr
# a bad word embedding: records
# a bad word embedding: strauss
# a bad word embedding: arriving
# a bad word embedding: sorted
# a bad word embedding: twilight
# a bad word embedding: \
# a bad word embedding: maintaining
# a bad word embedding: osama
# a bad word embedding: newest
# a bad word embedding: apologizes
# a bad word embedding: succeeds
# a bad word embedding: wish
# a bad word embedding: yellow
# a bad word embedding: pete
# a bad word embedding: fucking
# a bad word embedding: grants
# a bad word embedding: bowling
# a bad word embedding: stanley
# a bad word embedding: amnesty
# a bad word embedding: argies
# a bad word embedding: repaired
# a bad word embedding: ooomg
# a bad word embedding: louboutin
# a bad word embedding: square
# a bad word embedding: honduras
# a bad word embedding: mexico
# a bad word embedding: couples
# a bad word embedding: breakthrough
# a bad word embedding: live
# a bad word embedding: entering
# a bad word embedding: cole
# a bad word embedding: ergh
# a bad word embedding: troll
# a bad word embedding: joker
# a bad word embedding: demolition
# a bad word embedding: joy
# a bad word embedding: welcome
# a bad word embedding: job
# a bad word embedding: exploding
# a bad word embedding: joe
# a bad word embedding: squares
# a bad word embedding: bla
# a bad word embedding: jon
# a bad word embedding: smalls
# a bad word embedding: dodgers
# a bad word embedding: thank
# a bad word embedding: hairdresser
# a bad word embedding: million
# a bad word embedding: seventh
# a bad word embedding: magical
# a bad word embedding: governing
# a bad word embedding: quite
# a bad word embedding: disrespect
# a bad word embedding: complicated
# a bad word embedding: crazier
# a bad word embedding: besides
# a bad word embedding: mixed
# a bad word embedding: poems
# a bad word embedding: ___
# a bad word embedding: training
# a bad word embedding: dunno
# a bad word embedding: punk
# a bad word embedding: initiate
# a bad word embedding: whiplash
# a bad word embedding: puns
# a bad word embedding: massive
# a bad word embedding: bargain
# a bad word embedding: router
# a bad word embedding: brazil
# a bad word embedding: intuition
# a bad word embedding: saving
# a bad word embedding: baybay
# a bad word embedding: gasp
# a bad word embedding: petulant
# a bad word embedding: royal
# a bad word embedding: one
# a bad word embedding: behave
# a bad word embedding: spanish
# a bad word embedding: vote
# a bad word embedding: open
# a bad word embedding: ripping
# a bad word embedding: exaggerations
# a bad word embedding: city
# a bad word embedding: chums
# a bad word embedding: wrath
# a bad word embedding: monday
# a bad word embedding: structured
# a bad word embedding: rule
# a bad word embedding: hmm
# a bad word embedding: homosexuality
# a bad word embedding: draft
# a bad word embedding: types
# a bad word embedding: stuffed
# a bad word embedding: typing
# a bad word embedding: hype
# a bad word embedding: uses
# a bad word embedding: repeal
# a bad word embedding: violated
# a bad word embedding: williams
# a bad word embedding: patrick
# a bad word embedding: proving
# a bad word embedding: ridiculous
# a bad word embedding: korean
# a bad word embedding: bombs
# a bad word embedding: smoking
# a bad word embedding: fooled
# a bad word embedding: kurt
# a bad word embedding: boyfriend
# a bad word embedding: bored
# a bad word embedding: earmuffs
# a bad word embedding: dickhead
# a bad word embedding: depressed
# a bad word embedding: rival
# a bad word embedding: folly
# a bad word embedding: sensation
# a bad word embedding: crossroads
# a bad word embedding: fun
# a bad word embedding: rehab
# a bad word embedding: rochelle
# a bad word embedding: future
# a bad word embedding: fills
# a bad word embedding: surprisingly
# a bad word embedding: pwahaha
# a bad word embedding: damned
# a bad word embedding: prospect
# a bad word embedding: fly
# a bad word embedding: addressing
# a bad word embedding: illness
# a bad word embedding: nicer
# a bad word embedding: overcooked
# a bad word embedding: turned
# a bad word embedding: argument
# a bad word embedding: alley
# a bad word embedding: sad
# a bad word embedding: prestigious
# a bad word embedding: say
# a bad word embedding: buried
# a bad word embedding: hilarious
# a bad word embedding: allen
# a bad word embedding: regards
# a bad word embedding: e-book
# a bad word embedding: opened
# a bad word embedding: both
# a bad word embedding: presid
# a bad word embedding: zoe
# a bad word embedding: babysit
# a bad word embedding: alicia
# a bad word embedding: aside
# a bad word embedding: note
# a bad word embedding: omfg
# a bad word embedding: take
# a bad word embedding: half
# a bad word embedding: destroy
# a bad word embedding: mayer
# a bad word embedding: hall
# a bad word embedding: ironically
# a bad word embedding: printer
# a bad word embedding: altered
# a bad word embedding: opposite
# a bad word embedding: buffer
# a bad word embedding: knew
# a bad word embedding: kerr
# a bad word embedding: times
# a bad word embedding: wong
# a bad word embedding: abus
# a bad word embedding: keri
# a bad word embedding: remarks
# a bad word embedding: knee
# a bad word embedding: hoped
# a bad word embedding: pages
# a bad word embedding: trainer
# a bad word embedding: democratic
# a bad word embedding: cher
# a bad word embedding: phil
# a bad word embedding: drive
# a bad word embedding: moose
# a bad word embedding: federal
# a bad word embedding: antarctica
# a bad word embedding: strip
# a bad word embedding: ♪
# a bad word embedding: flashback
# a bad word embedding: blue
# a bad word embedding: walking
# a bad word embedding: olha
# a bad word embedding: supplements
# a bad word embedding: opportunist
# a bad word embedding: virgos
# a bad word embedding: sky
# a bad word embedding: tohoku
# a bad word embedding: boyz
# a bad word embedding: roland
# a bad word embedding: hornby
# a bad word embedding: aggressive
# a bad word embedding: wants
# a bad word embedding: smfh
# a bad word embedding: slow
# a bad word embedding: motherhood
# a bad word embedding: sacramento
# a bad word embedding: deck
# a bad word embedding: cinco
# a bad word embedding: tears
# a bad word embedding: going
# a bad word embedding: hockey
# a bad word embedding: outrage
# a bad word embedding: ✔
# a bad word embedding: congressional
# a bad word embedding: bryant
# a bad word embedding: trivia
# a bad word embedding: predict
# a bad word embedding: beatles
# a bad word embedding: hallows
# a bad word embedding: freezing
# a bad word embedding: cursing
# a bad word embedding: magazine
# a bad word embedding: products
# a bad word embedding: crossed
# a bad word embedding: having
# a bad word embedding: prime
# a bad word embedding: resource
# a bad word embedding: clipe
# a bad word embedding: artist
# a bad word embedding: jeff
# a bad word embedding: borrow
# a bad word embedding: awwwww
# a bad word embedding: worried
# a bad word embedding: manchester
# a bad word embedding: bombs
# a bad word embedding: worries
# a bad word embedding: yes
# a bad word embedding: where
# a bad word embedding: vision
# a bad word embedding: lindsaylohan
# a bad word embedding: cio
# a bad word embedding: diluted
# a bad word embedding: gangster
# a bad word embedding: anyways
# a bad word embedding: fellas
# a bad word embedding: surgery
# a bad word embedding: enjoying
# a bad word embedding: into
# a bad word embedding: rages
# a bad word embedding: britt
# a bad word embedding: church
# a bad word embedding: brave
# a bad word embedding: that
# a bad word embedding: jumped
# a bad word embedding: sites
# a bad word embedding: wisdom
# a bad word embedding: teeny
# a bad word embedding: books
# a bad word embedding: jonas
# a bad word embedding: teens
# a bad word embedding: than
# a bad word embedding: jumper
# a bad word embedding: bible
# a bad word embedding: jobs
# a bad word embedding: uk
# a bad word embedding: klown
# a bad word embedding: screen
# a bad word embedding: planes
# a bad word embedding: dome
# a bad word embedding: supermarket
# a bad word embedding: awards
# a bad word embedding: dslrs
# a bad word embedding: spark
# a bad word embedding: undermine
# a bad word embedding: tried
# a bad word embedding: www
# a bad word embedding: rant
# a bad word embedding: lice
# a bad word embedding: many
# a bad word embedding: manz
# a bad word embedding: millionaire
# a bad word embedding: flipped
# a bad word embedding: mana
# a bad word embedding: s
# a bad word embedding: loudly
# a bad word embedding: crooked
# a bad word embedding: expression
# a bad word embedding: guts
# a bad word embedding: syria
# a bad word embedding: timberlake
# a bad word embedding: team
# a bad word embedding: yankovic
# a bad word embedding: fsm
# a bad word embedding: mccain
# a bad word embedding: comparing
# a bad word embedding: twin
# a bad word embedding: appeaser
# a bad word embedding: comeback
# a bad word embedding: sentinel
# a bad word embedding: considers
# a bad word embedding: boat
# a bad word embedding: math
# a bad word embedding: caring
# a bad word embedding: myles
# a bad word embedding: armstrong
# a bad word embedding: fic
# a bad word embedding: stretch
# a bad word embedding: west
# a bad word embedding: flash
# a bad word embedding: breath
# a bad word embedding: combined
# a bad word embedding: nessas
# a bad word embedding: reflex
# a bad word embedding: princess
# a bad word embedding: hilarity
# a bad word embedding: shine
# a bad word embedding: wants
# a bad word embedding: detach
# a bad word embedding: whenever
# a bad word embedding: marc
# a bad word embedding: antivirus
# a bad word embedding: turtleneck
# a bad word embedding: muchlove
# a bad word embedding: greatest
# a bad word embedding: fleshy
# a bad word embedding: former
# a bad word embedding: fireflies
# a bad word embedding: jazeera
# a bad word embedding: run
# a bad word embedding: libya
# a bad word embedding: consultant
# a bad word embedding: polls
# a bad word embedding: outside
# a bad word embedding: ransom
# a bad word embedding: him
# a bad word embedding: doctrine
# a bad word embedding: situation
# a bad word embedding: album
# a bad word embedding: ive
# a bad word embedding: feel
# a bad word embedding: die
# a bad word embedding: purse
# a bad word embedding: dubious
# a bad word embedding: quiet
# a bad word embedding: looking
# a bad word embedding: blah
# a bad word embedding: useless
# a bad word embedding: prez
# a bad word embedding: pharoah
# a bad word embedding: grievous
# a bad word embedding: month
# a bad word embedding: technology
# a bad word embedding: fame
# a bad word embedding: pres
# a bad word embedding: len
# a bad word embedding: binary
# a bad word embedding: missiles
# a bad word embedding: verified
# a bad word embedding: rooting
# a bad word embedding: nationalism
# a bad word embedding: lovers
# a bad word embedding: yessir
# a bad word embedding: damon
# a bad word embedding: through
# a bad word embedding: bloom
# a bad word embedding: workout
# a bad word embedding: homophobic
# a bad word embedding: jailbreaking
# a bad word embedding: breakdown
# a bad word embedding: wires
# a bad word embedding: sickness
# a bad word embedding: i
# a bad word embedding: rotflmao
# a bad word embedding: rfid
# a bad word embedding: cheers
# a bad word embedding: cullen
# a bad word embedding: wired
# a bad word embedding: deff
# a bad word embedding: clean
# a bad word embedding: %
# a bad word embedding: taskbar
# a bad word embedding: own
# a bad word embedding: says
# a bad word embedding: behaved
# a bad word embedding: owe
# a bad word embedding: know
# a bad word embedding: may
# a bad word embedding: costs
# a bad word embedding: tutorial
# a bad word embedding: scholarship
# a bad word embedding: summer
# a bad word embedding: hbo
# a bad word embedding: sprayed
# a bad word embedding: predicting
# a bad word embedding: being
# a bad word embedding: rest
# a bad word embedding: conservative
# a bad word embedding: cards
# a bad word embedding: daniel
# a bad word embedding: verdad
# a bad word embedding: summed
# a bad word embedding: jeremy
# a bad word embedding: weekly
# a bad word embedding: segal
# a bad word embedding: kirk
# a bad word embedding: approves
# a bad word embedding: characterization
# a bad word embedding: nyanyi
# a bad word embedding: travolta
# a bad word embedding: crank
# a bad word embedding: overthrow
# a bad word embedding: coded
# a bad word embedding: vibrating
# a bad word embedding: pfsh
# a bad word embedding: travel
# a bad word embedding: roller
# a bad word embedding: ellen
# a bad word embedding: starving
# a bad word embedding: aspects
# a bad word embedding: around
# a bad word embedding: sonic
# a bad word embedding: myself
# a bad word embedding: drake
# a bad word embedding: bresnan
# a bad word embedding: retract
# a bad word embedding: dari
# a bad word embedding: traffic
# a bad word embedding: preference
# a bad word embedding: mgmt
# a bad word embedding: libs
# a bad word embedding: world
# a bad word embedding: dare
# a bad word embedding: sensational
# a bad word embedding: intel
# a bad word embedding: extremely
# a bad word embedding: share
# a bad word embedding: pole
# a bad word embedding: yourself
# a bad word embedding: rachael
# a bad word embedding: achievement
# a bad word embedding: clay
# a bad word embedding: beverly
# a bad word embedding: pundits
# a bad word embedding: tart
# a bad word embedding: agreed
# a bad word embedding: brite
# a bad word embedding: perry
# a bad word embedding: fives
# a bad word embedding: india
# a bad word embedding: khaled
# a bad word embedding: lebanon
# a bad word embedding: tvs
# a bad word embedding: seriously
# a bad word embedding: elements
# a bad word embedding: strobist
# a bad word embedding: brits
# a bad word embedding: divine
# a bad word embedding: thinks
# a bad word embedding: boxers
# a bad word embedding: scandals
# a bad word embedding: noob
# a bad word embedding: ddr
# a bad word embedding: tube
# a bad word embedding: ;]
# a bad word embedding: nook
# a bad word embedding: korver
# a bad word embedding: exit
# a bad word embedding: effort
# a bad word embedding: biased
# a bad word embedding: squabble
# a bad word embedding: transformers
# a bad word embedding: tcot
# a bad word embedding: disinformation
# a bad word embedding: sephora
# a bad word embedding: thumbs-up
# a bad word embedding: cash
# a bad word embedding: shoujo
# a bad word embedding: leadership
# a bad word embedding: curious
# a bad word embedding: lucia
# a bad word embedding: miss
# a bad word embedding: lock
# a bad word embedding: stone
# a bad word embedding: ace
# a bad word embedding: industry
# a bad word embedding: favorite
# a bad word embedding: side
# a bad word embedding: act
# a bad word embedding: message
# a bad word embedding: mean
# a bad word embedding: skew
# a bad word embedding: notwinning
# a bad word embedding: buuren
# a bad word embedding: her
# a bad word embedding: no
# a bad word embedding: headsets
# a bad word embedding: image
# a bad word embedding: qro
# a bad word embedding: paint
# a bad word embedding: gaddafi
# a bad word embedding: homeless
# a bad word embedding: parties
# a bad word embedding: nh
# a bad word embedding: subscriber
# a bad word embedding: her
# a bad word embedding: hes
# a bad word embedding: na
# a bad word embedding: transexual
# a bad word embedding: housewives
# a bad word embedding: sides
# a bad word embedding: hee
# a bad word embedding: nz
# a bad word embedding: mindless
# a bad word embedding: hea
# a bad word embedding: ringwald
# a bad word embedding: brazilian
# a bad word embedding: np
# a bad word embedding: bubble
# a bad word embedding: lang
# a bad word embedding: complete
# a bad word embedding: yayy
# a bad word embedding: arrogance
# a bad word embedding: harry
# a bad word embedding: lampoons
# a bad word embedding: with
# a bad word embedding: kai
# a bad word embedding: buying
# a bad word embedding: handsome
# a bad word embedding: pull
# a bad word embedding: rush
# a bad word embedding: october
# a bad word embedding: marni
# a bad word embedding: monopoly
# a bad word embedding: house
# a bad word embedding: tripe
# a bad word embedding: unveils
# a bad word embedding: taught
# a bad word embedding: -------------
# a bad word embedding: dirty
# a bad word embedding: politically
# a bad word embedding: obsession
# a bad word embedding: agree
# a bad word embedding: detailed
# a bad word embedding: e'er
# a bad word embedding: ab
# a bad word embedding: ohh
# a bad word embedding: ad
# a bad word embedding: ai
# a bad word embedding: ah
# a bad word embedding: walkn
# a bad word embedding: stealing
# a bad word embedding: am
# a bad word embedding: al
# a bad word embedding: watches
# a bad word embedding: how
# a bad word embedding: as
# a bad word embedding: ar
# a bad word embedding: au
# a bad word embedding: at
# ...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0121 20:50:55.429708 140568046942080 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0121 20:50:55.443212 140568046942080 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From at_lstm.py:213: calling reduce_max_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# W0121 20:50:55.467668 140568046942080 deprecation.py:506] From at_lstm.py:213: calling reduce_max_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From at_lstm.py:218: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# W0121 20:50:55.474951 140568046942080 deprecation.py:506] From at_lstm.py:218: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From at_lstm.py:230: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# W0121 20:50:55.493597 140568046942080 module_wrapper.py:139] From at_lstm.py:230: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From at_lstm.py:230: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0121 20:50:55.493765 140568046942080 module_wrapper.py:139] From at_lstm.py:230: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From at_lstm.py:232: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0121 20:50:55.494387 140568046942080 module_wrapper.py:139] From at_lstm.py:232: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From at_lstm.py:236: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0121 20:50:55.502843 140568046942080 module_wrapper.py:139] From at_lstm.py:236: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From at_lstm.py:246: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0121 20:50:56.076426 140568046942080 module_wrapper.py:139] From at_lstm.py:246: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-01-21 20:50:56.077921: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-21 20:50:56.135082: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 20:50:56.135686: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-01-21 20:50:56.146984: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-21 20:50:56.376656: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-01-21 20:50:56.499049: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-01-21 20:50:56.530341: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-01-21 20:50:56.788481: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-01-21 20:50:56.829240: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-01-21 20:50:57.324841: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-01-21 20:50:57.325056: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 20:50:57.325878: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 20:50:57.326458: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-01-21 20:50:57.336189: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-01-21 20:50:57.336517: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x201f100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-01-21 20:50:57.336550: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-01-21 20:50:57.463008: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 20:50:57.463667: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x201f2c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-01-21 20:50:57.463693: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-01-21 20:50:57.464839: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 20:50:57.465353: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-01-21 20:50:57.465432: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-21 20:50:57.465449: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-01-21 20:50:57.465463: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-01-21 20:50:57.465476: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-01-21 20:50:57.465493: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-01-21 20:50:57.465507: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-01-21 20:50:57.465520: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-01-21 20:50:57.465613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 20:50:57.466158: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 20:50:57.466659: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-01-21 20:50:57.470078: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-21 20:50:57.471277: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-01-21 20:50:57.471305: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-01-21 20:50:57.471314: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-01-21 20:50:57.472200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 20:50:57.472778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 20:50:57.473251: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-01-21 20:50:57.473282: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From at_lstm.py:258: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0121 20:50:57.474064 140568046942080 module_wrapper.py:139] From at_lstm.py:258: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From at_lstm.py:260: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W0121 20:50:57.476460 140568046942080 module_wrapper.py:139] From at_lstm.py:260: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From at_lstm.py:266: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# W0121 20:50:57.477996 140568046942080 module_wrapper.py:139] From at_lstm.py:266: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From at_lstm.py:270: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0121 20:51:02.360614 140568046942080 module_wrapper.py:139] From at_lstm.py:270: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From at_lstm.py:270: The name tf.train.SaverDef is deprecated. Please use tf.compat.v1.train.SaverDef instead.
#
# W0121 20:51:02.853583 140568046942080 module_wrapper.py:139] From at_lstm.py:270: The name tf.train.SaverDef is deprecated. Please use tf.compat.v1.train.SaverDef instead.
#
# WARNING:tensorflow:From at_lstm.py:272: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# W0121 20:51:02.890323 140568046942080 module_wrapper.py:139] From at_lstm.py:272: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# load word-to-id done!
# load aspect-to-id done!
# cnt= 120159
# Counter({'1': 62944, '0': 57215})
# load word-to-id done!
# load aspect-to-id done!
# cnt= 31522
# Counter({'1': 15861, '0': 15661})
# 2020-01-21 20:51:15.193016: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# all samples=31522, correct prediction=22444.0
# Iter 0: mini-batch loss=0.504678, test acc=0.712011
# all samples=31522, correct prediction=22675.0
# Iter 1: mini-batch loss=0.880278, test acc=0.719339
# all samples=31522, correct prediction=22481.0
# Iter 2: mini-batch loss=0.619740, test acc=0.713184
# all samples=31522, correct prediction=22691.0
# Iter 3: mini-batch loss=0.856615, test acc=0.719846
# all samples=31522, correct prediction=22256.0
# Iter 4: mini-batch loss=0.798936, test acc=0.706047
# all samples=31522, correct prediction=22003.0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# W0121 21:23:41.742319 140568046942080 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Iter 5: mini-batch loss=0.911960, test acc=0.698020
# all samples=31522, correct prediction=22226.0
# Iter 6: mini-batch loss=0.666206, test acc=0.705095
# all samples=31522, correct prediction=22594.0
# Iter 7: mini-batch loss=0.643582, test acc=0.716769
# all samples=31522, correct prediction=22520.0
# Iter 8: mini-batch loss=0.641305, test acc=0.714422
# all samples=31522, correct prediction=22336.0
# Iter 9: mini-batch loss=0.707751, test acc=0.708584
# all samples=31522, correct prediction=22300.0
# Iter 10: mini-batch loss=0.612381, test acc=0.707442
# all samples=31522, correct prediction=22177.0
# Iter 11: mini-batch loss=0.865795, test acc=0.703540
# Traceback (most recent call last):
#   File "at_lstm.py", line 376, in <module>
#     tf.app.run()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 299, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 250, in _run_main
#     sys.exit(main(argv))
#   File "at_lstm.py", line 372, in main
#     lstm.run()
#   File "at_lstm.py", line 302, in run
#     _, step, summary = sess.run([optimizer, global_step, train_summary_op], feed_dict=train)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 956, in run
#     run_metadata_ptr)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1180, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1359, in _do_run
#     run_metadata)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# KeyboardInterrupt

# %%
# AEAT SST2
# %cd /content/TD-LSTM
# !python at_lstm.py --train_file_path='../tmp/train.raw' --validate_file_path='../tmp/validate.raw' --test_file_path='../tmp/test.raw' --embedding_file_path='../tmp/twitter_word_embedding_partial_200.txt' --word_id_file_path='../tmp/word_id.txt' --aspect_id_file_path='../tmp/aspect_id.txt' --method='AT' --n_class=2

# %%
# AT SentiHood
# %cd /content/TD-LSTM
# !python at_lstm.py --train_file_path='../tmp/train.raw' --validate_file_path='../tmp/validate.raw' --test_file_path='../tmp/test.raw' --embedding_file_path='../tmp/twitter_word_embedding_partial_200.txt' --word_id_file_path='../tmp/word_id.txt' --aspect_id_file_path='../tmp/aspect_id.txt' --method='AT' --n_class=2
# Out:
# /content/TD-LSTM
# WARNING:tensorflow:From at_lstm.py:376: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
#
# load word-id mapping done!
#
# a bad word embedding: jojo
# a bad word embedding: raining
# a bad word embedding: borderline
# a bad word embedding: yellow
# a bad word embedding: keno
# a bad word embedding: four
# a bad word embedding: gag
# a bad word embedding: woods
# a bad word embedding: olympics
# a bad word embedding: spiders
# a bad word embedding: verses
# a bad word embedding: hanging
# a bad word embedding: until
# a bad word embedding: marching
# a bad word embedding: foundation
# a bad word embedding: twittercrush
# a bad word embedding: extrapolate
# a bad word embedding: archuleta
# a bad word embedding: gnews
# a bad word embedding: lord
# a bad word embedding: sinking
# a bad word embedding: muthafuckin
# a bad word embedding: differently
# a bad word embedding: hdtv
# a bad word embedding: fur
# a bad word embedding: bringing
# a bad word embedding: pants
# a bad word embedding: welp
# a bad word embedding: engga
# a bad word embedding: prize
# a bad word embedding: less
# a bad word embedding: wooden
# a bad word embedding: classic
# a bad word embedding: voyeur
# a bad word embedding: wednesday
# a bad word embedding: oooo
# a bad word embedding: solid
# a bad word embedding: does
# a bad word embedding: crotch
# a bad word embedding: gizmodo
# a bad word embedding: oooh
# a bad word embedding: multilateral
# a bad word embedding: provided
# a bad word embedding: paul
# a bad word embedding: straight
# a bad word embedding: playlist
# a bad word embedding: figured
# a bad word embedding: specially
# a bad word embedding: tired
# a bad word embedding: nigg
# a bad word embedding: perch
# a bad word embedding: pulse
# a bad word embedding: byron
# a bad word embedding: tires
# a bad word embedding: matthew
# a bad word embedding: second
# a bad word embedding: hockey
# a bad word embedding: hootsuite
# a bad word embedding: spambot
# a bad word embedding: newsrooms
# a bad word embedding: mason
# a bad word embedding: bet
# a bad word embedding: errors
# a bad word embedding: relieving
# a bad word embedding: reopens
# a bad word embedding: cooking
# a bad word embedding: fingers
# a bad word embedding: wrong
# a bad word embedding: hamilton
# a bad word embedding: ko
# a bad word embedding: designing
# a bad word embedding: increasing
# a bad word embedding: presidential
# a bad word embedding: pressed
# a bad word embedding: dort
# a bad word embedding: neville
# a bad word embedding: hero
# a bad word embedding: reporter
# a bad word embedding: aja
# a bad word embedding: hera
# a bad word embedding: interrupting
# a bad word embedding: budget
# a bad word embedding: here
# a bad word embedding: trustworthy
# a bad word embedding: reported
# a bad word embedding: presidency
# a bad word embedding: hers
# a bad word embedding: daht
# a bad word embedding: dork
# a bad word embedding: darkness
# a bad word embedding: kids
# a bad word embedding: downfall
# a bad word embedding: miss
# a bad word embedding: reports
# a bad word embedding: controversy
# a bad word embedding: lg
# a bad word embedding: transfixed
# a bad word embedding: not
# a bad word embedding: military
# a bad word embedding: now
# a bad word embedding: nope
# a bad word embedding: gambhir
# a bad word embedding: criticism
# a bad word embedding: compared
# a bad word embedding: smdh
# a bad word embedding: owed
# a bad word embedding: harvey
# a bad word embedding: explained
# a bad word embedding: three
# a bad word embedding: replace
# a bad word embedding: brought
# a bad word embedding: shoddy
# a bad word embedding: skater
# a bad word embedding: stern
# a bad word embedding: pee
# a bad word embedding: cocaine
# a bad word embedding: unit
# a bad word embedding: mote
# a bad word embedding: casey
# a bad word embedding: sexual
# a bad word embedding: brittani
# a bad word embedding: spoke
# a bad word embedding: catchy
# a bad word embedding: dnt
# a bad word embedding: melanie
# a bad word embedding: music
# a bad word embedding: therefore
# a bad word embedding: strike
# a bad word embedding: musik
# a bad word embedding: until
# a bad word embedding: brighton
# a bad word embedding: hu
# a bad word embedding: playboy
# a bad word embedding: holy
# a bad word embedding: relax
# a bad word embedding: successful
# a bad word embedding: brings
# a bad word embedding: hypocritical
# a bad word embedding: poppers
# a bad word embedding: hurt
# a bad word embedding: hole
# a bad word embedding: hold
# a bad word embedding: locked
# a bad word embedding: vou
# a bad word embedding: text
# a bad word embedding: accomplishment
# a bad word embedding: ending
# a bad word embedding: luna
# a bad word embedding: inget
# a bad word embedding: battlefront
# a bad word embedding: sweeter
# a bad word embedding: example
# a bad word embedding: grimes
# a bad word embedding: duke
# a bad word embedding: le
# a bad word embedding: wang
# a bad word embedding: ends
# a bad word embedding: reality
# a bad word embedding: currency
# a bad word embedding: kiss
# a bad word embedding: reviewing
# a bad word embedding: want
# a bad word embedding: peanuts
# a bad word embedding: dyke
# a bad word embedding: rescue
# a bad word embedding: preferably
# a bad word embedding: hoe
# a bad word embedding: lb
# a bad word embedding: la
# a bad word embedding: complaining
# a bad word embedding: hoo
# a bad word embedding: travel
# a bad word embedding: attention
# a bad word embedding: damage
# a bad word embedding: killing
# a bad word embedding: machine
# a bad word embedding: how
# a bad word embedding: hot
# a bad word embedding: elmo
# a bad word embedding: phils
# a bad word embedding: lp
# a bad word embedding: stock
# a bad word embedding: preferable
# a bad word embedding: wolfram
# a bad word embedding: a
# a bad word embedding: gaming
# a bad word embedding: oritse
# a bad word embedding: beauty
# a bad word embedding: dressed
# a bad word embedding: dell
# a bad word embedding: wrong
# a bad word embedding: hear
# a bad word embedding: reese
# a bad word embedding: high-profile
# a bad word embedding: chorus
# a bad word embedding: balads
# a bad word embedding: outcry
# a bad word embedding: hoping
# a bad word embedding: wins
# a bad word embedding: tumblr
# a bad word embedding: gimmie
# a bad word embedding: season
# a bad word embedding: wink
# a bad word embedding: another
# a bad word embedding: keeps
# a bad word embedding: boice
# a bad word embedding: wind
# a bad word embedding: wine
# a bad word embedding: __
# a bad word embedding: blind
# a bad word embedding: feedback
# a bad word embedding: telecom
# a bad word embedding: govern
# a bad word embedding: sylvester
# a bad word embedding: bubbles
# a bad word embedding: butcher
# a bad word embedding: mañana
# a bad word embedding: dispatch
# a bad word embedding: true
# a bad word embedding: told
# a bad word embedding: hip
# a bad word embedding: gossip
# a bad word embedding: his
# a bad word embedding: fit
# a bad word embedding: wire
# a bad word embedding: screaming
# a bad word embedding: fix
# a bad word embedding: rescued
# a bad word embedding: harris
# a bad word embedding: spurs
# a bad word embedding: fin
# a bad word embedding: easier
# a bad word embedding: aguilera
# a bad word embedding: glorify
# a bad word embedding: blowjobs
# a bad word embedding: lambert
# a bad word embedding: slate
# a bad word embedding: keri
# a bad word embedding: seth
# a bad word embedding: hahahahahahah
# a bad word embedding: zac
# a bad word embedding: yonni
# a bad word embedding: effects
# a bad word embedding: velcro
# a bad word embedding: schools
# a bad word embedding: angelinajolie
# a bad word embedding: sixteen
# a bad word embedding: mereçe
# a bad word embedding: represents
# a bad word embedding: debut
# a bad word embedding: dumps
# a bad word embedding: shame
# a bad word embedding: self-titled
# a bad word embedding: addicted
# a bad word embedding: loeb
# a bad word embedding: herta
# a bad word embedding: curse
# a bad word embedding: financial
# a bad word embedding: snakes
# a bad word embedding: woes
# a bad word embedding: series
# a bad word embedding: lamesauce
# a bad word embedding: science
# a bad word embedding: donald
# a bad word embedding: efron
# a bad word embedding: woei
# a bad word embedding: hollywood
# a bad word embedding: whip
# a bad word embedding: rt
# a bad word embedding: rv
# a bad word embedding: trending
# a bad word embedding: maksim
# a bad word embedding: oprah
# a bad word embedding: dst
# a bad word embedding: blitzer
# a bad word embedding: dsi
# a bad word embedding: size
# a bad word embedding: super
# a bad word embedding: foundation
# a bad word embedding: word
# a bad word embedding: written
# a bad word embedding: media
# a bad word embedding: university
# a bad word embedding: work
# a bad word embedding: threatened
# a bad word embedding: corrects
# a bad word embedding: gameplay
# a bad word embedding: debuting
# a bad word embedding: ate
# a bad word embedding: shelves
# a bad word embedding: atm
# a bad word embedding: chan
# a bad word embedding: devastation
# a bad word embedding: commented
# a bad word embedding: shipped
# a bad word embedding: levels
# a bad word embedding: human
# a bad word embedding: chaz
# a bad word embedding: yester
# a bad word embedding: crossings
# a bad word embedding: obituary
# a bad word embedding: trillion
# a bad word embedding: dun
# a bad word embedding: duo
# a bad word embedding: disfigured
# a bad word embedding: goggle
# a bad word embedding: please
# a bad word embedding: brian
# a bad word embedding: lauter
# a bad word embedding: customization
# a bad word embedding: politics
# a bad word embedding: sex
# a bad word embedding: singh
# a bad word embedding: website
# a bad word embedding: basketball
# a bad word embedding: backlinks
# a bad word embedding: service
# a bad word embedding: lego
# a bad word embedding: effect
# a bad word embedding: needed
# a bad word embedding: simmons
# a bad word embedding: master
# a bad word embedding: listed
# a bad word embedding: worlds
# a bad word embedding: invasion
# a bad word embedding: legs
# a bad word embedding: bitter
# a bad word embedding: listen
# a bad word embedding: yay
# a bad word embedding: grown-up
# a bad word embedding: lucunya
# a bad word embedding: named
# a bad word embedding: wisdom
# a bad word embedding: nirvana
# a bad word embedding: date
# a bad word embedding: predictable
# a bad word embedding: victory
# a bad word embedding: legally
# a bad word embedding: suck
# a bad word embedding: positively
# a bad word embedding: spotifylink
# a bad word embedding: beautiful
# a bad word embedding: trek
# a bad word embedding: code
# a bad word embedding: showed
# a bad word embedding: elegant
# a bad word embedding: coward
# a bad word embedding: tree
# a bad word embedding: likely
# a bad word embedding: nations
# a bad word embedding: project
# a bad word embedding: pioneer
# a bad word embedding: sheen
# a bad word embedding: hahaha
# a bad word embedding: feeling
# a bad word embedding: lebron
# a bad word embedding: cody
# a bad word embedding: chicago
# a bad word embedding: runner
# a bad word embedding: boston
# a bad word embedding: aapl
# a bad word embedding: esto
# a bad word embedding: spectrum
# a bad word embedding: angela
# a bad word embedding: son
# a bad word embedding: angels
# a bad word embedding: williams
# a bad word embedding: then
# a bad word embedding: them
# a bad word embedding: kidnap
# a bad word embedding: britney
# a bad word embedding: ast
# a bad word embedding: ginuwine
# a bad word embedding: band
# a bad word embedding: recommended
# a bad word embedding: causing
# a bad word embedding: amusing
# a bad word embedding: they
# a bad word embedding: brains
# a bad word embedding: ask
# a bad word embedding: jones
# a bad word embedding: haunting
# a bad word embedding: shall
# a bad word embedding: thrilled
# a bad word embedding: screwing
# a bad word embedding: object
# a bad word embedding: cinematic
# a bad word embedding: victoria
# a bad word embedding: kelly
# a bad word embedding: mouth
# a bad word embedding: addict
# a bad word embedding: letter
# a bad word embedding: entry
# a bad word embedding: retaining
# a bad word embedding: macbook
# a bad word embedding: thriller
# a bad word embedding: typical
# a bad word embedding: singer
# a bad word embedding: africa
# a bad word embedding: episode
# a bad word embedding: hispanic
# a bad word embedding: camp
# a bad word embedding: bullock
# a bad word embedding: coloquem
# a bad word embedding: drunks
# a bad word embedding: tech
# a bad word embedding: lisbon
# a bad word embedding: scream
# a bad word embedding: came
# a bad word embedding: saying
# a bad word embedding: bomb
# a bad word embedding: reactor
# a bad word embedding: dédié
# a bad word embedding: flunking
# a bad word embedding: meetings
# a bad word embedding: agency
# a bad word embedding: curls
# a bad word embedding: nominated
# a bad word embedding: rediscovery
# a bad word embedding: tehran
# a bad word embedding: daryl
# a bad word embedding: congressional
# a bad word embedding: vindictive
# a bad word embedding: lessons
# a bad word embedding: orleans
# a bad word embedding: busy
# a bad word embedding: rca
# a bad word embedding: shuffling
# a bad word embedding: headline
# a bad word embedding: menu
# a bad word embedding: boleh
# a bad word embedding: bust
# a bad word embedding: rihanna
# a bad word embedding: theme
# a bad word embedding: rick
# a bad word embedding: rich
# a bad word embedding: snitch
# a bad word embedding: mrs.
# a bad word embedding: yo
# a bad word embedding: goper
# a bad word embedding: btw
# a bad word embedding: psychiatric
# a bad word embedding: ldn
# a bad word embedding: pocket
# a bad word embedding: x
# a bad word embedding: thingys
# a bad word embedding: net
# a bad word embedding: nicely
# a bad word embedding: jovana
# a bad word embedding: armin
# a bad word embedding: rio
# a bad word embedding: openly
# a bad word embedding: sean
# a bad word embedding: piggy
# a bad word embedding: release
# a bad word embedding: clearly
# a bad word embedding: pada
# a bad word embedding: dmb
# a bad word embedding: disaster
# a bad word embedding: fair
# a bad word embedding: deemed
# a bad word embedding: levant
# a bad word embedding: goodnight
# a bad word embedding: dms
# a bad word embedding: result
# a bad word embedding: fail
# a bad word embedding: logging
# a bad word embedding: android
# a bad word embedding: john
# a bad word embedding: hammer
# a bad word embedding: best
# a bad word embedding: karate
# a bad word embedding: cobra
# a bad word embedding: moron
# a bad word embedding: risk
# a bad word embedding: manson
# a bad word embedding: glass
# a bad word embedding: lots
# a bad word embedding: rise
# a bad word embedding: rings
# a bad word embedding: upgraded
# a bad word embedding: lott
# a bad word embedding: stamps
# a bad word embedding: dms
# a bad word embedding: cage
# a bad word embedding: ire
# a bad word embedding: lamar
# a bad word embedding: never
# a bad word embedding: parallels
# a bad word embedding: omnivore
# a bad word embedding: lindsey
# a bad word embedding: wtf
# a bad word embedding: wth
# a bad word embedding: perverts
# a bad word embedding: jlo
# a bad word embedding: debt
# a bad word embedding: capello
# a bad word embedding: pity
# a bad word embedding: veronica
# a bad word embedding: accident
# a bad word embedding: mixtape
# a bad word embedding: country
# a bad word embedding: adapter
# a bad word embedding: psa
# a bad word embedding: sanja
# a bad word embedding: adventures
# a bad word embedding: demanded
# a bad word embedding: playful
# a bad word embedding: tekin
# a bad word embedding: geweldig
# a bad word embedding: planned
# a bad word embedding: hated
# a bad word embedding: als
# a bad word embedding: login
# a bad word embedding: argue
# a bad word embedding: asked
# a bad word embedding: and
# a bad word embedding: mortified
# a bad word embedding: apartment
# a bad word embedding: twenty-three
# a bad word embedding: closet
# a bad word embedding: vail
# a bad word embedding: vaio
# a bad word embedding: blonds
# a bad word embedding: cult
# a bad word embedding: telegraph
# a bad word embedding: pregnancy
# a bad word embedding: blonde
# a bad word embedding: method
# a bad word embedding: saturday
# a bad word embedding: americus
# a bad word embedding: blocks
# a bad word embedding: angel
# a bad word embedding: fromtwitter
# a bad word embedding: source
# a bad word embedding: chrome
# a bad word embedding: activa
# a bad word embedding: fri
# a bad word embedding: fro
# a bad word embedding: .
# a bad word embedding: bothers
# a bad word embedding: much
# a bad word embedding: dont
# a bad word embedding: privilege
# a bad word embedding: reggie
# a bad word embedding: fry
# a bad word embedding: gladly
# a bad word embedding: tomato
# a bad word embedding: life
# a bad word embedding: crying
# a bad word embedding: poland
# a bad word embedding: worker
# a bad word embedding: moldova
# a bad word embedding: dave
# a bad word embedding: lift
# a bad word embedding: child
# a bad word embedding: easton
# a bad word embedding: stepdad
# a bad word embedding: haters
# a bad word embedding: spin
# a bad word embedding: chill
# a bad word embedding: holmes
# a bad word embedding: commerce
# a bad word embedding: simplifies
# a bad word embedding: presidency
# a bad word embedding: ada
# a bad word embedding: vexed
# a bad word embedding: castro
# a bad word embedding: hippocratic
# a bad word embedding: starstruck
# a bad word embedding: goaly
# a bad word embedding: event
# a bad word embedding: spoof
# a bad word embedding: surprises
# a bad word embedding: played
# a bad word embedding: ditching
# a bad word embedding: vacation
# a bad word embedding: lol
# a bad word embedding: conditioned
# a bad word embedding: player
# a bad word embedding: courtney
# a bad word embedding: madonna
# a bad word embedding: sells
# a bad word embedding: trusted
# a bad word embedding: undue
# a bad word embedding: hong
# a bad word embedding: recover
# a bad word embedding: taped
# a bad word embedding: python
# a bad word embedding: things
# a bad word embedding: oh
# a bad word embedding: backed
# a bad word embedding: patient
# a bad word embedding: split
# a bad word embedding: babies
# a bad word embedding: electro
# a bad word embedding: fairly
# a bad word embedding: runs
# a bad word embedding: biggie
# a bad word embedding: maybe
# a bad word embedding: keyshia
# a bad word embedding: jungle
# a bad word embedding: tops
# a bad word embedding: workforce
# a bad word embedding: tuna
# a bad word embedding: truths
# a bad word embedding: haggard
# a bad word embedding: tune
# a bad word embedding: nuanced
# a bad word embedding: nat'l
# a bad word embedding: blowjob
# a bad word embedding: academic
# a bad word embedding: corporate
# a bad word embedding: fittest
# a bad word embedding: opinions
# a bad word embedding: thank
# a bad word embedding: sleeps
# a bad word embedding: that
# a bad word embedding: sleepy
# a bad word embedding: sid
# a bad word embedding: allday
# a bad word embedding: meester
# a bad word embedding: censoring
# a bad word embedding: rushing
# a bad word embedding: succeeding
# a bad word embedding: happy
# a bad word embedding: hah
# a bad word embedding: blame
# a bad word embedding: hal
# a bad word embedding: offer
# a bad word embedding: marieclaire
# a bad word embedding: ease
# a bad word embedding: had
# a bad word embedding: hag
# a bad word embedding: bnk
# a bad word embedding: haz
# a bad word embedding: surely
# a bad word embedding: richie
# a bad word embedding: easy
# a bad word embedding: prison
# a bad word embedding: har
# a bad word embedding: has
# a bad word embedding: hat
# a bad word embedding: wide
# a bad word embedding: survival
# a bad word embedding: credit
# a bad word embedding: posed
# a bad word embedding: possible
# a bad word embedding: twinks
# a bad word embedding: revolver
# a bad word embedding: possibly
# a bad word embedding: yeh
# a bad word embedding: kiss
# a bad word embedding: distortion
# a bad word embedding: shadow
# a bad word embedding: unique
# a bad word embedding: usually
# a bad word embedding: stylist
# a bad word embedding: desire
# a bad word embedding: stooopid
# a bad word embedding: ang
# a bad word embedding: oh
# a bad word embedding: kust
# a bad word embedding: remind
# a bad word embedding: aristotle
# a bad word embedding: steven
# a bad word embedding: sebastian
# a bad word embedding: oooooooooh
# a bad word embedding: swedish
# a bad word embedding: ola
# a bad word embedding: attorney
# a bad word embedding: right
# a bad word embedding: old
# a bad word embedding: creek
# a bad word embedding: people
# a bad word embedding: idiot
# a bad word embedding: creed
# a bad word embedding: crown
# a bad word embedding: topping
# a bad word embedding: olo
# a bad word embedding: arquette
# a bad word embedding: gon
# a bad word embedding: insistence
# a bad word embedding: billboard
# a bad word embedding: prick
# a bad word embedding: fuuuuck
# a bad word embedding: creep
# a bad word embedding: gasps
# a bad word embedding: ruffled
# a bad word embedding: for
# a bad word embedding: bottom
# a bad word embedding: res
# a bad word embedding: fox
# a bad word embedding: creative
# a bad word embedding: witty
# a bad word embedding: foe
# a bad word embedding: fog
# a bad word embedding: facebook
# a bad word embedding: foc
# a bad word embedding: umm
# a bad word embedding: keith
# a bad word embedding: celebration
# a bad word embedding: pinched
# a bad word embedding: instant
# a bad word embedding: annan
# a bad word embedding: calls
# a bad word embedding: lightsabers
# a bad word embedding: trampoline
# a bad word embedding: dng
# a bad word embedding: thing
# a bad word embedding: shifting
# a bad word embedding: starring
# a bad word embedding: stylish
# a bad word embedding: losing
# a bad word embedding: memorable
# a bad word embedding: jelena
# a bad word embedding: think
# a bad word embedding: first
# a bad word embedding: amber
# a bad word embedding: spektor
# a bad word embedding: nowplaying
# a bad word embedding: dollars
# a bad word embedding: citizens
# a bad word embedding: entrants
# a bad word embedding: o
# a bad word embedding: valentine
# a bad word embedding: schue
# a bad word embedding: stoked
# a bad word embedding: meddle
# a bad word embedding: sooo
# a bad word embedding: happens
# a bad word embedding: raised
# a bad word embedding: statements
# a bad word embedding: logo
# a bad word embedding: marshall
# a bad word embedding: honeymoon
# a bad word embedding: som
# a bad word embedding: son
# a bad word embedding: thankful
# a bad word embedding: aaron
# a bad word embedding: magazines
# a bad word embedding: latina
# a bad word embedding: globalgrind
# a bad word embedding: adhd
# a bad word embedding: soy
# a bad word embedding: shoots
# a bad word embedding: discography
# a bad word embedding: fey
# a bad word embedding: novo
# a bad word embedding: ends
# a bad word embedding: novi
# a bad word embedding: waits
# a bad word embedding: support
# a bad word embedding: halle
# a bad word embedding: hang
# a bad word embedding: avail
# a bad word embedding: absolutely
# a bad word embedding: jank
# a bad word embedding: spring
# a bad word embedding: awful
# a bad word embedding: tweeps
# a bad word embedding: marge
# a bad word embedding: happy
# a bad word embedding: manufacturers
# a bad word embedding: fascination
# a bad word embedding: eer
# a bad word embedding: publicized
# a bad word embedding: fresh
# a bad word embedding: handjob
# a bad word embedding: upgrades
# a bad word embedding: seeing
# a bad word embedding: congratulations
# a bad word embedding: humbled
# a bad word embedding: minaj
# a bad word embedding: inside
# a bad word embedding: islands
# a bad word embedding: trash
# a bad word embedding: devices
# a bad word embedding: cale
# a bad word embedding: considered
# a bad word embedding: vanguard
# a bad word embedding: tony
# a bad word embedding: palm
# a bad word embedding: duet
# a bad word embedding: panels
# a bad word embedding: cuddles
# a bad word embedding: disgrace
# a bad word embedding: minaj
# a bad word embedding: steady
# a bad word embedding: six
# a bad word embedding: josh
# a bad word embedding: christina
# a bad word embedding: proven
# a bad word embedding: ''
# a bad word embedding: virgin
# a bad word embedding: proves
# a bad word embedding: exist
# a bad word embedding: portrayed
# a bad word embedding: dealer
# a bad word embedding: woooow
# a bad word embedding: francisco
# a bad word embedding: floor
# a bad word embedding: feat
# a bad word embedding: mayo
# a bad word embedding: actor
# a bad word embedding: ourselves
# a bad word embedding: flood
# a bad word embedding: role
# a bad word embedding: woke
# a bad word embedding: hurr
# a bad word embedding: developers
# a bad word embedding: smell
# a bad word embedding: roll
# a bad word embedding: re-watched
# a bad word embedding: cracks
# a bad word embedding: 's
# a bad word embedding: palms
# a bad word embedding: lenny
# a bad word embedding: meghan
# a bad word embedding: center
# a bad word embedding: snowe
# a bad word embedding: 'd
# a bad word embedding: idk
# a bad word embedding: miranda
# a bad word embedding: rolling
# a bad word embedding: 'n
# a bad word embedding: 'm
# a bad word embedding: chrisette
# a bad word embedding: jewelry
# a bad word embedding: 's
# a bad word embedding: euroland
# a bad word embedding: contacts
# a bad word embedding: ottawa
# a bad word embedding: montag
# a bad word embedding: bitchmode
# a bad word embedding: time
# a bad word embedding: push
# a bad word embedding: tunes
# a bad word embedding: empire
# a bad word embedding: inc
# a bad word embedding: gown
# a bad word embedding: japan
# a bad word embedding: whoever
# a bad word embedding: real-estate
# a bad word embedding: nicklaus
# a bad word embedding: plumb
# a bad word embedding: hawaii
# a bad word embedding: disappears
# a bad word embedding: chair
# a bad word embedding: bye
# a bad word embedding: imacs
# a bad word embedding: ward
# a bad word embedding: ver
# a bad word embedding: struggle
# a bad word embedding: sneakers
# a bad word embedding: tourism
# a bad word embedding: eliminate
# a bad word embedding: recipient
# a bad word embedding: logos
# a bad word embedding: downloading
# a bad word embedding: prize
# a bad word embedding: jerk
# a bad word embedding: everytime
# a bad word embedding: saldana
# a bad word embedding: consolidation
# a bad word embedding: olympus
# a bad word embedding: choice
# a bad word embedding: nothing
# a bad word embedding: laurie
# a bad word embedding: rechargable
# a bad word embedding: minute
# a bad word embedding: rand
# a bad word embedding: cooks
# a bad word embedding: doggy
# a bad word embedding: micah
# a bad word embedding: hahah
# a bad word embedding: ludacris
# a bad word embedding: tax
# a bad word embedding: invade
# a bad word embedding: leave
# a bad word embedding: :]
# a bad word embedding: katrina
# a bad word embedding: dnc
# a bad word embedding: team
# a bad word embedding: warren
# a bad word embedding: loads
# a bad word embedding: shooters
# a bad word embedding: kevin
# a bad word embedding: prevent
# a bad word embedding: droid
# a bad word embedding: o.o
# a bad word embedding: sigh
# a bad word embedding: sign
# a bad word embedding: utility
# a bad word embedding: failed
# a bad word embedding: erotic
# a bad word embedding: mega
# a bad word embedding: designs
# a bad word embedding: shirts
# a bad word embedding: reaffirmed
# a bad word embedding: ➲
# a bad word embedding: brady
# a bad word embedding: threesomes
# a bad word embedding: jeopardy
# a bad word embedding: celebrated
# a bad word embedding: realizing
# a bad word embedding: melt
# a bad word embedding: maine
# a bad word embedding: current
# a bad word embedding: freaks
# a bad word embedding: ➜
# a bad word embedding: locket
# a bad word embedding: falling
# a bad word embedding: celebrates
# a bad word embedding: lopez
# a bad word embedding: me
# a bad word embedding: creepiest
# a bad word embedding: dates
# a bad word embedding: ma
# a bad word embedding: niche
# a bad word embedding: africa
# a bad word embedding: rachel
# a bad word embedding: understanding
# a bad word embedding: sharing
# a bad word embedding: mr
# a bad word embedding: alone
# a bad word embedding: along
# a bad word embedding: my
# a bad word embedding: warner
# a bad word embedding: assassinating
# a bad word embedding: neville
# a bad word embedding: butt-naked
# a bad word embedding: toyboy
# a bad word embedding: redemption
# a bad word embedding: dusty
# a bad word embedding: woop
# a bad word embedding: wherever
# a bad word embedding: mj
# a bad word embedding: blog
# a bad word embedding: born
# a bad word embedding: ineffective
# a bad word embedding: myers
# a bad word embedding: my
# a bad word embedding: mx
# a bad word embedding: reclaim
# a bad word embedding: real
# a bad word embedding: love
# a bad word embedding: policies
# a bad word embedding: lactating
# a bad word embedding: defend
# a bad word embedding: prefer
# a bad word embedding: dog
# a bad word embedding: bloody
# a bad word embedding: fakers
# a bad word embedding: fake
# a bad word embedding: carol
# a bad word embedding: ecuador
# a bad word embedding: himym
# a bad word embedding: working
# a bad word embedding: may
# a bad word embedding: positive
# a bad word embedding: angry
# a bad word embedding: nationalize
# a bad word embedding: hello
# a bad word embedding: sisterly
# a bad word embedding: wondering
# a bad word embedding: films
# a bad word embedding: heroics
# a bad word embedding: softball
# a bad word embedding: bodies
# a bad word embedding: loving
# a bad word embedding: scratched
# a bad word embedding: ``
# a bad word embedding: leeches
# a bad word embedding: clitoris
# a bad word embedding: apparent
# a bad word embedding: refrain
# a bad word embedding: consoles
# a bad word embedding: goods
# a bad word embedding: everywhere
# a bad word embedding: icon
# a bad word embedding: rythme
# a bad word embedding: behalf
# a bad word embedding: suckah
# a bad word embedding: logos
# a bad word embedding: deserved
# a bad word embedding: originally
# a bad word embedding: pretend
# a bad word embedding: magnificent
# a bad word embedding: birkin
# a bad word embedding: believer
# a bad word embedding: believes
# a bad word embedding: nether
# a bad word embedding: inciter
# a bad word embedding: values
# a bad word embedding: phoebe
# a bad word embedding: goody
# a bad word embedding: following
# a bad word embedding: our
# a bad word embedding: marsden
# a bad word embedding: slightly
# a bad word embedding: pur
# a bad word embedding: out
# a bad word embedding: hermoine
# a bad word embedding: awesome
# a bad word embedding: stipulation
# a bad word embedding: bad
# a bad word embedding: ter
# a bad word embedding: allowed
# a bad word embedding: offense
# a bad word embedding: kemacetan
# a bad word embedding: juli
# a bad word embedding: stole
# a bad word embedding: piazza
# a bad word embedding: winter
# a bad word embedding: cobain
# a bad word embedding: gambino
# a bad word embedding: who
# a bad word embedding: poking
# a bad word embedding: cloak
# a bad word embedding: caged
# a bad word embedding: homii
# a bad word embedding: why
# a bad word embedding: snaps
# a bad word embedding: jazz
# a bad word embedding: laundry
# a bad word embedding: explorer
# a bad word embedding: meets
# a bad word embedding: blogtv
# a bad word embedding: punk
# a bad word embedding: blasting
# a bad word embedding: spot
# a bad word embedding: dats
# a bad word embedding: applications
# a bad word embedding: snape
# a bad word embedding: co-writing
# a bad word embedding: date
# a bad word embedding: such
# a bad word embedding: suck
# a bad word embedding: data
# a bad word embedding: shockingly
# a bad word embedding: moly
# a bad word embedding: surfing
# a bad word embedding: natural
# a bad word embedding: vogel
# a bad word embedding: stomping
# a bad word embedding: wheelchair
# a bad word embedding: sw
# a bad word embedding: st
# a bad word embedding: si
# a bad word embedding: sh
# a bad word embedding: so
# a bad word embedding: haterade
# a bad word embedding: swollen
# a bad word embedding: kanye
# a bad word embedding: sa
# a bad word embedding: katie
# a bad word embedding: pulled
# a bad word embedding: se
# a bad word embedding: sd
# a bad word embedding: drunken
# a bad word embedding: lie
# a bad word embedding: imogen
# a bad word embedding: barnes
# a bad word embedding: morissette
# a bad word embedding: years
# a bad word embedding: rihanna
# a bad word embedding: course
# a bad word embedding: episodes
# a bad word embedding: kanye
# a bad word embedding: stills
# a bad word embedding: abduzeedo
# a bad word embedding: hip-hop
# a bad word embedding: splurge
# a bad word embedding: overhaul
# a bad word embedding: thumb
# a bad word embedding: couric
# a bad word embedding: muses
# a bad word embedding: tori
# a bad word embedding: stupidity
# a bad word embedding: faves
# a bad word embedding: attraction
# a bad word embedding: suspicion
# a bad word embedding: whitney
# a bad word embedding: troubled
# a bad word embedding: visiting
# a bad word embedding: petition
# a bad word embedding: sate
# a bad word embedding: buck
# a bad word embedding: sister
# a bad word embedding: unlove
# a bad word embedding: hop
# a bad word embedding: matches
# a bad word embedding: smarter
# a bad word embedding: nation
# a bad word embedding: fr
# a bad word embedding: records
# a bad word embedding: strauss
# a bad word embedding: arriving
# a bad word embedding: sorted
# a bad word embedding: twilight
# a bad word embedding: \
# a bad word embedding: maintaining
# a bad word embedding: osama
# a bad word embedding: newest
# a bad word embedding: apologizes
# a bad word embedding: succeeds
# a bad word embedding: wish
# a bad word embedding: yellow
# a bad word embedding: pete
# a bad word embedding: fucking
# a bad word embedding: grants
# a bad word embedding: bowling
# a bad word embedding: stanley
# a bad word embedding: amnesty
# a bad word embedding: argies
# a bad word embedding: repaired
# a bad word embedding: ooomg
# a bad word embedding: louboutin
# a bad word embedding: square
# a bad word embedding: honduras
# a bad word embedding: mexico
# a bad word embedding: couples
# a bad word embedding: breakthrough
# a bad word embedding: live
# a bad word embedding: entering
# a bad word embedding: cole
# a bad word embedding: ergh
# a bad word embedding: troll
# a bad word embedding: joker
# a bad word embedding: demolition
# a bad word embedding: joy
# a bad word embedding: welcome
# a bad word embedding: job
# a bad word embedding: exploding
# a bad word embedding: joe
# a bad word embedding: squares
# a bad word embedding: bla
# a bad word embedding: jon
# a bad word embedding: smalls
# a bad word embedding: dodgers
# a bad word embedding: thank
# a bad word embedding: hairdresser
# a bad word embedding: million
# a bad word embedding: seventh
# a bad word embedding: magical
# a bad word embedding: governing
# a bad word embedding: quite
# a bad word embedding: disrespect
# a bad word embedding: complicated
# a bad word embedding: crazier
# a bad word embedding: besides
# a bad word embedding: mixed
# a bad word embedding: poems
# a bad word embedding: ___
# a bad word embedding: training
# a bad word embedding: dunno
# a bad word embedding: punk
# a bad word embedding: initiate
# a bad word embedding: whiplash
# a bad word embedding: puns
# a bad word embedding: massive
# a bad word embedding: bargain
# a bad word embedding: router
# a bad word embedding: brazil
# a bad word embedding: intuition
# a bad word embedding: saving
# a bad word embedding: baybay
# a bad word embedding: gasp
# a bad word embedding: petulant
# a bad word embedding: royal
# a bad word embedding: one
# a bad word embedding: behave
# a bad word embedding: spanish
# a bad word embedding: vote
# a bad word embedding: open
# a bad word embedding: ripping
# a bad word embedding: exaggerations
# a bad word embedding: city
# a bad word embedding: chums
# a bad word embedding: wrath
# a bad word embedding: monday
# a bad word embedding: structured
# a bad word embedding: rule
# a bad word embedding: hmm
# a bad word embedding: homosexuality
# a bad word embedding: draft
# a bad word embedding: types
# a bad word embedding: stuffed
# a bad word embedding: typing
# a bad word embedding: hype
# a bad word embedding: uses
# a bad word embedding: repeal
# a bad word embedding: violated
# a bad word embedding: williams
# a bad word embedding: patrick
# a bad word embedding: proving
# a bad word embedding: ridiculous
# a bad word embedding: korean
# a bad word embedding: bombs
# a bad word embedding: smoking
# a bad word embedding: fooled
# a bad word embedding: kurt
# a bad word embedding: boyfriend
# a bad word embedding: bored
# a bad word embedding: earmuffs
# a bad word embedding: dickhead
# a bad word embedding: depressed
# a bad word embedding: rival
# a bad word embedding: folly
# a bad word embedding: sensation
# a bad word embedding: crossroads
# a bad word embedding: fun
# a bad word embedding: rehab
# a bad word embedding: rochelle
# a bad word embedding: future
# a bad word embedding: fills
# a bad word embedding: surprisingly
# a bad word embedding: pwahaha
# a bad word embedding: damned
# a bad word embedding: prospect
# a bad word embedding: fly
# a bad word embedding: addressing
# a bad word embedding: illness
# a bad word embedding: nicer
# a bad word embedding: overcooked
# a bad word embedding: turned
# a bad word embedding: argument
# a bad word embedding: alley
# a bad word embedding: sad
# a bad word embedding: prestigious
# a bad word embedding: say
# a bad word embedding: buried
# a bad word embedding: hilarious
# a bad word embedding: allen
# a bad word embedding: regards
# a bad word embedding: e-book
# a bad word embedding: opened
# a bad word embedding: both
# a bad word embedding: presid
# a bad word embedding: zoe
# a bad word embedding: babysit
# a bad word embedding: alicia
# a bad word embedding: aside
# a bad word embedding: note
# a bad word embedding: omfg
# a bad word embedding: take
# a bad word embedding: half
# a bad word embedding: destroy
# a bad word embedding: mayer
# a bad word embedding: hall
# a bad word embedding: ironically
# a bad word embedding: printer
# a bad word embedding: altered
# a bad word embedding: opposite
# a bad word embedding: buffer
# a bad word embedding: knew
# a bad word embedding: kerr
# a bad word embedding: times
# a bad word embedding: wong
# a bad word embedding: abus
# a bad word embedding: keri
# a bad word embedding: remarks
# a bad word embedding: knee
# a bad word embedding: hoped
# a bad word embedding: pages
# a bad word embedding: trainer
# a bad word embedding: democratic
# a bad word embedding: cher
# a bad word embedding: phil
# a bad word embedding: drive
# a bad word embedding: moose
# a bad word embedding: federal
# a bad word embedding: antarctica
# a bad word embedding: strip
# a bad word embedding: ♪
# a bad word embedding: flashback
# a bad word embedding: blue
# a bad word embedding: walking
# a bad word embedding: olha
# a bad word embedding: supplements
# a bad word embedding: opportunist
# a bad word embedding: virgos
# a bad word embedding: sky
# a bad word embedding: tohoku
# a bad word embedding: boyz
# a bad word embedding: roland
# a bad word embedding: hornby
# a bad word embedding: aggressive
# a bad word embedding: wants
# a bad word embedding: smfh
# a bad word embedding: slow
# a bad word embedding: motherhood
# a bad word embedding: sacramento
# a bad word embedding: deck
# a bad word embedding: cinco
# a bad word embedding: tears
# a bad word embedding: going
# a bad word embedding: hockey
# a bad word embedding: outrage
# a bad word embedding: ✔
# a bad word embedding: congressional
# a bad word embedding: bryant
# a bad word embedding: trivia
# a bad word embedding: predict
# a bad word embedding: beatles
# a bad word embedding: hallows
# a bad word embedding: freezing
# a bad word embedding: cursing
# a bad word embedding: magazine
# a bad word embedding: products
# a bad word embedding: crossed
# a bad word embedding: having
# a bad word embedding: prime
# a bad word embedding: resource
# a bad word embedding: clipe
# a bad word embedding: artist
# a bad word embedding: jeff
# a bad word embedding: borrow
# a bad word embedding: awwwww
# a bad word embedding: worried
# a bad word embedding: manchester
# a bad word embedding: bombs
# a bad word embedding: worries
# a bad word embedding: yes
# a bad word embedding: where
# a bad word embedding: vision
# a bad word embedding: lindsaylohan
# a bad word embedding: cio
# a bad word embedding: diluted
# a bad word embedding: gangster
# a bad word embedding: anyways
# a bad word embedding: fellas
# a bad word embedding: surgery
# a bad word embedding: enjoying
# a bad word embedding: into
# a bad word embedding: rages
# a bad word embedding: britt
# a bad word embedding: church
# a bad word embedding: brave
# a bad word embedding: that
# a bad word embedding: jumped
# a bad word embedding: sites
# a bad word embedding: wisdom
# a bad word embedding: teeny
# a bad word embedding: books
# a bad word embedding: jonas
# a bad word embedding: teens
# a bad word embedding: than
# a bad word embedding: jumper
# a bad word embedding: bible
# a bad word embedding: jobs
# a bad word embedding: uk
# a bad word embedding: klown
# a bad word embedding: screen
# a bad word embedding: planes
# a bad word embedding: dome
# a bad word embedding: supermarket
# a bad word embedding: awards
# a bad word embedding: dslrs
# a bad word embedding: spark
# a bad word embedding: undermine
# a bad word embedding: tried
# a bad word embedding: www
# a bad word embedding: rant
# a bad word embedding: lice
# a bad word embedding: many
# a bad word embedding: manz
# a bad word embedding: millionaire
# a bad word embedding: flipped
# a bad word embedding: mana
# a bad word embedding: s
# a bad word embedding: loudly
# a bad word embedding: crooked
# a bad word embedding: expression
# a bad word embedding: guts
# a bad word embedding: syria
# a bad word embedding: timberlake
# a bad word embedding: team
# a bad word embedding: yankovic
# a bad word embedding: fsm
# a bad word embedding: mccain
# a bad word embedding: comparing
# a bad word embedding: twin
# a bad word embedding: appeaser
# a bad word embedding: comeback
# a bad word embedding: sentinel
# a bad word embedding: considers
# a bad word embedding: boat
# a bad word embedding: math
# a bad word embedding: caring
# a bad word embedding: myles
# a bad word embedding: armstrong
# a bad word embedding: fic
# a bad word embedding: stretch
# a bad word embedding: west
# a bad word embedding: flash
# a bad word embedding: breath
# a bad word embedding: combined
# a bad word embedding: nessas
# a bad word embedding: reflex
# a bad word embedding: princess
# a bad word embedding: hilarity
# a bad word embedding: shine
# a bad word embedding: wants
# a bad word embedding: detach
# a bad word embedding: whenever
# a bad word embedding: marc
# a bad word embedding: antivirus
# a bad word embedding: turtleneck
# a bad word embedding: muchlove
# a bad word embedding: greatest
# a bad word embedding: fleshy
# a bad word embedding: former
# a bad word embedding: fireflies
# a bad word embedding: jazeera
# a bad word embedding: run
# a bad word embedding: libya
# a bad word embedding: consultant
# a bad word embedding: polls
# a bad word embedding: outside
# a bad word embedding: ransom
# a bad word embedding: him
# a bad word embedding: doctrine
# a bad word embedding: situation
# a bad word embedding: album
# a bad word embedding: ive
# a bad word embedding: feel
# a bad word embedding: die
# a bad word embedding: purse
# a bad word embedding: dubious
# a bad word embedding: quiet
# a bad word embedding: looking
# a bad word embedding: blah
# a bad word embedding: useless
# a bad word embedding: prez
# a bad word embedding: pharoah
# a bad word embedding: grievous
# a bad word embedding: month
# a bad word embedding: technology
# a bad word embedding: fame
# a bad word embedding: pres
# a bad word embedding: len
# a bad word embedding: binary
# a bad word embedding: missiles
# a bad word embedding: verified
# a bad word embedding: rooting
# a bad word embedding: nationalism
# a bad word embedding: lovers
# a bad word embedding: yessir
# a bad word embedding: damon
# a bad word embedding: through
# a bad word embedding: bloom
# a bad word embedding: workout
# a bad word embedding: homophobic
# a bad word embedding: jailbreaking
# a bad word embedding: breakdown
# a bad word embedding: wires
# a bad word embedding: sickness
# a bad word embedding: i
# a bad word embedding: rotflmao
# a bad word embedding: rfid
# a bad word embedding: cheers
# a bad word embedding: cullen
# a bad word embedding: wired
# a bad word embedding: deff
# a bad word embedding: clean
# a bad word embedding: %
# a bad word embedding: taskbar
# a bad word embedding: own
# a bad word embedding: says
# a bad word embedding: behaved
# a bad word embedding: owe
# a bad word embedding: know
# a bad word embedding: may
# a bad word embedding: costs
# a bad word embedding: tutorial
# a bad word embedding: scholarship
# a bad word embedding: summer
# a bad word embedding: hbo
# a bad word embedding: sprayed
# a bad word embedding: predicting
# a bad word embedding: being
# a bad word embedding: rest
# a bad word embedding: conservative
# a bad word embedding: cards
# a bad word embedding: daniel
# a bad word embedding: verdad
# a bad word embedding: summed
# a bad word embedding: jeremy
# a bad word embedding: weekly
# a bad word embedding: segal
# a bad word embedding: kirk
# a bad word embedding: approves
# a bad word embedding: characterization
# a bad word embedding: nyanyi
# a bad word embedding: travolta
# a bad word embedding: crank
# a bad word embedding: overthrow
# a bad word embedding: coded
# a bad word embedding: vibrating
# a bad word embedding: pfsh
# a bad word embedding: travel
# a bad word embedding: roller
# a bad word embedding: ellen
# a bad word embedding: starving
# a bad word embedding: aspects
# a bad word embedding: around
# a bad word embedding: sonic
# a bad word embedding: myself
# a bad word embedding: drake
# a bad word embedding: bresnan
# a bad word embedding: retract
# a bad word embedding: dari
# a bad word embedding: traffic
# a bad word embedding: preference
# a bad word embedding: mgmt
# a bad word embedding: libs
# a bad word embedding: world
# a bad word embedding: dare
# a bad word embedding: sensational
# a bad word embedding: intel
# a bad word embedding: extremely
# a bad word embedding: share
# a bad word embedding: pole
# a bad word embedding: yourself
# a bad word embedding: rachael
# a bad word embedding: achievement
# a bad word embedding: clay
# a bad word embedding: beverly
# a bad word embedding: pundits
# a bad word embedding: tart
# a bad word embedding: agreed
# a bad word embedding: brite
# a bad word embedding: perry
# a bad word embedding: fives
# a bad word embedding: india
# a bad word embedding: khaled
# a bad word embedding: lebanon
# a bad word embedding: tvs
# a bad word embedding: seriously
# a bad word embedding: elements
# a bad word embedding: strobist
# a bad word embedding: brits
# a bad word embedding: divine
# a bad word embedding: thinks
# a bad word embedding: boxers
# a bad word embedding: scandals
# a bad word embedding: noob
# a bad word embedding: ddr
# a bad word embedding: tube
# a bad word embedding: ;]
# a bad word embedding: nook
# a bad word embedding: korver
# a bad word embedding: exit
# a bad word embedding: effort
# a bad word embedding: biased
# a bad word embedding: squabble
# a bad word embedding: transformers
# a bad word embedding: tcot
# a bad word embedding: disinformation
# a bad word embedding: sephora
# a bad word embedding: thumbs-up
# a bad word embedding: cash
# a bad word embedding: shoujo
# a bad word embedding: leadership
# a bad word embedding: curious
# a bad word embedding: lucia
# a bad word embedding: miss
# a bad word embedding: lock
# a bad word embedding: stone
# a bad word embedding: ace
# a bad word embedding: industry
# a bad word embedding: favorite
# a bad word embedding: side
# a bad word embedding: act
# a bad word embedding: message
# a bad word embedding: mean
# a bad word embedding: skew
# a bad word embedding: notwinning
# a bad word embedding: buuren
# a bad word embedding: her
# a bad word embedding: no
# a bad word embedding: headsets
# a bad word embedding: image
# a bad word embedding: qro
# a bad word embedding: paint
# a bad word embedding: gaddafi
# a bad word embedding: homeless
# a bad word embedding: parties
# a bad word embedding: nh
# a bad word embedding: subscriber
# a bad word embedding: her
# a bad word embedding: hes
# a bad word embedding: na
# a bad word embedding: transexual
# a bad word embedding: housewives
# a bad word embedding: sides
# a bad word embedding: hee
# a bad word embedding: nz
# a bad word embedding: mindless
# a bad word embedding: hea
# a bad word embedding: ringwald
# a bad word embedding: brazilian
# a bad word embedding: np
# a bad word embedding: bubble
# a bad word embedding: lang
# a bad word embedding: complete
# a bad word embedding: yayy
# a bad word embedding: arrogance
# a bad word embedding: harry
# a bad word embedding: lampoons
# a bad word embedding: with
# a bad word embedding: kai
# a bad word embedding: buying
# a bad word embedding: handsome
# a bad word embedding: pull
# a bad word embedding: rush
# a bad word embedding: october
# a bad word embedding: marni
# a bad word embedding: monopoly
# a bad word embedding: house
# a bad word embedding: tripe
# a bad word embedding: unveils
# a bad word embedding: taught
# a bad word embedding: -------------
# a bad word embedding: dirty
# a bad word embedding: politically
# a bad word embedding: obsession
# a bad word embedding: agree
# a bad word embedding: detailed
# a bad word embedding: e'er
# a bad word embedding: ab
# a bad word embedding: ohh
# a bad word embedding: ad
# a bad word embedding: ai
# a bad word embedding: ah
# a bad word embedding: walkn
# a bad word embedding: stealing
# a bad word embedding: am
# a bad word embedding: al
# a bad word embedding: watches
# a bad word embedding: how
# a bad word embedding: as
# a bad word embedding: ar
# a bad word embedding: au
# a bad word embedding: at
# ...
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# I0121 22:20:27.637286 139900719126400 utils.py:141] NumExpr defaulting to 2 threads.
# I am AT.
# WARNING:tensorflow:From at_lstm.py:173: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0121 22:20:28.118342 139900719126400 deprecation.py:506] From at_lstm.py:173: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From at_lstm.py:113: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W0121 22:20:28.127796 139900719126400 deprecation.py:323] From at_lstm.py:113: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From at_lstm.py:117: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# W0121 22:20:28.129145 139900719126400 deprecation.py:323] From at_lstm.py:117: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W0121 22:20:28.210009 139900719126400 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0121 22:20:28.218070 139900719126400 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0121 22:20:28.236171 139900719126400 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From at_lstm.py:213: calling reduce_max_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# W0121 22:20:28.267183 139900719126400 deprecation.py:506] From at_lstm.py:213: calling reduce_max_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From at_lstm.py:218: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# W0121 22:20:28.276711 139900719126400 deprecation.py:506] From at_lstm.py:218: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From at_lstm.py:230: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# W0121 22:20:28.307484 139900719126400 module_wrapper.py:139] From at_lstm.py:230: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From at_lstm.py:230: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0121 22:20:28.307667 139900719126400 module_wrapper.py:139] From at_lstm.py:230: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From at_lstm.py:232: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0121 22:20:28.308467 139900719126400 module_wrapper.py:139] From at_lstm.py:232: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From at_lstm.py:236: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0121 22:20:28.320827 139900719126400 module_wrapper.py:139] From at_lstm.py:236: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From at_lstm.py:246: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0121 22:20:28.980772 139900719126400 module_wrapper.py:139] From at_lstm.py:246: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-01-21 22:20:28.982056: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-21 22:20:29.015122: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 22:20:29.015744: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-01-21 22:20:29.016042: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-21 22:20:29.017719: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-01-21 22:20:29.019212: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-01-21 22:20:29.019562: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-01-21 22:20:29.021122: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-01-21 22:20:29.021849: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-01-21 22:20:29.025516: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-01-21 22:20:29.025683: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 22:20:29.026335: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 22:20:29.026883: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-01-21 22:20:29.031551: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-01-21 22:20:29.031733: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x19a4d80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-01-21 22:20:29.031757: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-01-21 22:20:29.138557: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 22:20:29.139184: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x19a4bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-01-21 22:20:29.139215: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-01-21 22:20:29.139476: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 22:20:29.139978: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-01-21 22:20:29.140052: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-21 22:20:29.140076: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-01-21 22:20:29.140101: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-01-21 22:20:29.140121: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-01-21 22:20:29.140144: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-01-21 22:20:29.140162: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-01-21 22:20:29.140180: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-01-21 22:20:29.140279: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 22:20:29.140888: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 22:20:29.141386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-01-21 22:20:29.141463: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-21 22:20:29.142616: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-01-21 22:20:29.142642: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-01-21 22:20:29.142653: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-01-21 22:20:29.142791: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 22:20:29.143331: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-21 22:20:29.143813: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-01-21 22:20:29.143849: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From at_lstm.py:258: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0121 22:20:29.144613 139900719126400 module_wrapper.py:139] From at_lstm.py:258: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From at_lstm.py:260: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W0121 22:20:29.147147 139900719126400 module_wrapper.py:139] From at_lstm.py:260: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From at_lstm.py:266: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# W0121 22:20:29.148849 139900719126400 module_wrapper.py:139] From at_lstm.py:266: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From at_lstm.py:270: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0121 22:20:29.659093 139900719126400 module_wrapper.py:139] From at_lstm.py:270: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From at_lstm.py:270: The name tf.train.SaverDef is deprecated. Please use tf.compat.v1.train.SaverDef instead.
#
# W0121 22:20:29.659611 139900719126400 module_wrapper.py:139] From at_lstm.py:270: The name tf.train.SaverDef is deprecated. Please use tf.compat.v1.train.SaverDef instead.
#
# WARNING:tensorflow:From at_lstm.py:272: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# W0121 22:20:29.690641 139900719126400 module_wrapper.py:139] From at_lstm.py:272: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# load word-to-id done!
# load aspect-to-id done!
# cnt= 3401
# Counter({'1': 2480, '0': 921})
# aaaaa= 107
# aaaaa= 107
# aaaaa= 104
# aaaaa= 104
# Traceback (most recent call last):
#   File "at_lstm.py", line 376, in <module>
#     tf.app.run()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 299, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 250, in _run_main
#     sys.exit(main(argv))
#   File "at_lstm.py", line 372, in main
#     lstm.run()
#   File "at_lstm.py", line 287, in run
#     self.type_
#   File "/content/TD-LSTM/utils.py", line 214, in load_inputs_twitter_at
#     x = np.asarray(x, dtype=np.int32)
#   File "/usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: setting an array element with a sequence.

# %%
# AEAT SentiHood
# %cd /content/TD-LSTM
# !python at_lstm.py --train_file_path='../tmp/train.raw' --validate_file_path='../tmp/validate.raw' --test_file_path='../tmp/test.raw' --embedding_file_path='../tmp/twitter_word_embedding_partial_200.txt' --word_id_file_path='../tmp/word_id.txt' --aspect_id_file_path='../tmp/aspect_id.txt' --method='AEAT' --n_class=2
